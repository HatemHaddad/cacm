# %%
import pandas as pd
import numpy as np
import pyodbc
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
svr_name = 'KU1ICDDWV011.kunet.ae'
db_name_read = 'CACM'
db_name_write = 'CACMP'
u_name = 'cacm_user'
u_pass = 'Welcome#123'

# %%
eng_read = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name_read+"?driver=ODBC+Driver+17+for+SQL+Server")
eng_write = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name_write+"?driver=ODBC+Driver+17+for+SQL+Server")

# %% [markdown]
# # IT Tickets

# %%
query_std_IT = "Select * from dbo.IT_Tickets_View"

# %%
df_IT_Tickets = pd.read_sql(query_std_IT, eng_read)

# %%
df_IT_Tickets.to_excel("./data/df_IT_Tickets_P.xlsx")

# %%
closed = df_IT_Tickets['RequestStatus'] == 'Closed'
other = df_IT_Tickets['Category'] == 'Other'

# %%
df_IT_Tickets[np.logical_and(closed,other)]
# Out:
#       SLAStatus  ReferenceNumber  \
# 4                          65711
# 7                          65725
# 19                         65748
# 23                         65761
# 63                         65824
# ...         ...              ...
# 46039                     140679
# 46057                     140720
# 46108                     140796
# 46381                     141231
# 46549                     141496
#
#                                                  Subject  \
# 4      RECORDS MANAGEMENT, RETENTION AND DESTRUCTION ...
# 7                                        Transcript size
# 19             Returned mail: see transcript for details
# 23                                  List of KU Emolpyees
# 63     [*Newsletter*] Discover the Benefits of Pre-Te...
# ...                                                  ...
# 46039                                          Faza card
# 46057                     Maintenance (Bulb replacement)
# ...
