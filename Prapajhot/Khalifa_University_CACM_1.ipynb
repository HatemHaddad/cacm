# %% [markdown]
# # Khalifa University - CACM

# %% [markdown]
# ### Table of Contents
#
# - *Student Master Data*
# - *Human Resources Master Data*
# - *Finance Master Data*

# %% [markdown]
# ### Master Data Naming Convention
#
# The scripts and pandas dataframe across the jupyter notebook follows the following naming convention:
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> df_[type of database]_[master] </div>
#
# where df is the dataframe
# type of database is students, finance, human resources
# master refers to master data

# %% [markdown]
# ### Exceptions Naming Convention
#
# Additionally, all exceptions are named using the following naming convention:
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> df_[type of database]_[master]_[exception] </div>
#
# where df is the dataframe
# type of database is students, finance, human resources
# master refers to master data
# exception refers to type of exception, for e.g., duplicate students, employee details, invoices, payments etc.

# %% [markdown]
# # Import Data from SQL Server

# %% [markdown]
# ### Key Libraries

# %% [markdown]
# **Pymssql** is a sql connector package that enables to extract all information in the server directly into pandas dataframe as an input.
#
# Using pymssql extract all information from different sql queries and can be utilized for analysis / creating the mongoDB.
#
# The below scripts in other sections can utilize the pandas dataframe directly for running the analysis instead of connecting to excel files.
#
# **Pandas** - Pandas is a fast, powerful, flexible and easy to use open source library which enables the user to perform data manipulation from any source (SQL, Excel, JSON, etc.)
#
# **Numpy** - Numpy is a versatile tool in python for data analysis which enables to user to perform analysis around n-dimensional arrays, numerical computing tools and object oriented programming for ensuring readability / scalability of the code.
#
# **Time** - Time is a library to import and stamp the current data / time of analysis and store for future information incase of tracking previous iteration of exceptions.
#
# Additionally, the naming convention within python can assist in utilizing these libraries as abbreviations.
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> **import pandas as pd** enables the user to use "pd" within the python code to the use pandas library</div>

# %%
import pandas as pd
import numpy as np
import pyodbc
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
svr_name = 'KU1ICDDWV011.kunet.ae'
db_name_read = 'CACM'
db_name_write = 'CACMP'
u_name = 'cacm_user'
u_pass = 'Welcome#123'

# %%
eng_read = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name_read+"?driver=ODBC+Driver+17+for+SQL+Server")
eng_write = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name_write+"?driver=ODBC+Driver+17+for+SQL+Server")

# %% [markdown]
# To extract the relevant information from the SQL server, below the following example:
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Query = SELECT * FROM [Database] WHERE [Condition] </div>
#
# where Database is the name of the database;
# and conditions can be added as required such as WHERE, GroupBy, Join etc.

# %% [markdown]
# **Extract Student Master Information**

# %% [markdown]
# Based on the requirement, we can use pymssql or pyodbc. For each instance the sample code is given below:

# %%
query_std_master = "SELECT * FROM dbo.KU_SRC_STD_MASTER"

# %%
df_student_master = pd.read_sql(query_std_master, eng_read)

# %%
df_student_master.to_excel("./data/df_student_master.xlsx")

# %% [markdown]
# **Extract Student Course Schedule**

# %%
query_crs_sced = "SELECT * FROM dbo.KU_SRC_STD_CRS_SCHEDULE"

# %%
df_student_courses = pd.read_sql(query_crs_sced, eng_read)

# %%
df_student_courses.to_excel("./data/df_student_courses.xlsx")

# %% [markdown]
# **Extract Student Attednance**

# %%
query_std_attend = "SELECT * FROM dbo.KU_SRC_STD_ATTENDANCE"

# %%
df_student_attendance = pd.read_sql(query_std_attend, eng_read)

# %%
df_student_attendance.to_excel("./data/df_student_attendance.xlsx")

# %% [markdown]
# **Extract Employee Master Information**

# %%
query_emp_details = "SELECT * FROM dbo.KU_SRC_EmployeeDetails"

# %%
df_employee_master = pd.read_sql(query_emp_details, eng_read)

# %%
df_employee_master.to_excel("./data/df_employee_master.xlsx")

# %% [markdown]
# **Extract Employee Bank Details**

# %%
query_emp_emp_bank_details = "SELECT * FROM dbo.KU_SRC_EmployeesBankDetails"

# %%
df_employee_bank_details = pd.read_sql(query_emp_emp_bank_details, eng_read)

# %%
df_employee_bank_details.to_excel("./data/df_employee_bank_details.xlsx")

# %% [markdown]
# **Extract Employee Leaves**

# %%
query_emp_leaves = "SELECT * FROM dbo.KU_SRC_EmployeesLeaves"

# %%
df_employee_leaves = pd.read_sql(query_emp_leaves, eng_read)

# %%
df_employee_leaves.to_excel("./data/df_employee_leaves.xlsx")

# %% [markdown]
# **Extract AP Invoices**

# %%
query_ap_invoices = "SELECT * FROM dbo.KU_SRC_AP_Invoices"

# %%
df_AP_invoices = pd.read_sql(query_ap_invoices, eng_read)

# %%
df_AP_invoices.to_excel("./data/df_AP_invoices.xlsx")

# %% [markdown]
# **Extract Purchase Order Master**

# %%
query_pos = "SELECT * FROM KU_SRC_BI_KUST_PO"

# %%
df_POs = pd.read_sql(query_pos, eng_read)

# %%
df_POs.to_excel("./data/df_POs_1.xlsx",)

# %%
df_POs.shape
# Out:
# (51053, 56)

# %% [markdown]
# **Extract Purchase Requisitions Information**

# %%
query_prs = "SELECT * FROM dbo.KU_SRC_PRs"

# %%
df_PRs = pd.read_sql(query_prs, eng_read)

# %%
df_PRs.to_excel("./data/df_PRs.xlsx")

# %% [markdown]
# **Extract IT Tickets**

# %%
query_it_tickets = "SELECT * FROM dbo.KU_SRC_IT_Tickets"

# %%
df_it_tickets = pd.read_sql(query_it_tickets, eng_read)

# %%
df_it_tickets.to_excel("./data/df_it_tickets.xlsx")

# %% [markdown]
# **Extract Supplier Information**

# %%
query_supplier_master = "SELECT * FROM dbo.KU_SRC_Suppliers"

# %%
df_supplier_master = pd.read_sql(query_supplier_master, eng_read)

# %%
df_supplier_master.to_excel("./data/df_supplier_master.xlsx")

# %% [markdown]
# ## Write into SQL Server

# %% [markdown]
# For writing files / exceptions into SQL Server, the following code can be utilized:
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Code = [dataframe].to_sql("[Name of table / database]", conn) </div>
#
# where dataframe is the name of the pandas dataframe
# to_sql writes into the SQL server
# Name of table / database is the name of the database in the SQL server
# conn is the connection established to the SQL server

# %% [markdown]
# # Scripts for Student, Procurement and Finance Master Data

# %% [markdown]
# # 1. Student Master Data

# %% [markdown]
# Pandas dataframe library within python enables to import information from any database including SQL, Excel, Text, JSON, etc. To utilize Pandas Dataframe, it is important to designate the type of read access.
#
# For importing from excel database the following naming convention is used:
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> df_[type of database]_[master] = pd.read_excel("[Name of file].xlsx") </div>

# %%
df_student_master.head(5)
# Out:
#           ID NAPO_ID FIRST_NAME    LAST_NAME  \
# 0  100020068    None   Mohammed     Al Khaja
# 1  100020083    None     Rashid  Al Murashda
# 2  100020008    None    Abdulla     Mohammed
# 3  100020015    None      Ahmed     Al Wahbi
# 4  100020016    None      Ahmed   Al Suwaidi
#
#                           FULL_NAME ARABIC_NAME ADMIT_TERM START_DATE GENDER  \
# 0             Mohammed Ali Al Khaja        None     200810 2008-08-23      M
# 1   Rashid Rashed Saeed Al Murashda        None     200810 2008-08-23      M
# 2   Abdulla Ahmed Abdullah Mohammed        None     200810 2008-08-23      M
# 3   Ahmed Abdullah Ibrahim Al Wahbi        None     200810 2008-08-23      M
# 4  Ahmed Mohammed Sultan Al Suwaidi        None     200810 2008-08-23      M
#
#   CAMPUS  ... MOBILE3 PARENT_PHONE RESIDENCE_PHONE POBOX  CITY  \
# 0      S  ...    None         None            None  None  None
# 1      S  ...    None         None            None  None  None
# 2      S  ...    None         None            None  None  None
# 3      S  ...    None         None            None  None  None
# 4      S  ...    None         None            None  None  None
#
#             NATIONALITY  EMERGENCY_CONTACT_NAME EMERGENCY_CONTACT_INFORMATION  \
# 0  United Arab Emirates                    None                          None
# 1  United Arab Emirates                    None                          None
# 2  United Arab Emirates                    None                          None
# 3  United Arab Emirates                    None                          None
# 4  United Arab Emirates                    None                          None
#
#   ACADEMIC_STANDING PRIMARY_ADVISOR
# 0              None            None
# 1              None            None
# 2              None            None
# 3              None            None
# 4              None            None
#
# [5 rows x 57 columns]

# %% [markdown]
# ## 1.1 Duplicate Student Records (Frequency: semi-annual - based on admission cycle)

# %% [markdown]
# ### 1.1 Overall Duplicates

# %% [markdown]
# The below set of scripts enable the user to identify the duplicates in student master data based on **student ID, student names, emirates ID, passport details and length of emirates ID**.
#
# Additionally, the script can further be modified to track active and inactive students to identify the admission of academically dismissed students to further test the re-admission of such students as per KU policies and procedures.

# %%
df_student_master_duplicate = df_student_master[df_student_master.duplicated()]

# %%
df_student_master_duplicate
# Out:
# Empty DataFrame
# Columns: [ID, NAPO_ID, FIRST_NAME, LAST_NAME, FULL_NAME, ARABIC_NAME, ADMIT_TERM, START_DATE, GENDER, CAMPUS, MAX_TERM, STUDENT_STATUS, CURRENT_TERM_ENROLLMENT_STATUS, MAX_TERM_ENROLLMENT_STATUS, MAX_TERM_ENROLLED_WITHDR_DATE, PROGRAM, COURSES, MAJOR, CONCENTRATION, MINOR, STUDENT_LEVEL, COLLEGE, CGPA, PASSPORT_ID, PASSPORT_EXP_DATE, EMIRATES_ID, BIRTH_DATE, SCHOOL_NAME, SCHOOL_SYSTEM, SCHOOL_AVG, HIGH_SCHOOL_ENGL, HIGH_SCHOOL_MATH, HIGH_SCHOOL_ARAB, HIGH_SCHOOL_PHYSICS, IELTS_OVERALL, ELTS_TEST_DATE, EMTH, EMEN, EMSAT_PHYSICS, EMSAT_ARABIC, KMT1_MATH, KMT2_MATH, KOXF_ENGLISH, TOFL_ENGLISH, KPET_PHYSICS, MOBILE1, MOBILE2, MOBILE3, PARENT_PHONE, RESIDENCE_PHONE, POBOX, CITY, NATIONALITY, EMERGENCY_CONTACT_NAME, EMERGENCY_CONTACT_INFORMATION, ACADEMIC_STANDING, PRIMARY_ADVISOR]
# Index: []
#
# [0 rows x 57 columns]

# %% [markdown]
# ### 1.1.2 Student ID Duplicates

# %% [markdown]
# Student ID line items are stored in the database as column name **"ID"**. Therefore, to identify the duplicates, the script is enabled on column name "ID".

# %%
df_student_master_duplicate = df_student_master[df_student_master.duplicated(['ID'])]

# %%
df_student_master_duplicate
# Out:
# Empty DataFrame
# Columns: [ID, NAPO_ID, FIRST_NAME, LAST_NAME, FULL_NAME, ARABIC_NAME, ADMIT_TERM, START_DATE, GENDER, CAMPUS, MAX_TERM, STUDENT_STATUS, CURRENT_TERM_ENROLLMENT_STATUS, MAX_TERM_ENROLLMENT_STATUS, MAX_TERM_ENROLLED_WITHDR_DATE, PROGRAM, COURSES, MAJOR, CONCENTRATION, MINOR, STUDENT_LEVEL, COLLEGE, CGPA, PASSPORT_ID, PASSPORT_EXP_DATE, EMIRATES_ID, BIRTH_DATE, SCHOOL_NAME, SCHOOL_SYSTEM, SCHOOL_AVG, HIGH_SCHOOL_ENGL, HIGH_SCHOOL_MATH, HIGH_SCHOOL_ARAB, HIGH_SCHOOL_PHYSICS, IELTS_OVERALL, ELTS_TEST_DATE, EMTH, EMEN, EMSAT_PHYSICS, EMSAT_ARABIC, KMT1_MATH, KMT2_MATH, KOXF_ENGLISH, TOFL_ENGLISH, KPET_PHYSICS, MOBILE1, MOBILE2, MOBILE3, PARENT_PHONE, RESIDENCE_PHONE, POBOX, CITY, NATIONALITY, EMERGENCY_CONTACT_NAME, EMERGENCY_CONTACT_INFORMATION, ACADEMIC_STANDING, PRIMARY_ADVISOR]
# Index: []
#
# [0 rows x 57 columns]

# %% [markdown]
# ### 1.1.3 Student Names Duplicates

# %% [markdown]
# Student Names line items are stored in the database as column name **"FULL_NAME"**. Therefore, to identify the duplicates, the script is enabled on column name "FULL_NAME".

# %%
df_student_master_duplicate = df_student_master[df_student_master.duplicated(['FULL_NAME'])]

# %%
df_student_master_duplicate
# Out:
#               ID NAPO_ID      FIRST_NAME                 LAST_NAME  \
# 3589   100058270    None        Mohammad                 Awadhalla
# 4156   100035081    None            Alya                   Alsaadi
# 6735   100042377    None            Hend  Mohamed Ahmed Almarzooqi
# 6986   100001904    None         Abdulla                    Al Ali
# 7092   100048093    None            Nouf                   Alzaabi
# 7722   100046318    None           Hanan                    Hamdan
# 7757   100052916    None            Fadi                  Dawaymeh
# 7808   100058255    None            Dima                       Ali
# 7833   100043364    None          Fareha                     Nasim
# 7962   100061899    None  Muhammad Ahmed                    Humais
# 8096   100059518    None        Muhammad                     Osama
# 8504   100035348    None          Bushra                    Ehmaid
# 8812   100038841    None           Shiza                    Saleem
# 9213   100048474    None          Mariam                  Alhashmi
# 9292   100049147    None       Xiaoxiong                     Zhang
# 9647   100038906    None         Mahmoud                    Khalil
# 9751   100049400    None  Muhammad Ahmed                    Humais
# 9875   100045979    None          Mariam                   Salmeen
# 9905   100050201    None             Ali                  Alobaidi
# 10184  100042767    None           Hamad     Ali Mohammed Alhosani
# 11346  100049383    None           Haile             Woldesellasse
# 11385  100050075    None          Salama                   Alheara
# 12766  100041200    None           Vikas                     Kumar
# 12867  100047399    None        Muhammad                       Ali
# 13872  100049403    None         Yohanna                     Fseha
# 13938  100058223    None           Tariq                  Altamimi
# 14025  100050196    None           Yusra                 Alblooshi
# 14369  100061039    None         Mohamed                 Alnufaili
# 14495  100058297    None          Maitha                  Alshamsi
# 14645  100036836    None          Martin          Oliver Fernandes
# 15293  100048206    None          Sohail                      Shah
# 15377  100048544    None           Diana                      Amin
# 15481  100049380    None           Karim                    Moharm
# 15482  100049382    None             Mai                   Almarri
# 15987  100050135    None            Hind                  Sulieman
# 15989  100050151    None       Abdulaziz                 Alblooshi
# 16009  100058220    None           Mahra                 Aldarmaki
# 16034  100057585    None         Hongtao                     Zhang
# 16040  100057666    None           Ahmed                 Elkafrawy
# 16105  100050190    None       Abdulaziz                 Alsabeeha
# 16202  100061895    None           Abeer                 Awadallah
#
#                                         FULL_NAME  \
# 3589                      Mohammad Fadi Awadhalla
# 4156                                Alya  Alsaadi
# 6735          Hend Ahmed Mohamed Ahmed Almarzooqi
# 6986                        Abdulla Rashid Al Ali
# 7092                         Nouf Ebrahim Alzaabi
# 7722                  Hanan Ahmad Mohammad Hamdan
# 7757                          Fadi Zeyad Dawaymeh
# 7808                               Dima Samer Ali
# 7833                          Fareha Zainab Nasim
# 7962                       Muhammad Ahmed  Humais
# 8096                              Muhammad  Osama
# 8504                 Bushra Bassam Mohamed Ehmaid
# 8812                                Shiza  Saleem
# 9213   Mariam Abdulhameed Alsayedmohamed Alhashmi
# 9292                             Xiaoxiong  Zhang
# 9647                       Mahmoud Mustafa Khalil
# 9751                       Muhammad Ahmed  Humais
# 9875           Mariam Hamad Salmeen Anber Salmeen
# 9905                Ali Khalid Ali Saleh Alobaidi
# 10184          Hamad Hassan Ali Mohammed Alhosani
# 11346                   Haile Tecle Woldesellasse
# 11385                         Salama Amer Alheara
# 12766                                Vikas  Kumar
# 12867                               Muhammad  Ali
# 13872                         Yohanna Haile Fseha
# 13938                    Tariq Saadaldin Altamimi
# 14025          Yusra Mohammed Moosa Ali Alblooshi
# 14369                   Mohamed Abdulla Alnufaili
# 14495                       Maitha Helal Alshamsi
# 14645                    Martin  Oliver Fernandes
# 15293                                Sohail  Shah
# 15377                     Diana Maher Morris Amin
# 15481                        Karim Ibrahim Moharm
# 15482                      Mai Abdulsalam Almarri
# 15987                         Hind Yahya Sulieman
# 15989      Abdulaziz Abbas Ahmed Yousef Alblooshi
# 16009                     Mahra Khalifa Aldarmaki
# 16034                              Hongtao  Zhang
# 16040                       Ahmed Asaad Elkafrawy
# 16105                  Abdulaziz Nabeel Alsabeeha
# 16202                     Abeer Mahmoud Awadallah
#
#                             ARABIC_NAME ADMIT_TERM          START_DATE GENDER  \
# 3589                 محمد فادي عوض الله     202010 2020-08-23 00:00:00      M
# 4156                               None     200920 2009-11-23 00:00:00      F
# 6735                               None     201510 2015-08-23 00:00:00      F
# 6986                               None     200710 2007-06-18 12:06:23      M
# 7092     نوف ابراهيم سالم مسعود الزعابي     201310 2013-09-08 00:00:00      F
# 7722               حنان احمد محمد حمدان     201520 2016-01-10 00:00:00      F
# 7757            فادي  زياد نواف  دوايمه     201910 2019-08-25 00:00:00      M
# 7808                      ديمة سامر علي     202010 2020-08-23 00:00:00      F
# 7833                               None     201520 2016-01-10 00:00:00      F
# 7962                    محمد أحمد  حميس     202120 2022-01-17 00:00:00      M
# 8096                               None     202010 2020-08-23 00:00:00      M
# 8504                               None     201010 2010-05-01 00:00:00      F
# 8812           شيزا سليم بنت محمد جافيد     201210 2012-09-02 00:00:00      F
# 9213   مريم عبدالحميد السيدمحمد الهاشمي     201510 2015-08-23 00:00:00      F
# 9292                اكسياوكسيونج  زهانج     201520 2016-01-10 00:00:00      M
# 9647                محمود  مصطفى  خليل      201210 2012-09-02 00:00:00      M
# 9751         محمد  أحمد محمد اجاز  رشيد     201810 2018-08-28 00:00:00      M
# 9875        مريم حمد سالمين عنبر سالمين     201710 2017-08-20 00:00:00      F
# 9905          على خالد على صالح العبيدى     201610 2016-08-21 00:00:00      M
# 10184                              None     201510 2015-08-23 00:00:00      M
# 11346              هيلي  تيسل  ولديسلاس     201810 2018-08-28 00:00:00      M
# 11385                              None     201820 2019-01-13 00:00:00      F
# 12766         ويكاس بانجات براساد كومار     201410 2014-08-24 00:00:00      M
# 12867                              None     201110 2011-09-11 00:00:00      M
# 13872                يوحانا  هيل  فسيحة     201810 2018-08-28 00:00:00      F
# 13938             طارق سعدالدين التميمي     202010 2020-08-23 00:00:00      M
# 14025        يسرا محمد موسى على البلوشي     201510 2015-08-23 00:00:00      F
# 14369              محمد عبدالله النفيلي     202110 2021-08-22 00:00:00      M
# 14495                 ميثا هلال الشامسي     202010 2020-08-23 00:00:00      F
# 14645                              None     201110 2011-09-11 00:00:00      M
# 15293                              None     201420 2015-01-11 00:00:00      M
# 15377             ديانا ماهر موريس امين     201410 2014-08-24 00:00:00      F
# 15481               كريم  ابراهيم  محمد     201810 2018-08-28 00:00:00      M
# 15482              مي  عبدالسلام  المري     201810 2018-08-28 00:00:00      F
# 15987                   هند يحيى سليمان     201820 2019-01-13 00:00:00      F
# 15989  عبدالعزيز عباس احمد يوسف البلوشى     201610 2016-08-21 00:00:00      M
# 16009                مهره خليفه الدرمكي     202010 2020-08-23 00:00:00      F
# 16034                      هونجتو  زانج     201920 2020-01-12 00:00:00      M
# 16040                احمد اسعد الكفراوي     201920 2020-01-12 00:00:00      M
# 16105                              None     201820 2019-01-13 00:00:00      M
# 16202               عبير محمود عوض الله     202120 2022-01-17 00:00:00      F
#
#       CAMPUS  ... MOBILE3 PARENT_PHONE RESIDENCE_PHONE  \
# 3589       A  ...    None         None            None
# 4156       S  ...    None         None            None
# 6735       A  ...    None         None            None
# 6986       S  ...    None         None            None
# 7092       M  ...    None         None            None
# 7722       P  ...    None         None            None
# 7757       A  ...    None         None            None
# 7808       A  ...    None         None            None
# 7833       A  ...    None         None            None
# 7962       A  ...    None         None            None
# 8096       A  ...    None         None            None
# 8504       A  ...    None         None            None
# 8812       A  ...    None         None            None
# 9213       Z  ...    None         None            None
# 9292       P  ...    None         None            None
# 9647       A  ...    None         None            None
# 9751       A  ...    None         None            None
# 9875    None  ...    None         None            None
# 9905       H  ...    None         None            None
# 10184      A  ...    None         None            None
# 11346      A  ...    None         None            None
# 11385      A  ...    None         None            None
# 12766      M  ...    None         None            None
# 12867      M  ...    None         None            None
# 13872      A  ...    None         None            None
# 13938      A  ...    None         None            None
# 14025      Z  ...    None         None            None
# 14369      A  ...    None         None            None
# 14495      A  ...    None         None            None
# 14645      A  ...    None         None            None
# 15293      M  ...    None         None            None
# 15377      P  ...    None         None            None
# 15481      A  ...    None         None            None
# 15482      A  ...    None         None            None
# 15987      A  ...    None         None            None
# 15989      H  ...    None         None            None
# 16009      A  ...    None         None            None
# 16034      A  ...    None         None            None
# 16040      A  ...    None         None            None
# 16105      A  ...    None         None            None
# 16202      A  ...    None         None            None
#
#                                                    POBOX  \
# 3589                        Albarsha 2 Street 29 Villa 8
# 4156                                                None
# 6735                                            AL FALAH
# 6986                                     Abu Dhabi 77334
# 7092                                                  UN
# 7722                                      P.O. Box 1065
# 7757   Abu Dhabi,behind one to one hotel, Malqatah st...
# 7808                                           Abu Dhabi
# 7833                          Fatima Bint Mubarak Street
# 7962                    R-1931, Block-14, Federal B Area
# 8096     Ali street house no 2 green land officer colony
# 8504                                                None
# 8812   HSBC Building Opposite Etisalat building Old A...
# 9213                P.O.Box:5852,Mohammed bin zayed city
# 9292            P.O.Box:1002249,18 Fuxue Load, Changping
# 9647                    Airport street .. central market
# 9751                                      P.O.Box: 38384
# 9875                                                 971
# 9905                         PO Box PO Box P.O.Box:31841
# 10184                                        AL HAMEEDYA
# 11346                             HBKU, Educational City
# 11385                                  zone 34, MBZ city
# 12766                      Wind Block Room No 1.08 , SAO
# 12867                                                 UN
# 13872                                 19 Mike Ruta Court
# 13938                                48A st. Al Barsha 2
# 14025                               P.O.Box:1032,Aldhait
# 14369                               Al Shamkha Abu Dhabi
# 14495                           Nahel Town, Alain, 70 St
# 14645                                               None
# 15293                                                 UN
# 15377                                     P.O. Box 25260
# 15481                          383 Gamal Abdelnasser St,
# 15482                      Al Zaab Area, 18 st, Villa 44
# 15987                                             Al Ain
# 15989                        PO Box PO Box P.O.Box:2720,
# 16009                                          Street 22
# 16034                                      Masdar campus
# 16040                          10 st. Abulmaati - Agouza
# 16105               7th April St, Khuzam, Ras Al Khaimah
# 16202                          Building 32 - Apartment 4
#
#                            CITY           NATIONALITY  EMERGENCY_CONTACT_NAME  \
# 3589                      Dubai  United Arab Emirates                    None
# 4156                  Abu Dhabi  United Arab Emirates                    None
# 6735                  Abu Dhabi  United Arab Emirates                    None
# 6986                  Abu Dhabi  United Arab Emirates                    None
# 7092                         UN  United Arab Emirates                    None
# 7722                     Al Ain                JORDAN                    None
# 7757                  Abu Dhabi                JORDAN                      --
# 7808                  Abu Dhabi                JORDAN                    None
# 7833                  Abu Dhabi              PAKISTAN                    None
# 7962                    Karachi              PAKISTAN                    None
# 8096                 Rawalpindi              PAKISTAN                    None
# 8504                       None             PALESTINE                    None
# 8812                  Abu Dhabi              PAKISTAN                    None
# 9213                  Abu Dhabi  United Arab Emirates      FatimaElsyed Ahmed
# 9292                    Beijing                 CHINA                    None
# 9647                  Abu Dhabi  SYRIAN ARAB REPUBLIC                    None
# 9751                  Abu Dhabi              PAKISTAN                      --
# 9875   Baniyas East - Abu Dhabi  United Arab Emirates                    None
# 9905                  Abu Dhabi  United Arab Emirates          khaledAlobaidi
# 10184               Al Hameedya  United Arab Emirates                    None
# 11346                      Doha               ERITREA                      --
# 11385                  Abudhabi  United Arab Emirates                    None
# 12766                 Abu Dhabi                 INDIA                    None
# 12867                        UN              PAKISTAN                    None
# 13872                  Winnipeg               ERITREA               HaileElfu
# 13938                     Dubai  United Arab Emirates                    None
# 14025            Ras Al Khaimah  United Arab Emirates       MohammedAlblooshi
# 14369                 Abu Dhabi  United Arab Emirates                    None
# 14495                     Alain  United Arab Emirates                    None
# 14645                      None                 INDIA                    None
# 15293                        UN                 INDIA                    None
# 15377                 Abu Dhabi                 EGYPT                    None
# 15481                     Egypt                 EGYPT                    None
# 15482                 Abu Dhabi  United Arab Emirates                    None
# 15987                    Al Ain                JORDAN                      --
# 15989                 Abu Dhabi  United Arab Emirates          AbbasAlBlooshi
# 16009            Khalifa City A  United Arab Emirates                    None
# 16034               Masdar City                 CHINA                    None
# 16040                      Giza                 EGYPT                    None
# 16105                  Abudhabi  United Arab Emirates                    None
# 16202               Al Ain City                JORDAN                    None
#
#       EMERGENCY_CONTACT_INFORMATION ACADEMIC_STANDING         PRIMARY_ADVISOR
# 3589                           None              None      Khaled  Elbassioni
# 4156                           None              None                    None
# 6735                           None              None                    None
# 6986                           None              None                    None
# 7092                           None              None                    None
# 7722                           None                00                    None
# 7757                           None              None  Nahla Saeed  Al Amoodi
# 7808                           None              None   Isam Mustafa Janajreh
# 7833                           None              None                    None
# 7962                           None              None     Mahmoud  Al Qutayri
# 8096                           None              None                    None
# 8504                           None              None                    None
# 8812                           None                00                    None
# 9213                     0501955566                00          Braham  Barkat
# 9292                           None              None                    None
# 9647                           None              None                    None
# 9751                           None                00                    None
# 9875                           None                00                    None
# 9905                      506117854              None      Faisal  AlMarzooqi
# 10184                          None              None                    None
# 11346                          None                00                    None
# 11385                          None              None                    None
# 12766                          None              None                    None
# 12867                          None              None                    None
# 13872                  971555291245              None   Banu  Sizirici Yildiz
# 13938                          None              None     Natalie Van Niekerk
# 14025                     506479976              None  Khaled Ali  Al Jaafari
# 14369                          None              None          Toufic  Mezher
# 14495                          None              None         Eman  Alefishat
# 14645                          None              None                    None
# 15293                          None              None                    None
# 15377                          None              None                    None
# 15481                          None              None                    None
# 15482                          None                00                    None
# 15987                          None              None           Sadoon  Morad
# 15989                     506122826              None    Ali Rashed  Al Alili
# 16009                          None              None            Jamal  Ahmad
# 16034                          None              None   Isam Mustafa Janajreh
# 16040                          None              None                    None
# 16105                          None              None                    None
# 16202                          None              None      Khaled  Elbassioni
#
# [41 rows x 57 columns]

# %%
df_comparison = pd.merge(df_student_master, df_student_master_duplicate, on='FULL_NAME', how='inner')
df_comparison.head(5)
# Out:
#         ID_x NAPO_ID_x FIRST_NAME_x              LAST_NAME_x  \
# 0  100032432      None         Alya                  Alsaadi
# 1  100035081      None         Alya                  Alsaadi
# 2  100042429      None       Mariam  Alsayedmohamed Alhashmi
# 3  100048474      None       Mariam                 Alhashmi
# 4  100045114      None       Fareha                    Nasim
#
#                                     FULL_NAME  \
# 0                               Alya  Alsaadi
# 1                               Alya  Alsaadi
# 2  Mariam Abdulhameed Alsayedmohamed Alhashmi
# 3  Mariam Abdulhameed Alsayedmohamed Alhashmi
# 4                         Fareha Zainab Nasim
#
#                       ARABIC_NAME_x ADMIT_TERM_x START_DATE_x GENDER_x  \
# 0                              None       200910   2009-08-23        F
# 1                              None       200920   2009-11-23        F
# 2                              None       201510   2015-08-23        F
# 3  مريم عبدالحميد السيدمحمد الهاشمي       201510   2015-08-23        F
# 4                   فريحه زينب نسيم       201610   2016-08-21        F
#
#   CAMPUS_x  ... MOBILE3_y PARENT_PHONE_y RESIDENCE_PHONE_y  \
# 0        S  ...      None           None              None
# 1        S  ...      None           None              None
# 2        A  ...      None           None              None
# 3        Z  ...      None           None              None
# 4        A  ...      None           None              None
#
#                                 POBOX_y     CITY_y         NATIONALITY_y  \
# 0                                  None  Abu Dhabi  United Arab Emirates
# 1                                  None  Abu Dhabi  United Arab Emirates
# 2  P.O.Box:5852,Mohammed bin zayed city  Abu Dhabi  United Arab Emirates
# 3  P.O.Box:5852,Mohammed bin zayed city  Abu Dhabi  United Arab Emirates
# 4            Fatima Bint Mubarak Street  Abu Dhabi              PAKISTAN
#
#    EMERGENCY_CONTACT_NAME_y EMERGENCY_CONTACT_INFORMATION_y  \
# 0                      None                            None
# 1                      None                            None
# 2        FatimaElsyed Ahmed                      0501955566
# 3        FatimaElsyed Ahmed                      0501955566
# 4                      None                            None
#
#   ACADEMIC_STANDING_y PRIMARY_ADVISOR_y
# 0                None              None
# 1                None              None
# 2                  00    Braham  Barkat
# 3                  00    Braham  Barkat
# 4                None              None
#
# [5 rows x 113 columns]

# %%
df_student_master_duplicate.to_sql("Dup_Student_Records", eng_write)

# %% [markdown]
# ### 1.1.4 Emirates ID Duplicate

# %% [markdown]
# Student Emirates ID line items are stored in the database as column name **"EMIRATES_ID"**. Therefore, to identify the duplicates, the script is enabled on column name "EMIRATES_ID".

# %%
df_student_master_duplicate = df_student_master[df_student_master.duplicated(['EMIRATES_ID'])]

# %%
df_student_master_duplicate
# Out:
#               ID NAPO_ID      FIRST_NAME    LAST_NAME  \
# 1      100020083    None          Rashid  Al Murashda
# 2      100020008    None         Abdulla     Mohammed
# 3      100020015    None           Ahmed     Al Wahbi
# 4      100020016    None           Ahmed   Al Suwaidi
# 6      100020031    None           Hamad      Tunaiji
# ...          ...     ...             ...          ...
# 16518  100061196    None          Maryam          Ali
# 16545  100058885    None        Muhammad    Danishwar
# 16553  100058294    None  Nowshin Radiya        Kabir
# 16555  100058314    None           Cyril       Pepple
# 16557  100058324    None            Sara    El Moussa
#
#                                FULL_NAME       ARABIC_NAME ADMIT_TERM  \
# 1        Rashid Rashed Saeed Al Murashda              None     200810
# 2        Abdulla Ahmed Abdullah Mohammed              None     200810
# 3        Ahmed Abdullah Ibrahim Al Wahbi              None     200810
# 4       Ahmed Mohammed Sultan Al Suwaidi              None     200810
# 6           Hamad Saeed Mohammed Tunaiji              None     200810
# ...                                  ...               ...        ...
# 16518                 Maryam Abdulla Ali  مريم عبدالله علي     202110
# 16545  Muhammad Zulfiqar Ahmad Danishwar              None     202010
# 16553              Nowshin Radiya  Kabir              None     202010
# 16555           Cyril Christopher Pepple              None     202010
# 16557               Sara Ahmad El Moussa  سارة أحمد الموسى     202010
#
#       START_DATE GENDER CAMPUS  ... MOBILE3 PARENT_PHONE RESIDENCE_PHONE  \
# 1     2008-08-23      M      S  ...    None         None            None
# 2     2008-08-23      M      S  ...    None         None            None
# 3     2008-08-23      M      S  ...    None         None            None
# 4     2008-08-23      M      S  ...    None         None            None
# 6     2008-08-23      M      S  ...    None         None            None
# ...          ...    ...    ...  ...     ...          ...             ...
# 16518 2021-08-22      F      A  ...    None         None            None
# 16545 2020-08-23      M      A  ...    None         None            None
# 16553 2020-08-23      F      A  ...    None         None            None
# 16555 2020-08-23      M      A  ...    None         None            None
# 16557 2020-08-23      F      A  ...    None         None            None
#
#                                                    POBOX       CITY  \
# 1                                                   None       None
# 2                                                   None       None
# 3                                                   None       None
# 4                                                   None       None
# 6                                                   None       None
# ...                                                  ...        ...
# 16518                     House 1497 Road 1434 Block 514  Jid alhaj
# 16545  470/02, Near Jiyo Banwuet Hall, Behind Butt Sw...     Lahore
# 16553                                     P.O. Box 42069  Abu Dhabi
# 16555      10 Fatomi Crescent, Bajulaye Compound, Somolu      Lagos
# 16557                       Borj El Chemali/Salha Street       Sour
#
#                 NATIONALITY  EMERGENCY_CONTACT_NAME  \
# 1      United Arab Emirates                    None
# 2      United Arab Emirates                    None
# 3      United Arab Emirates                    None
# 4      United Arab Emirates                    None
# 6      United Arab Emirates                    None
# ...                     ...                     ...
# 16518               BAHRAIN                    None
# 16545              PAKISTAN                    None
# 16553           NEW ZEALAND                    None
# 16555               NIGERIA                    None
# 16557             PALESTINE                    None
#
#       EMERGENCY_CONTACT_INFORMATION ACADEMIC_STANDING        PRIMARY_ADVISOR
# 1                              None              None                   None
# 2                              None              None                   None
# 3                              None              None                   None
# 4                              None              None                   None
# 6                              None              None                   None
# ...                             ...               ...                    ...
# 16518                          None              None                   None
# 16545                          None              None  Isam Mustafa Janajreh
# 16553                          None              None    Mohammad  Abu Haija
# 16555                          None              None   Mohammed  Al Kobaisi
# 16557                          None              None                   None
#
# [5077 rows x 57 columns]

# %%
df_comparison = pd.merge(df_student_master, df_student_master_duplicate, on='EMIRATES_ID', how='inner')
df_comparison.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-b6d1e78817c3> in <module>
# ----> 1 df_comparison = pd.merge(df_student_master, df_student_master_duplicate, on='EMIRATES_ID', how='inner')
#       2 df_comparison.head(5)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#     123
#     124
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     723         rindexers = {1: right_indexer} if right_indexer is not None else {}
#     724
# --> 725         result_data = concatenate_managers(
#     726             [(self.left._mgr, lindexers), (self.right._mgr, rindexers)],
#     727             axes=[llabels.append(rlabels), join_index],
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\concat.py in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     224             fastpath = blk.values.dtype == values.dtype
#     225         else:
# --> 226             values = _concatenate_join_units(join_units, concat_axis, copy=copy)
#     227             fastpath = False
#     228
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\concat.py in _concatenate_join_units(join_units, concat_axis, copy)
#     488     upcasted_na = _dtype_to_na_value(empty_dtype, has_none_blocks)
#     489
# --> 490     to_concat = [
#     491         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     492         for ju in join_units
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\concat.py in <listcomp>(.0)
#     489
#     490     to_concat = [
# --> 491         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
#     492         for ju in join_units
#     493     ]
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\concat.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#     468         else:
#     469             for ax, indexer in self.indexers.items():
# --> 470                 values = algos.take_nd(values, indexer, axis=ax)
#     471
#     472         return values
#
# ~\Anaconda3\lib\site-packages\pandas\core\array_algos\take.py in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     106
#     107     arr = np.asarray(arr)
# --> 108     return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     109
#     110
#
# ~\Anaconda3\lib\site-packages\pandas\core\array_algos\take.py in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     149         out = np.empty(out_shape, dtype=dtype)
#     150
# --> 151     func = _get_take_nd_function(
#     152         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     153     )
#
# KeyboardInterrupt:

# %%
df_student_master_duplicate.to_sql("Dup_Student_Records_EmiratesID", eng_write)

# %% [markdown]
# ### 1.1.5 Emirates ID

# %% [markdown]
# Emirates ID across the UAE contain exactly 15 digits, any deviation to the length of Emirates ID is an invalid detail. To identify such discrepancies, we utilize the **str.len() function** of python which counts the number of characters of each cell in the column.
#
# Further, we filter the results for more than and less than **15 digits to identify discrepancies**.
#
# We noted many student details did not contain Emirates ID details and such students are discarded as part of the test since all those students are inactive.

# %%
df_student_master['Length'] = df_student_master['EMIRATES_ID'].str.len()

# %%
df_student_master_EID = df_student_master[(df_student_master['Length'] < 15) | (df_student_master['Length'] > 15)]

# %%
df_student_master_EID
# Out:
#               ID NAPO_ID      FIRST_NAME     LAST_NAME  \
# 58     100020289    None           Marwa         Jaber
# 128    100035191    None          Zainab       Moazzam
# 249    100038590    None            Mona  Ali Allbishr
# 281    100038884    None            Amna     Alzubaidi
# 463    100038838    None            Lina        El-Haj
# ...          ...     ...             ...           ...
# 14654  100035189    None           Waffa         Fadol
# 14692  100038265    None            Essa      Alshahei
# 14695  100033711    None            Sara       Bazhair
# 14742  100036765    None  Mohammad Ather           Ali
# 15979  100051986    None          Fatima      Abdallah
#
#                                    FULL_NAME  \
# 58                     Marwa Ali Awadh Jaber
# 128          Zainab Muhammad Moazzam Moazzam
# 249            Mona Ahmed Saleh Ali Allbishr
# 281    Amna Abdulmajeed Brek Saeed Alzubaidi
# 463                       Lina Hesham El-Haj
# ...                                      ...
# 14654          Waffa Badraldin  Mohmed Fadol
# 14692                Essa Ahmad Ali Alshahei
# 14695            Sara Khaled Abdulla Bazhair
# 14742            Mohammad Ather Rana Ali Ali
# 15979        Fatima Mohamad Youssef Abdallah
#
#                                ARABIC_NAME ADMIT_TERM START_DATE GENDER  \
# 58                       مروة  علي عوض جبر     200810 2008-08-23      F
# 128                        زينب  محمد معظم     201010 2010-05-01      F
# 249                 منى  أحمد صالح  البشر      201210 2012-09-02      F
# 281           أمنه عبد المجيد بريك الزبيدي     201210 2012-09-02      F
# 463                     لينا  هشام  الحاج      201210 2012-09-02      F
# ...                                    ...        ...        ...    ...
# 14654              وفاء بدر الدين محمد فضل     201010 2010-05-01      F
# 14692               عيسى  أحمد على  الشحى      201210 2012-09-02      M
# 14695  ساره  خالد عبدالله سالم سعيد بازهير     200910 2009-08-23      F
# 14742             محمد  اطهر رانا علي أصغر     201110 2011-09-11      M
# 15979              فاطمه محمد يوسف عبدالله     201410 2014-08-24      F
#
#       CAMPUS  ... PARENT_PHONE RESIDENCE_PHONE                       POBOX  \
# 58         A  ...         None            None                P O Box 7778
# 128        A  ...         None            None              P.O BOX 127788
# 249        S  ...         None            None                P.O.Box 3211
# 281        A  ...         None            None                        None
# 463        A  ...         None            None  Madinet Zayed Falah Street
# ...      ...  ...          ...             ...                         ...
# 14654      A  ...    507730409            None               P O Box 18616
# 14692      A  ...         None            None             Al Warqaa 4 53A
# 14695      A  ...         None            None                  P O Box 89
# 14742      A  ...         None            None                        None
# 15979      Z  ...         None            None         P.O.Box:93818,dubai
#
#             CITY           NATIONALITY EMERGENCY_CONTACT_NAME  \
# 58     Abu Dhabi  United Arab Emirates               MaisaAli
# 128    Abu Dhabi              PAKISTAN                   None
# 249      Sharjah  United Arab Emirates                   None
# 281            -  United Arab Emirates                   None
# 463    Abu Dhabi             AUSTRALIA                   None
# ...          ...                   ...                    ...
# 14654     Al Ain                 SUDAN         BadraldinFadol
# 14692      Dubai  United Arab Emirates                   None
# 14695  Abu Dhabi  United Arab Emirates          NouraBazuhair
# 14742          -              PAKISTAN                   None
# 15979      Dubai  United Arab Emirates        mohammedabdulla
#
#        EMERGENCY_CONTACT_INFORMATION ACADEMIC_STANDING    PRIMARY_ADVISOR  \
# 58                        0506118857                00               None
# 128                             None                00               None
# 249                             None                NA               None
# 281                             None                00               None
# 463                             None                00               None
# ...                              ...               ...                ...
# 14654                      569139349                00               None
# 14692                           None              None               None
# 14695                     0507114172                00               None
# 14742                           None                00               None
# 15979                      504949155              None  Ricardo  Nogueira
#
#       Length
# 58       7.0
# 128      7.0
# 249      9.0
# 281      9.0
# 463      9.0
# ...      ...
# 14654    8.0
# 14692    9.0
# 14695    7.0
# 14742    7.0
# 15979   14.0
#
# [84 rows x 58 columns]

# %%
df_student_master_EID.to_sql("Dup_Student_Records_EID_Length", eng_write)

# %% [markdown]
# ### 1.1.6 Passport

# %% [markdown]
# Student Passport Details line items are stored in the database as column name **"PASSPORT_ID"**. Therefore, to identify the duplicates, the script is enabled on column name "PASSPORT_ID".
#
# Additionally, we can also filter results for all active students for whom the passport details are not entered in the system. This test is necessary for international / students of other nationalities.

# %%
df_student_master_Passport = df_student_master[(df_student_master['STUDENT_STATUS'] == 'Active') & (df_student_master['PASSPORT_ID'] == "NULL")]

# %%
df_student_master_Passport
# Out:
# Empty DataFrame
# Columns: [ID, NAPO_ID, FIRST_NAME, LAST_NAME, FULL_NAME, ARABIC_NAME, ADMIT_TERM, START_DATE, GENDER, CAMPUS, MAX_TERM, STUDENT_STATUS, CURRENT_TERM_ENROLLMENT_STATUS, MAX_TERM_ENROLLMENT_STATUS, MAX_TERM_ENROLLED_WITHDR_DATE, PROGRAM, COURSES, MAJOR, CONCENTRATION, MINOR, STUDENT_LEVEL, COLLEGE, CGPA, PASSPORT_ID, PASSPORT_EXP_DATE, EMIRATES_ID, BIRTH_DATE, SCHOOL_NAME, SCHOOL_SYSTEM, SCHOOL_AVG, HIGH_SCHOOL_ENGL, HIGH_SCHOOL_MATH, HIGH_SCHOOL_ARAB, HIGH_SCHOOL_PHYSICS, IELTS_OVERALL, ELTS_TEST_DATE, EMTH, EMEN, EMSAT_PHYSICS, EMSAT_ARABIC, KMT1_MATH, KMT2_MATH, KOXF_ENGLISH, TOFL_ENGLISH, KPET_PHYSICS, MOBILE1, MOBILE2, MOBILE3, PARENT_PHONE, RESIDENCE_PHONE, POBOX, CITY, NATIONALITY, EMERGENCY_CONTACT_NAME, EMERGENCY_CONTACT_INFORMATION, ACADEMIC_STANDING, PRIMARY_ADVISOR, Length]
# Index: []
#
# [0 rows x 58 columns]

# %% [markdown]
# We can also test for the length in digits for passport details, however the details may or may not be accurate as the number of digits for passport differs across countries / nations.

# %%
df_student_master['Passport_Length'] = df_student_master['PASSPORT_ID'].str.len()

# %%
df_student_master['Passport_Length']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 16587    9.0
# 16588    9.0
# 16589    9.0
# 16590    9.0
# 16591    9.0
# Name: Passport_Length, Length: 16592, dtype: float64

# %%
df_student_master_Passport = df_student_master[(df_student_master['STUDENT_STATUS'] == 'Active') & (df_student_master['Passport_Length'] < 7)]

# %%
df_student_master_Passport
# Out:
#               ID NAPO_ID FIRST_NAME  LAST_NAME  \
# 141    100036658    None      Sarah      Azzam
# 8301   100061297    None      Malak     Zahran
# 9805   100058043    None    George      Hajjar
# 11194  100047903    None    Khadije    El Kadi
# 12309  100046297    None       Omar   Elkhatib
# 12780  100039053    None   Alyazyah  Alsuwaidi
# 14189  100059989    None   Ibrahim      Zaydan
# 16450  100061132    None      Saly      Srouji
#
#                                        FULL_NAME  \
# 141                           Sarah Kassem Azzam
# 8301                        Malak Yasser  Zahran
# 9805                George  Abdulmassih   Hajjar
# 11194                           Khadije  El Kadi
# 12309                        Omar Salah Elkhatib
# 12780  Alyazyah Ahmed Saeed Binshaheen Alsuwaidi
# 14189            Ibrahim  Ibrahim Zaydan  Zaydan
# 16450                  Saly  Oussama El   Srouji
#
#                          ARABIC_NAME ADMIT_TERM START_DATE GENDER CAMPUS  ...  \
# 141                  ساره  قاسم عزام     201720 2018-01-14      F      A  ...
# 8301                  ملك ياسر زهران     202110 2021-08-22      F      A  ...
# 9805             جورج عبدالمسيح حجار     201920 2020-01-12      M      A  ...
# 11194              خديجه شكري القاضي     202110 2021-08-22      F      A  ...
# 12309              عمر  صالح  الخطيب     201920 2020-01-12      M      A  ...
# 12780  اليازية أحمد بن شاهين السويدي     201941 2019-08-18      F   None  ...
# 14189       ابراهيم عبد الرحمن زيدان     202020 2021-01-17      M      A  ...
# 16450             سالي أسامة السروجي     202110 2021-08-22      F      A  ...
#
#       RESIDENCE_PHONE                           POBOX       CITY  \
# 141              None                            None  Abu Dhabi
# 8301             None                       Almamoora  Abu Dhabi
# 9805             None                         Muwajii  Abu Dhabi
# 11194            None  Al Andalos Building, Flat 1801  Abu Dhabi
# 12309            None                 Estiqlal Street  Abu Dhabi
# 12780            None                   P.O.Box 44501    Sharjah
# 14189            None                    Delma Street  Abu Dhabi
# 16450            None          Zayed The First Street  Abu Dhabi
#
#                 NATIONALITY EMERGENCY_CONTACT_NAME  \
# 141               PALESTINE                     --
# 8301                 JORDAN             WafaNubani
# 9805              PALESTINE                   None
# 11194             PALESTINE                   None
# 12309             PALESTINE                   None
# 12780  United Arab Emirates         NouraAlsuwaidi
# 14189             PALESTINE                   None
# 16450             PALESTINE                   None
#
#       EMERGENCY_CONTACT_INFORMATION  ACADEMIC_STANDING  \
# 141                            None               None
# 8301                           None               None
# 9805                           None               None
# 11194                          None               None
# 12309                          None               None
# 12780                00971502121022               None
# 14189                          None               None
# 16450                          None               None
#
#                      PRIMARY_ADVISOR Length Passport_Length
# 141    Abdulrahim Abdulrahman Sajini   15.0             6.0
# 8301              Sean Shan Min Swei   15.0             6.0
# 9805                 Abdullahi  Umar   15.0             6.0
# 11194          Isam Mustafa Janajreh   15.0             6.0
# 12309              Andreas  Schiffer   15.0             6.0
# 12780                Peter  Corridon   15.0             6.0
# 14189                Aymen  Laadhari   15.0             6.0
# 16450         Arjen Rene'  Van Vliet   15.0             6.0
#
# [8 rows x 59 columns]

# %%
df_student_master_Passport.to_sql("Dup_Student_Records_Passport", eng_write)

# %% [markdown]
# ## 1.2 Re-admission of previous students (Frequency: semi-annual - based on admission cycle)

# %% [markdown]
# Students at Khalifa University may be re-admitted based on appopriate approvals from Academic Management. To analyze the re-admitted students, we can identify the students admitted based on same Emirates ID versus the previous inactive accounts.
#
# This will require to analyze the output report to identify such instances as one column does not notify of re-admission.

# %%
df_student_master.head(5)
# Out:
#           ID NAPO_ID FIRST_NAME    LAST_NAME  \
# 0  100020068    None   Mohammed     Al Khaja
# 1  100020083    None     Rashid  Al Murashda
# 2  100020008    None    Abdulla     Mohammed
# 3  100020015    None      Ahmed     Al Wahbi
# 4  100020016    None      Ahmed   Al Suwaidi
#
#                           FULL_NAME ARABIC_NAME ADMIT_TERM START_DATE GENDER  \
# 0             Mohammed Ali Al Khaja        None     200810 2008-08-23      M
# 1   Rashid Rashed Saeed Al Murashda        None     200810 2008-08-23      M
# 2   Abdulla Ahmed Abdullah Mohammed        None     200810 2008-08-23      M
# 3   Ahmed Abdullah Ibrahim Al Wahbi        None     200810 2008-08-23      M
# 4  Ahmed Mohammed Sultan Al Suwaidi        None     200810 2008-08-23      M
#
#   CAMPUS  ... RESIDENCE_PHONE POBOX  CITY           NATIONALITY  \
# 0      S  ...            None  None  None  United Arab Emirates
# 1      S  ...            None  None  None  United Arab Emirates
# 2      S  ...            None  None  None  United Arab Emirates
# 3      S  ...            None  None  None  United Arab Emirates
# 4      S  ...            None  None  None  United Arab Emirates
#
#   EMERGENCY_CONTACT_NAME EMERGENCY_CONTACT_INFORMATION  ACADEMIC_STANDING  \
# 0                   None                          None               None
# 1                   None                          None               None
# 2                   None                          None               None
# 3                   None                          None               None
# 4                   None                          None               None
#
#   PRIMARY_ADVISOR Length Passport_Length
# 0            None    NaN             NaN
# 1            None    NaN             NaN
# 2            None    NaN             NaN
# 3            None    NaN             NaN
# 4            None    NaN             NaN
#
# [5 rows x 59 columns]

# %%
df_student_master_Readmission = df_student_master[(df_student_master['STUDENT_STATUS'] == 'Inactive') & (df_student_master.duplicated(['PASSPORT_ID']))]

# %%
df_student_master_Readmission
# Out:
#               ID NAPO_ID FIRST_NAME    LAST_NAME  \
# 1      100020083    None     Rashid  Al Murashda
# 2      100020008    None    Abdulla     Mohammed
# 3      100020015    None      Ahmed     Al Wahbi
# 4      100020016    None      Ahmed   Al Suwaidi
# 6      100020031    None      Hamad      Tunaiji
# ...          ...     ...        ...          ...
# 15212  100001943    None    Mohamed  Al Marzouqi
# 15495  100001555    None    Abdulla     Al Hebsi
# 15498  100001619    None      Majed    Al Neaimi
# 15500  100001643    None    Mohamed      Mohamed
# 16105  100050190    None  Abdulaziz    Alsabeeha
#
#                                  FULL_NAME ARABIC_NAME ADMIT_TERM  \
# 1          Rashid Rashed Saeed Al Murashda        None     200810
# 2          Abdulla Ahmed Abdullah Mohammed        None     200810
# 3          Ahmed Abdullah Ibrahim Al Wahbi        None     200810
# 4         Ahmed Mohammed Sultan Al Suwaidi        None     200810
# 6             Hamad Saeed Mohammed Tunaiji        None     200810
# ...                                    ...         ...        ...
# 15212    Mohamed Ali M. Habeeb Al Marzouqi        None     200710
# 15495            Abdulla S. Alwan Al Hebsi        None     200310
# 15498  Majed Mohamed S. Alsayyah Al Neaimi        None     200410
# 15500              Mohamed Mohamed Mohamed        None     200410
# 16105           Abdulaziz Nabeel Alsabeeha        None     201820
#
#                START_DATE GENDER CAMPUS  ... RESIDENCE_PHONE  \
# 1     2008-08-23 00:00:00      M      S  ...            None
# 2     2008-08-23 00:00:00      M      S  ...            None
# 3     2008-08-23 00:00:00      M      S  ...            None
# 4     2008-08-23 00:00:00      M      S  ...            None
# 6     2008-08-23 00:00:00      M      S  ...            None
# ...                   ...    ...    ...  ...             ...
# 15212 2007-06-18 12:06:23      M      S  ...            None
# 15495 2003-06-17 18:38:22      M      S  ...            None
# 15498 2004-06-30 09:41:27      M      S  ...            None
# 15500 2004-06-30 09:41:27      M      S  ...            None
# 16105 2019-01-13 00:00:00      M      A  ...            None
#
#                                       POBOX            CITY  \
# 1                                      None            None
# 2                                      None            None
# 3                                      None            None
# 4                                      None            None
# 6                                      None            None
# ...                                     ...             ...
# 15212                                  1612         Sharjah
# 15495                                        Ras Al-Khaimah
# 15498                                   744  Ras Al-Khaimah
# 15500                                  5601         Sharjah
# 16105  7th April St, Khuzam, Ras Al Khaimah        Abudhabi
#
#                 NATIONALITY EMERGENCY_CONTACT_NAME  \
# 1      United Arab Emirates                   None
# 2      United Arab Emirates                   None
# 3      United Arab Emirates                   None
# 4      United Arab Emirates                   None
# 6      United Arab Emirates                   None
# ...                     ...                    ...
# 15212  United Arab Emirates                   None
# 15495  United Arab Emirates                   None
# 15498  United Arab Emirates                   None
# 15500  United Arab Emirates                   None
# 16105  United Arab Emirates                   None
#
#       EMERGENCY_CONTACT_INFORMATION  ACADEMIC_STANDING PRIMARY_ADVISOR Length  \
# 1                              None               None            None    NaN
# 2                              None               None            None    NaN
# 3                              None               None            None    NaN
# 4                              None               None            None    NaN
# 6                              None               None            None    NaN
# ...                             ...                ...             ...    ...
# 15212                          None               None            None    NaN
# 15495                          None               None            None    NaN
# 15498                          None               None            None    NaN
# 15500                          None               None            None    NaN
# 16105                          None               None            None    NaN
#
#       Passport_Length
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 6                 NaN
# ...               ...
# 15212             NaN
# 15495             NaN
# 15498             NaN
# 15500             NaN
# 16105             9.0
#
# [444 rows x 59 columns]

# %%
df_student_master_Readmission.to_sql("Readmitted_students", eng_write)

# %% [markdown]
# ## 1.3 Missing Student Information (Frequency: any frequency - weekly, monthly or quarterly to ensure adequate student information is available)

# %% [markdown]
# All active students should have complete information as per the registrar records and protocol within the master data. The below script analyzes the missing information to ensure completeness of the data.
#
# It is essential to ensure adequate information is available for all students as per SAI requirements which may affect funding received by KU.

# %% [markdown]
# To review the missing information, the library for isnull() is utilized which identifies the missing elements across all columns using the axis (column) technique.

# %%
df_student_master.head(5)
# Out:
#           ID NAPO_ID FIRST_NAME    LAST_NAME  \
# 0  100020068    None   Mohammed     Al Khaja
# 1  100020083    None     Rashid  Al Murashda
# 2  100020008    None    Abdulla     Mohammed
# 3  100020015    None      Ahmed     Al Wahbi
# 4  100020016    None      Ahmed   Al Suwaidi
#
#                           FULL_NAME ARABIC_NAME ADMIT_TERM START_DATE GENDER  \
# 0             Mohammed Ali Al Khaja        None     200810 2008-08-23      M
# 1   Rashid Rashed Saeed Al Murashda        None     200810 2008-08-23      M
# 2   Abdulla Ahmed Abdullah Mohammed        None     200810 2008-08-23      M
# 3   Ahmed Abdullah Ibrahim Al Wahbi        None     200810 2008-08-23      M
# 4  Ahmed Mohammed Sultan Al Suwaidi        None     200810 2008-08-23      M
#
#   CAMPUS  ... RESIDENCE_PHONE POBOX  CITY           NATIONALITY  \
# 0      S  ...            None  None  None  United Arab Emirates
# 1      S  ...            None  None  None  United Arab Emirates
# 2      S  ...            None  None  None  United Arab Emirates
# 3      S  ...            None  None  None  United Arab Emirates
# 4      S  ...            None  None  None  United Arab Emirates
#
#   EMERGENCY_CONTACT_NAME EMERGENCY_CONTACT_INFORMATION  ACADEMIC_STANDING  \
# 0                   None                          None               None
# 1                   None                          None               None
# 2                   None                          None               None
# 3                   None                          None               None
# 4                   None                          None               None
#
#   PRIMARY_ADVISOR Length Passport_Length
# 0            None    NaN             NaN
# 1            None    NaN             NaN
# 2            None    NaN             NaN
# 3            None    NaN             NaN
# 4            None    NaN             NaN
#
# [5 rows x 59 columns]

# %%
df_student_missing = df_student_master[df_student_master.isnull().any(axis=1)]
df_student_missing.head(5)
# Out:
#           ID NAPO_ID FIRST_NAME    LAST_NAME  \
# 0  100020068    None   Mohammed     Al Khaja
# 1  100020083    None     Rashid  Al Murashda
# 2  100020008    None    Abdulla     Mohammed
# 3  100020015    None      Ahmed     Al Wahbi
# 4  100020016    None      Ahmed   Al Suwaidi
#
#                           FULL_NAME ARABIC_NAME ADMIT_TERM START_DATE GENDER  \
# 0             Mohammed Ali Al Khaja        None     200810 2008-08-23      M
# 1   Rashid Rashed Saeed Al Murashda        None     200810 2008-08-23      M
# 2   Abdulla Ahmed Abdullah Mohammed        None     200810 2008-08-23      M
# 3   Ahmed Abdullah Ibrahim Al Wahbi        None     200810 2008-08-23      M
# 4  Ahmed Mohammed Sultan Al Suwaidi        None     200810 2008-08-23      M
#
#   CAMPUS  ... RESIDENCE_PHONE POBOX  CITY           NATIONALITY  \
# 0      S  ...            None  None  None  United Arab Emirates
# 1      S  ...            None  None  None  United Arab Emirates
# 2      S  ...            None  None  None  United Arab Emirates
# 3      S  ...            None  None  None  United Arab Emirates
# 4      S  ...            None  None  None  United Arab Emirates
#
#   EMERGENCY_CONTACT_NAME EMERGENCY_CONTACT_INFORMATION  ACADEMIC_STANDING  \
# 0                   None                          None               None
# 1                   None                          None               None
# 2                   None                          None               None
# 3                   None                          None               None
# 4                   None                          None               None
#
#   PRIMARY_ADVISOR Length Passport_Length
# 0            None    NaN             NaN
# 1            None    NaN             NaN
# 2            None    NaN             NaN
# 3            None    NaN             NaN
# 4            None    NaN             NaN
#
# [5 rows x 59 columns]

# %%
df_student_missing_final = df_student_missing[(df_student_missing['STUDENT_STATUS'] == 'Active')]

# %%
df_student_missing_final.head(5)
# Out:
#             ID NAPO_ID   FIRST_NAME  LAST_NAME  \
# 68   100031581    None        Falah  Alhammadi
# 135  100035244    None  Abdulrahman       Agha
# 141  100036658    None        Sarah      Azzam
# 175  100020345    None       Maryam     Al Ali
# 209  100040178    None         Amna   Alshehhi
#
#                                  FULL_NAME                     ARABIC_NAME  \
# 68     Falah Mohamed Amer Yousuf Alhammadi     فلاح محمد عامر يوسف الحمادى
# 135               Abdulrahman Mohamad Agha          عبدالرحمن محمد عمر آغا
# 141                     Sarah Kassem Azzam                 ساره  قاسم عزام
# 175  Maryam Mohamed Abdulla Mohamed Al Ali  مريم   محمد عبدالله محمد العلي
# 209           Amna Ali Samrah Ali Alshehhi         آمنه علي صمره علي الشحي
#
#     ADMIT_TERM START_DATE GENDER CAMPUS  ... RESIDENCE_PHONE  \
# 68      202010 2020-08-23      M      A  ...            None
# 135     201910 2019-08-25      M      A  ...            None
# 141     201720 2018-01-14      F      A  ...            None
# 175     202010 2020-08-23      F      A  ...            None
# 209     201910 2019-08-25      F      A  ...            None
#
#                                             POBOX       CITY  \
# 68                                  P O Box 50655  Abu Dhabi
# 135                                Al Sulaimaniah     Riyadh
# 141                                          None  Abu Dhabi
# 175                                 PO Box 127788  Abu Dhabi
# 209  Alhumaidia, Sheikh Maktoum Bin Rashed Street      Ajman
#
#               NATIONALITY EMERGENCY_CONTACT_NAME  \
# 68   United Arab Emirates         AdelAl Hammadi
# 135               LEBANON                   None
# 141             PALESTINE                     --
# 175  United Arab Emirates                   None
# 209  United Arab Emirates                     --
#
#     EMERGENCY_CONTACT_INFORMATION  ACADEMIC_STANDING  \
# 68                     0504460448               None
# 135                          None               None
# 141                          None               None
# 175                          None               None
# 209                          None               None
#
#                        PRIMARY_ADVISOR Length Passport_Length
# 68                Anas Zakaria Alazzam   15.0             9.0
# 135               Anas Zakaria Alazzam   15.0             9.0
# 141      Abdulrahim Abdulrahman Sajini   15.0             6.0
# 175  Maryam Rashed Abdulrahman Alkindi   15.0             9.0
# 209                Panagiotis  Liatsis   15.0             9.0
#
# [5 rows x 59 columns]

# %%
df_student_missing_final.to_sql("Missing_student_details", eng_write)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\pyodbc.py in do_executemany(self, cursor, statement, parameters, context)
#     549             cursor.fast_executemany = True
# --> 550         super(MSDialect_pyodbc, self).do_executemany(
#     551             cursor, statement, parameters, context=context
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     713     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 714         cursor.executemany(statement, parameters)
#     715
#
# DataError: ('22007', '[22007] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The conversion of a datetime2 data type to a datetime data type resulted in an out-of-range value. (242) (SQLExecDirectW); [22007] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The statement has been terminated. (3621)')
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-61-55a093bc3b06> in <module>
# ----> 1 df_student_missing_final.to_sql("Missing_student_details", eng_write)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1261             )
#    1262         else:
# -> 1263             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1264
#    1265     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321     ):
#     322         if _force or self.supports_execution:
# --> 323             return connection._execute_clauseelement(
#     324                 self, multiparams, params, execution_options
#     325             )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1450             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1451         )
# -> 1452         ret = self._execute_context(
#    1453             dialect,
#    1454             dialect.execution_ctx_cls._init_compiled,
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1993                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1994             elif should_wrap:
# -> 1995                 util.raise_(
#    1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1749                             break
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#    1753                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\pyodbc.py in do_executemany(self, cursor, statement, parameters, context)
#     548         if self.fast_executemany:
#     549             cursor.fast_executemany = True
# --> 550         super(MSDialect_pyodbc, self).do_executemany(
#     551             cursor, statement, parameters, context=context
#     552         )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     712
#     713     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 714         cursor.executemany(statement, parameters)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
#
# DataError: (pyodbc.DataError) ('22007', '[22007] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The conversion of a datetime2 data type to a datetime data type resulted in an out-of-range value. (242) (SQLExecDirectW); [22007] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The statement has been terminated. (3621)')
# [SQL: INSERT INTO [Missing_student_details] ([index], [ID], [NAPO_ID], [FIRST_NAME], [LAST_NAME], [FULL_NAME], [ARABIC_NAME], [ADMIT_TERM], [START_DATE], [GENDER], [CAMPUS], [MAX_TERM], [STUDENT_STATUS], [CURRENT_TERM_ENROLLMENT_STATUS], [MAX_TERM_ENROLLMENT_STATUS], [MAX_TERM_ENROLLED_WITHDR_DATE], [PROGRAM], [COURSES], [MAJOR], [CONCENTRATION], [MINOR], [STUDENT_LEVEL], [COLLEGE], [CGPA], [PASSPORT_ID], [PASSPORT_EXP_DATE], [EMIRATES_ID], [BIRTH_DATE], [SCHOOL_NAME], [SCHOOL_SYSTEM], [SCHOOL_AVG], [HIGH_SCHOOL_ENGL], [HIGH_SCHOOL_MATH], [HIGH_SCHOOL_ARAB], [HIGH_SCHOOL_PHYSICS], [IELTS_OVERALL], [ELTS_TEST_DATE], [EMTH], [EMEN], [EMSAT_PHYSICS], [EMSAT_ARABIC], [KMT1_MATH], [KMT2_MATH], [KOXF_ENGLISH], [TOFL_ENGLISH], [KPET_PHYSICS], [MOBILE1], [MOBILE2], [MOBILE3], [PARENT_PHONE], [RESIDENCE_PHONE], [POBOX], [CITY], [NATIONALITY], [EMERGENCY_CONTACT_NAME], [EMERGENCY_CONTACT_INFORMATION], [ACADEMIC_STANDING], [PRIMARY_ADVISOR], [Length], [Passport_Length]) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ((68, '100031581', None, 'Falah', 'Alhammadi', 'Falah Mohamed Amer Yousuf Alhammadi', 'فلاح محمد عامر يوسف الحمادى', '202010', datetime.datetime(2020, 8, 23, 0, 0), 'M', 'A', '202120', 'Active', 'YES', 'YES', datetime.datetime(2022, 1, 27, 9, 22, 23), 'PHD_ENGR', 1035.0, 'PHGN', 'MECH', None, 'PH', 'EN', 3.93, 'HCP653009', datetime.datetime(2021, 3, 28, 0, 0), '784199137430874', datetime.datetime(1991, 11, 18, 0, 0), "ALFarazdaq Boy's Secondary Sch", 'High School Goverment Science', '090.8', '072', '097', None, '091', '7.5', datetime.datetime(2020, 2, 21, 0, 0), None, None, None, None, None, None, None, None, None, '505661172', None, None, None, None, 'P O Box 50655', 'Abu Dhabi', 'United Arab Emirates', 'AdelAl Hammadi', '0504460448', None, 'Anas Zakaria Alazzam', 15.0, 9.0), (135, '100035244', None, 'Abdulrahman', 'Agha', 'Abdulrahman Mohamad Agha', 'عبدالرحمن محمد عمر آغا', '201910', datetime.datetime(2019, 8, 25, 0, 0), 'M', 'A', '202120', 'Active', 'YES', 'YES', datetime.datetime(2021, 12, 5, 11, 48, 11), 'PHD_ENGR', 1513.0, 'PHGN', 'MECH', None, 'PH', 'EN', 3.68, 'RL3918703', None, '784199317398701', datetime.datetime(1993, 1, 21, 0, 0), None, 'IGCSE/GCSE', '89.8', '89', '88', None, '85', '7.5', datetime.datetime(2018, 3, 3, 0, 0), None, None, None, None, None, None, '65', None, None, '56 4458584', None, None, None, None, 'Al Sulaimaniah', 'Riyadh', 'LEBANON', None, None, None, 'Anas Zakaria Alazzam', 15.0, 9.0), (141, '100036658', None, 'Sarah', 'Azzam', 'Sarah Kassem Azzam', 'ساره  قاسم عزام', '201720', datetime.datetime(2018, 1, 14, 0, 0), 'F', 'A', '202120', 'Active', 'YES', 'YES', datetime.datetime(2022, 1, 18, 11, 7, 16), 'PHD_ENGR', 2443.0, 'PHGN', 'BMED', None, 'PH', 'EN', 3.89, '534068', datetime.datetime(2018, 11, 11, 0, 0), '784199391837285', datetime.datetime(1993, 3, 2, 0, 0), 'PALESTINE SCHOOL-F', 'High School Goverment -Science', '98.6', '98.5', '98.3', None, '96.7', None, None, None, None, None, None, None, None, '0', '095', None, None, None, None, None, None, None, 'Abu Dhabi', 'PALESTINE', '--', None, None, 'Abdulrahim Abdulrahman Sajini', 15.0, 6.0), (175, '100020345', None, 'Maryam', 'Al Ali', 'Maryam Mohamed Abdulla Mohamed Al Ali', 'مريم   محمد عبدالله محمد العلي', '202010', datetime.datetime(2020, 8, 23, 0, 0), 'F', 'A', None, 'Active', 'NO', 'NO', None, 'B.SC ENGR', 0.0, '0000', None, None, 'UG', 'EN', None, 'NG9230419', datetime.datetime(2017, 6, 24, 0, 0), '784198560380465', datetime.datetime(1985, 10, 3, 0, 0), None, None, None, None, None, None, None, '6.0', datetime.datetime(2019, 2, 20, 0, 0), None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'PO Box 127788', 'Abu Dhabi', 'United Arab Emirates', None, None, None, 'Maryam Rashed Abdulrahman Alkindi', 15.0, 9.0), (209, '100040178', None, 'Amna', 'Alshehhi', 'Amna Ali Samrah Ali Alshehhi', 'آمنه علي صمره علي الشحي', '201910', datetime.datetime(2019, 8, 25, 0, 0), 'F', 'A', '202120', 'Active', 'YES', 'YES', datetime.datetime(2021, 11, 27, 20, 17, 39), 'M.SC ECE', 1750.0, 'ECOE', None, None, 'GR', 'EN', 3.52, 'RNJ459537', datetime.datetime(2021, 8, 3, 0, 0), '784199683628152', datetime.datetime(1996, 3, 3, 0, 0), 'AJMAN SEC .SCHOOL -G', 'High School Goverment -Science', '96.4', '095', '096', None, '090', '6.0', datetime.datetime(2014, 5, 24, 0, 0), None, None, None, None, '075', '070', '049', None, None, '507696056', None, None, None, None, 'Alhumaidia, Sheikh Maktoum Bin Rashed Street', 'Ajman', 'United Arab Emirates', '--', None, None, 'Panagiotis  Liatsis', 15.0, 9.0), (292, '100040035', None, 'Noora', 'Alhosani', 'Noora Ali Mohamed Hasan Alhosani', 'نوره علي محمد الحوسني', '202020', datetime.datetime(2021, 1, 17, 0, 0), 'F', 'A', '202120', 'Active', 'YES', 'YES', datetime.datetime(2021, 11, 24, 16, 2, 45), 'M_ENGR_ HSEG', 622.0, 'HSEG', None, None, 'GR', 'EN', 3.25, 'g70c15277', None, '784199598079202', datetime.datetime(1995, 7, 20, 0, 0), 'UMM AMMAR SCHOOL -F', 'High School Goverment -Science', ...
# (Background on this error at: https://sqlalche.me/e/14/9h9h)

# %% [markdown]
# ## 1.4 Admission requirements (Frequency: semi-annual - based on admission of students)

# %% [markdown]
# Khalifa University admits students based on type of school curriculum (british, american, national, etc.). Additionally, each school curriculum has different admission requirements that the student must fulfill.
#
# However, the IT system does not store the type of school curriculum and only the name of the student. Based on the above information, the code below analyzes the minimum requirements of admission across KU and verifies the student admission based on the same.
#
# For any deviations, appropriate approvals would be required from the Dean of the University/Department and necessary Senior Management/Government which are required to be verified on case to case basis.

# %%
##verify high school average

df_student_admissioncriteria_HS = df_student_master[(df_student_master['STUDENT_STATUS']=='Active') & (df_student_master['SCHOOL_AVG']<70)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-039c480eebe4> in <module>
#       1 ##verify high school average
#       2
# ----> 3 df_student_admissioncriteria_HS = df_student_master[(df_student_master['STUDENT_STATUS']=='Active') & (df_student_master['SCHOOL_AVG']<70)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __lt__(self, other)
#      38     @unpack_zerodim_and_defer("__lt__")
#      39     def __lt__(self, other):
# ---> 40         return self._cmp_method(other, operator.lt)
#      41
#      42     @unpack_zerodim_and_defer("__le__")
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
##verify english scores

df_student_admissioncriteria_EN = df_student_master[(df_student_master['STUDENT_STATUS']=='Active') & (df_student_master['IELTS_OVERALL']<5) | (df_student_master['TOFL_ENGLISH']<90) | (df_student_master['EMEN']<800)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-c72b013bfe36> in <module>
#       1 ##verify english scores
#       2
# ----> 3 df_student_admissioncriteria_EN = df_student_master[(df_student_master['STUDENT_STATUS']=='Active') & (df_student_master['IELTS_OVERALL']<5) | (df_student_master['TOFL_ENGLISH']<90) | (df_student_master['EMEN']<800)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __lt__(self, other)
#      38     @unpack_zerodim_and_defer("__lt__")
#      39     def __lt__(self, other):
# ---> 40         return self._cmp_method(other, operator.lt)
#      41
#      42     @unpack_zerodim_and_defer("__le__")
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
df_student_admissioncriteria_HS.to_sql("HS_Scores", eng_write)

# %%
df_student_admissioncriteria_EN.to_sql("EN_Scores", eng_write)

# %% [markdown]
# # 2. Student Attendance (Frequency: semi-annual - based on end of semester due to the configuration of the IT systems)

# %% [markdown]
# ## 2.1 Student Attendance as per Policy

# %% [markdown]
# Student Attendance in Khalifa University as per the policies and procedures, follow two different protocols:
#
# - 80% and above for undergraduates
# - 50% and above for graduates
#
# For the same, we analyze the student attendance master data in the following manner:
#
# - Identify the Total Classes in the semester
# - Calculate the %age of absences using the new Total Classes figure and number of absences
# - Identify discrepancies of more than 20% and registration status as "RE" (RE refers to still registered)
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b>((Total Classes)/(Total Absences))*100; Highlight all exceptions</div>

# %%
##import master data for excel

## df_student_attendance = pd.read_excel("C:/Users/prabhjotsingh3/OneDrive - KPMG/Documents/2021 Projects/Khalifa University/Project/Data/Student Attendance Data.xlsx")

# %%
df_student_attendance.head()
# Out:
#   TERM_CODE   COURSE    CRN             DIVISION  \
# 0    202120  NUCE601  21075  Nuclear Engineering
# 1    202110  NUCE602  11347  Nuclear Engineering
# 2    202110  NUCE602  11347  Nuclear Engineering
# 3    202120  NUCE603  21076  Nuclear Engineering
# 4    202110  NUCE624  11008  Nuclear Engineering
#
#                      COURSE_TITLE FACULTY_ID   FACULTY_NAME CAMPUS STUDENT_ID  \
# 0  Thermal Hydraulics in Nuc Syst  100035101   Yacine Addad      H  100060563
# 1  Nuc. Materials, Str Int & Chem  100036155     Yongsun Yi      H  100060563
# 2  Nuc. Materials, Str Int & Chem  100036155     Yongsun Yi      H  100041411
# 3          Nuclear Reactor Theory  100043529  Saeed Alameri      H  100060563
# 4      Rad. Damage and Nuc. Fuels  100036155     Yongsun Yi      H  100035400
#
#                     STUDENT_NAME REG_STATUS  TOTAL_ABSENCES  TOTAL_ATTENDED
# 0           Nouf Talib Alhattawi         RE             0.0             8.0
# 1           Nouf Talib Alhattawi         RE             0.0            33.0
# 2    Saif Khalifa Salem Alfalasi         RE             1.0            32.0
# 3           Nouf Talib Alhattawi         RE             0.0             8.0
# 4  Yousif Yaqoub Yousif Alhosani         RW             0.0            36.0

# %%
df_student_attendance['Total Classes'] = df_student_attendance["TOTAL_ABSENCES"]+df_student_attendance["TOTAL_ATTENDED"]

# %%
df_student_attendance['Absence Percentage'] = (df_student_attendance['TOTAL_ABSENCES']/df_student_attendance['Total Classes'])*100

# %%
df_student_attendance_exception = df_student_attendance[(df_student_attendance['Absence Percentage']>20) & (df_student_attendance['REG_STATUS']=="RE")]

# %%
df_student_attendance_exception
# Out:
#       TERM_CODE   COURSE    CRN                        DIVISION  \
# 1127     202120  ENGR111  20143          Engineering Department
# 1441     202120  ENGR111  20154          Engineering Department
# 1488     202120  ENGR111  21218          Engineering Department
# 1506     202120  ENGR111  21218          Engineering Department
# 1510     202120  ENGR111  21218          Engineering Department
# ...         ...      ...    ...                             ...
# 37618    202142  MDBS709  40010    Medicine and Health Sciences
# 38355    202120  ECCE427  20837  Electrical Engr & Computer Sci
# 40463    202120  PHYS122  20432                         Physics
# 41041    202120  COSC434  21182  Electrical Engr & Computer Sci
# 41398    202120  ECCE650  20235  Electrical Engr & Computer Sci
#
#                     COURSE_TITLE FACULTY_ID       FACULTY_NAME CAMPUS  \
# 1127          Engineering Design  100046297      Omar Elkhatib      H
# 1441          Engineering Design  100046227     Valerie Eveloy      H
# 1488          Engineering Design  100059712   Sanjana Chandran      H
# 1506          Engineering Design  100059712   Sanjana Chandran      H
# 1510          Engineering Design  100059712   Sanjana Chandran      H
# ...                          ...        ...                ...    ...
# 37618             Nervous System  100057466     Israel Alfonso      A
# 38355    Power System Protection  100046212  Khaled Al Jaafari      A
# 40463       University Physics 2  100052467        Taha Ismail      H
# 41041  Intro to Machine Learning  100037703    Ahmed Alhammadi      A
# 41398             Linear Systems  100045794  Khalid Al Hammadi      H
#
#       STUDENT_ID                               STUDENT_NAME REG_STATUS  \
# 1127   100060408     Noura  Younis Abdulla Abbas   Alkhouri         RE
# 1441   100061255        Meera Khamis Bati Abdulla  Almheiri         RE
# 1488   100059774     Khalifa Abdalla Khalifa Salman Allahaf         RE
# 1506   100060157  Abdulla  Jasim Mohamed Abdulla   Alhosani         RE
# 1510   100059157             Rayan Ali Ahmed Ali  Alhefeiti         RE
# ...          ...                                        ...        ...
# 37618  100058299                    Abdul Rahman Walid Taha         RE
# 38355  100044948          Omar Rashed Humaid Saeed Alshamsi         RE
# 40463  100053616      Rashed  Jamal Mohamed Khamis Aldosari         RE
# 41041  100049821              Mohammad Kamal Ali Almaqadmeh         RE
# 41398  100062060                       Ahmed Refaat Elshamy         RE
#
#        TOTAL_ABSENCES  TOTAL_ATTENDED  Total Classes  Absence Percentage
# 1127              2.0             6.0            8.0                25.0
# 1441              2.0             6.0            8.0                25.0
# 1488              2.0             6.0            8.0                25.0
# 1506              3.0             5.0            8.0                37.5
# 1510              2.0             6.0            8.0                25.0
# ...               ...             ...            ...                 ...
# 37618             3.0             7.0           10.0                30.0
# 38355             3.0             5.0            8.0                37.5
# 40463             1.0             3.0            4.0                25.0
# 41041             1.0             3.0            4.0                25.0
# 41398             2.0             6.0            8.0                25.0
#
# [218 rows x 15 columns]

# %%
## write into excel; if required

## df_student_attendance_exception.to_excel("C:/Users/prabhjotsingh3/OneDrive - KPMG/Documents/2021 Projects/Khalifa University/Project/Analysis/Attendance Exception.xlsx")

# %%
df_student_attendance_exception.to_sql("Student_Attendance", eng_write)

# %% [markdown]
# # 3. Student Courses (Frequency: as per requirement - can be based on admission/registration cycle and the cool-off period for changing courses for students)

# %% [markdown]
# The below mentioned data source is imported to analyze the student courses within Khalifa University

# %%
## import master data for excel

## df_student_courses = pd.read_excel("C:/Users/prabhjotsingh3/OneDrive - KPMG/Documents/2021 Projects/Khalifa University/Project/Data/Student Course Data.xlsx")

# %%
df_student_courses
# Out:
#      TERM_CODE CAMPUS               CRS_DIVISION_NAME    CRN   CRS_ID  \
# 0       202120      A  Electrical Engr & Computer Sci  21097  ECCE221
# 1       202120      A  Electrical Engr & Computer Sci  21098  ECCE222
# 2       202120      A  Electrical Engr & Computer Sci  21113  ECCE410
# 3       202120      A  Electrical Engr & Computer Sci  21114  ECCE411
# 4       202120      A                         Physics  21128  PHYS497
# ...        ...    ...                             ...    ...      ...
# 2300    202110      A  Electrical Engr & Computer Sci  10412  ECCE221
# 2301    202110      A    Humanities & Social Sciences  10413  BUSS201
# 2302    202110      A    Humanities & Social Sciences  10414  BUSS201
# 2303    202110      A                         English  11172  ENGL102
# 2304    202110      A                         English  11173  ENGL102
#
#                         COURSE_TITLE  CREDIT_HOURS INSTRUCTOR_INDICATOR  \
# 0                Electric Circuits I           0.0              Primary
# 1               Electric Circuits II           0.0              Primary
# 2                VLSI Systems Design           3.0              Primary
# 3     Analog Integrated Circ. Design           3.0              Primary
# 4                   Senior Project I           3.0              Primary
# ...                              ...           ...                  ...
# 2300             Electric Circuits I           4.0              Primary
# 2301     Fundamentals of Acc. & Fin.           3.0              Primary
# 2302     Fundamentals of Acc. & Fin.           3.0              Primary
# 2303             Academic English II           3.0              Primary
# 2304             Academic English II           3.0              Primary
#
#       RESPONSIBILITY_PCT  CONTACT_HOURS  ... SCHEDULE_END_TIME NO_HOLD  \
# 0                    0.0            3.0  ...              1800     0.0
# 1                    0.0            3.0  ...              1700     0.0
# 2                  100.0            3.0  ...              1215     0.0
# 3                  100.0            3.0  ...              1215     0.0
# 4                   50.0            NaN  ...              None     0.0
# ...                  ...            ...  ...               ...     ...
# 2300               100.0            NaN  ...              1045     0.0
# 2301               100.0            3.0  ...              1050     0.0
# 2302               100.0            3.0  ...              0950     0.0
# 2303               100.0            3.0  ...              0915     0.0
# 2304               100.0            3.0  ...              1345     0.0
#
#      SECT_WAITLIST_MAX_ENRL MAX_ENROLLMENT_ALLOWED_CRN  \
# 0                       0.0                       18.0
# 1                       0.0                       18.0
# 2                       0.0                       30.0
# 3                       0.0                       30.0
# 4                       0.0                       24.0
# ...                     ...                        ...
# 2300                    0.0                       25.0
# 2301                    0.0                       36.0
# 2302                    0.0                       36.0
# 2303                    0.0                       24.0
# 2304                    0.0                       24.0
#
#      NBR_REGISTERED_STUDENTS_CRN   SUN   MON   TUE   WED   THU
# 0                           17.0  None  None  None  None  None
# 1                           18.0  None  None  None     Y  None
# 2                           13.0  None     Y  None     Y  None
# 3                           10.0  None  None     Y  None  None
# 4                            1.0  None  None  None  None  None
# ...                          ...   ...   ...   ...   ...   ...
# 2300                        24.0  None     Y  None     Y  None
# 2301                        33.0     Y  None     Y  None  None
# 2302                        18.0     Y  None     Y  None  None
# 2303                        23.0  None     Y  None     Y  None
# 2304                        16.0  None     Y  None     Y  None
#
# [2305 rows x 33 columns]

# %% [markdown]
# ## 3.1 Student Max Enrollment

# %% [markdown]
# Each course in Khalifa University has a maximum alloted number of students based on classroom size and in compliance with CAA standards to maintain student to faculty ratio.
#
# As per the below analysis, we identified the maximum number of students as per a course (MAX_ENROLLMENT_ALLOWED_CRN) versus the number of students registered (NBR_REGISTERED_CRN) for the semester.
#
# All exceptions are noted and identified
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b>(Maximum number of students enrolled in a CRN) - (Number of students registered in a CRN); Highlight all exceptions</div>

# %%
df_student_courses['Above Max Enrollment'] = df_student_courses['MAX_ENROLLMENT_ALLOWED_CRN'] - df_student_courses['NBR_REGISTERED_STUDENTS_CRN']

# %%
df_student_courses_max = df_student_courses[df_student_courses['Above Max Enrollment'] <0]

# %%
df_student_courses_max
# Out:
#      TERM_CODE CAMPUS             CRS_DIVISION_NAME    CRN   CRS_ID  \
# 37      202110      A                 Arts& Science  11367  SCIE795
# 55      202120      A        Mechanical Engineering  20381  MEEN435
# 59      202120      H                     Chemistry  20390  CHEM115
# 60      202120      H                     Chemistry  20390  CHEM115
# 66      202120      H                     Chemistry  20396  CHEM115
# ...        ...    ...                           ...    ...      ...
# 2218    202110      A                          Math  10150  MATH111
# 2219    202110      A                          Math  10151  MATH111
# 2230    202110      A  Humanities & Social Sciences  10532  HUMA101
# 2273    202110      A        Biomedical Engineering  10383  BMED351
# 2281    202110      A  Humanities & Social Sciences  11146  HUMA101
#
#                         COURSE_TITLE  CREDIT_HOURS INSTRUCTOR_INDICATOR  \
# 37    PhD Written Qualifying Examina           0.0              Primary
# 55                    Turbomachinery           3.0              Primary
# 59               General Chemistry I           4.0              Primary
# 60               General Chemistry I           4.0              Primary
# 66               General Chemistry I           4.0              Primary
# ...                              ...           ...                  ...
# 2218                      Calculus I           4.0              Primary
# 2219                      Calculus I           4.0              Primary
# 2230                 Arabic Language           3.0              Primary
# 2273   Biomedical Circuits & Signals           4.0              Primary
# 2281                 Arabic Language           3.0              Primary
#
#       RESPONSIBILITY_PCT  CONTACT_HOURS  ... NO_HOLD SECT_WAITLIST_MAX_ENRL  \
# 37                 100.0            0.0  ...     0.0                    0.0
# 55                 100.0            3.0  ...     0.0                    0.0
# 59                 100.0            3.0  ...     0.0                    0.0
# 60                 100.0            3.0  ...     0.0                    0.0
# 66                 100.0            NaN  ...     0.0                    0.0
# ...                  ...            ...  ...     ...                    ...
# 2218               100.0            4.0  ...     0.0                    0.0
# 2219               100.0            4.0  ...     0.0                    0.0
# 2230               100.0            3.0  ...     0.0                    0.0
# 2273               100.0            6.0  ...     0.0                    0.0
# 2281               100.0            3.0  ...     0.0                    0.0
#
#      MAX_ENROLLMENT_ALLOWED_CRN NBR_REGISTERED_STUDENTS_CRN   SUN   MON   TUE  \
# 37                          2.0                         4.0  None  None  None
# 55                         35.0                        36.0  None     Y  None
# 59                         30.0                        36.0  None     Y  None
# 60                         30.0                        36.0  None     Y  None
# 66                         30.0                        36.0  None     Y  None
# ...                         ...                         ...   ...   ...   ...
# 2218                       30.0                        38.0     Y     Y     Y
# 2219                       30.0                        38.0     Y     Y     Y
# 2230                       30.0                        37.0     Y  None     Y
# 2273                       25.0                        27.0  None     Y  None
# 2281                       40.0                        49.0     Y  None     Y
#
#        WED   THU  Above Max Enrollment
# 37    None  None                  -2.0
# 55       Y  None                  -1.0
# 59       Y  None                  -6.0
# 60    None  None                  -6.0
# 66       Y  None                  -6.0
# ...    ...   ...                   ...
# 2218     Y  None                  -8.0
# 2219     Y  None                  -8.0
# 2230  None  None                  -7.0
# 2273     Y  None                  -2.0
# 2281  None  None                  -9.0
#
# [295 rows x 34 columns]

# %%
## write into excel; if required

## df_student_courses_max.to_excel('C:/Users/prabhjotsingh3/OneDrive - KPMG/Documents/2021 Projects/Khalifa University/Project/Analysis/Above Max Enrollment.xlsx')

# %%
df_student_courses_max.to_sql("Above_Max_Courses", eng_write)

# %% [markdown]
# ## 3.2 Scheduling of Courses

# %% [markdown]
# The below code analyzes the student courses schedule the same instructor / instructors during the same slot on multiple different days / periods. However, on analysis the output below showcases due to the multiple instructors assigned for each individual course, the exceptions are not valid.
#
# As a recommendation, the output should be analyzed prior to reporting instances.

# %%
df_student_courses_exception = df_student_courses[(df_student_courses.duplicated(['INSTRUCTOR_NAME','SCHEDULE_START_TIME','SCHEDULE_END_TIME','SUN']) | 
                                                                    df_student_courses.duplicated(['INSTRUCTOR_NAME','SCHEDULE_START_TIME','SCHEDULE_END_TIME','MON']) |
                                                                    df_student_courses.duplicated(['INSTRUCTOR_NAME','SCHEDULE_START_TIME','SCHEDULE_END_TIME','TUE']) |
                                                                    df_student_courses.duplicated(['INSTRUCTOR_NAME','SCHEDULE_START_TIME','SCHEDULE_END_TIME','WED']) |
                                                                    df_student_courses.duplicated(['INSTRUCTOR_NAME','SCHEDULE_START_TIME','SCHEDULE_END_TIME','THU']))
                                                                    & df_student_courses['SUN'].notna()]

# %%
df_student_courses_exception
# Out:
#      TERM_CODE CAMPUS               CRS_DIVISION_NAME    CRN   CRS_ID  \
# 956     202110      A                            PREP  10894  STEM002
# 965     202110      A                            PREP  10895  STEM002
# 1023    202110      A                            PREP  10901  ENGL002
# 1031    202110      A                            PREP  11281  STEM002
# 1037    202110      A                            PREP  11281  STEM002
# ...        ...    ...                             ...    ...      ...
# 2258    202110      A                         Physics  10164  PHYS121
# 2274    202110      A          Biomedical Engineering  10384  BMED351
# 2294    202110      A  Electrical Engr & Computer Sci  10405  ECCE210
# 2298    202110      A  Electrical Engr & Computer Sci  10409  ECCE210
# 2301    202110      A    Humanities & Social Sciences  10413  BUSS201
#
#                        COURSE_TITLE  CREDIT_HOURS INSTRUCTOR_INDICATOR  \
# 956                          STEM 2          12.0              Primary
# 965                          STEM 2          12.0              Primary
# 1023          Preparatory English 2          14.0              Primary
# 1031                         STEM 2          12.0              Primary
# 1037                         STEM 2          12.0              Primary
# ...                             ...           ...                  ...
# 2258           University Physics 1           0.0              Primary
# 2274  Biomedical Circuits & Signals           0.0              Primary
# 2294           Digital Logic Design           4.0              Primary
# 2298           Digital Logic Design           0.0              Primary
# 2301    Fundamentals of Acc. & Fin.           3.0              Primary
#
#       RESPONSIBILITY_PCT  CONTACT_HOURS  ... NO_HOLD SECT_WAITLIST_MAX_ENRL  \
# 956                100.0            8.0  ...     0.0                    0.0
# 965                100.0            8.0  ...     0.0                    0.0
# 1023                70.0           14.0  ...     0.0                    0.0
# 1031               100.0            8.0  ...     0.0                    0.0
# 1037               100.0            8.0  ...     0.0                    0.0
# ...                  ...            ...  ...     ...                    ...
# 2258                 0.0            5.0  ...     0.0                    0.0
# 2274                 0.0            3.0  ...     0.0                    0.0
# 2294               100.0            NaN  ...     0.0                    0.0
# 2298                 0.0            NaN  ...     0.0                    0.0
# 2301               100.0            3.0  ...     0.0                    0.0
#
#      MAX_ENROLLMENT_ALLOWED_CRN NBR_REGISTERED_STUDENTS_CRN SUN   MON   TUE  \
# 956                        35.0                        35.0   Y  None  None
# 965                        35.0                        35.0   Y  None  None
# 1023                       24.0                        22.0   Y  None     Y
# 1031                       30.0                        30.0   Y  None  None
# 1037                       30.0                        30.0   Y  None  None
# ...                         ...                         ...  ..   ...   ...
# 2258                       24.0                        22.0   Y  None  None
# 2274                       25.0                        17.0   Y  None  None
# 2294                       25.0                        24.0   Y  None     Y
# 2298                       19.0                        16.0   Y  None  None
# 2301                       36.0                        33.0   Y  None     Y
#
#        WED   THU  Above Max Enrollment
# 956   None  None                   0.0
# 965   None  None                   0.0
# 1023  None  None                   2.0
# 1031     Y  None                   0.0
# 1037  None  None                   0.0
# ...    ...   ...                   ...
# 2258  None  None                   2.0
# 2274  None  None                   8.0
# 2294  None  None                   1.0
# 2298  None  None                   3.0
# 2301  None  None                   3.0
#
# [146 rows x 34 columns]

# %%
## write into excel; if required

## df_student_courses_schedule_exception.to_excel("C:/Users/prabhjotsingh3/OneDrive - KPMG/Documents/2021 Projects/Khalifa University/Project/Analysis/Student Courses.xlsx")

# %%
df_student_courses_exception.to_sql("Duplicate_Course_Schedule", eng_write)

# %% [markdown]
# # 4. Human Resources (Frequency: as per requirement - weekly, monthy or annually)

# %% [markdown]
# The below code analyzes the duplicate employee accounts, emirates ID, employee leaves, bank details and missing information for employees. For each analysis the scripts generate different outputs stored as multiple links. Below are the in-built logic drivers:
#
# 1. Employee accounts - duplicates identified based on employee number and person ID
# 2. Employee leaves - identify all types of leaves availed for more than 60 day period. The output should be analyzed for consistency as maternity leave can vary
# 3. Bank details - duplicate bank details / incorrect bank details for employees are highlighted
# 4. Missing information - key missing information across the HR data is highlighted such as emirates id, contract date etc. for active employees as per the data source
# 5. Contract date - to analyze if any active employees are working in Khalifa University without valid contracts

# %%
## import master data for excel

## df_employee_master = pd.read_excel("C:/Users/prabhjotsingh3/OneDrive - KPMG/Documents/2021 Projects/Khalifa University/Project/Data/HR Master Data.xlsx")

# %%
df_employee_master
# Out:
#           EmpNo  PersonID                 EmployeeName  \
# 0     100043305  308866.0  Shaima Ahmad Abdulaziz Ahli
# 1     100046247  309197.0                Chong Un Pyon
# 2     100046248  309466.0                  Ayoung Sohn
# 3     100049466  778886.0               Akihide Hidaka
# 4     100049994  819498.0            Riyazdheen Kaffar
# ...         ...       ...                          ...
# 1259     PI4182  625335.0     Sawsan Hussain Mohammadi
# 1260     PI4204  625079.0              Basem Al Shaabi
# 1261     PI4223  624922.0      Ayesha Abdulla Al Zaabi
# 1262     PI4227  625073.0            Abdulla Al Hosani
# 1263     PI4283  625006.0              Salem Al Jaberi
#
#                   EmployeeArabicName              Position     PositionName  \
# 0        شيماء   احمد عبدالعزيز اهلى         STAFF.2020208            STAFF
# 1                   تشونج اون   بيون  Adjunct Faculty.1062  Adjunct Faculty
# 2                       ايونج   سوهن  Adjunct Faculty.1061  Adjunct Faculty
# 3                   أكيهايد   هيديكا   Adjunct Faculty.878  Adjunct Faculty
# 4                     رياضدين   كفار           Driver.5042           Driver
# ...                              ...                   ...              ...
# 1259               سوسن حسين   محمدي         STAFF.2020263            STAFF
# 1260          باسم سيف محمد   الشعبي         STAFF.2020058            STAFF
# 1261    عائشة عبدالله سليمان الزعابي         STAFF.2020097            STAFF
# 1262  عبدالله سليمان عبدالله الحوسني         STAFF.2020098            STAFF
# 1263         سالم منيف  سالم الجابري         STAFF.2020060            STAFF
#
#      PositionCode       PositionAR              Job  \
# 0         2020208             موظف       Specialist
# 1            1062  Adjunct Faculty  Adjunct Faculty
# 2            1061  Adjunct Faculty  Adjunct Faculty
# 3             878  Adjunct Faculty  Adjunct Faculty
# 4            5042             سائق           Driver
# ...           ...              ...              ...
# 1259      2020263             موظف       Specialist
# 1260      2020058             موظف       Specialist
# 1261      2020097             موظف       Specialist
# 1262      2020098             موظف       Specialist
# 1263      2020060             موظف       Specialist
#
#                                              OrgUnit  ...  \
# 0            Off Chart - Marketing and Communication  ...
# 1                     Humanities and Social Sciences  ...
# 2                     Humanities and Social Sciences  ...
# 3                      Nuclear Engineering Institute  ...
# 4              College of Medicine & Health Sciences  ...
# ...                                              ...  ...
# 1259  Off Chart - Administration, Facilities and EHS  ...
# 1260       Off Chart - Academic and Student Services  ...
# 1261  Off Chart - Administration, Facilities and EHS  ...
# 1262  Off Chart - Administration, Facilities and EHS  ...
# 1263       Off Chart - Academic and Student Services  ...
#
#                                  Department  \
# 0               Marketing and Communication
# 1            Humanities and Social Sciences
# 2            Humanities and Social Sciences
# 3             Nuclear Engineering Institute
# 4     College of Medicine & Health Sciences
# ...                                     ...
# 1259     Administration, Facilities and EHS
# 1260          Academic and Student Services
# 1261     Administration, Facilities and EHS
# 1262     Administration, Facilities and EHS
# 1263          Academic and Student Services
#
#                                            DepartmentAR  \
# 0                                إدارة التسويق والاتصال
# 1                          العلوم الإنسانية والإجتماعية
# 2                          العلوم الإنسانية والإجتماعية
# 3                                       الهندسة النووية
# 4                                             كلية الطب
# ...                                                 ...
# 1259  إدارة  الشؤون الإدارية والمرافق ، البيئة و الص...
# 1260                  قطاع الخدمات الطلابية والاكاديميه
# 1261  إدارة  الشؤون الإدارية والمرافق ، البيئة و الص...
# 1262  إدارة  الشؤون الإدارية والمرافق ، البيئة و الص...
# 1263                  قطاع الخدمات الطلابية والاكاديميه
#
#                                     Division  \
# 0     Office of the Executive Vice President
# 1                College of Arts and Science
# 2                College of Arts and Science
# 3                     College of Engineering
# 4      College of Medicine & Health Sciences
# ...                                      ...
# 1259      Administration, Facilities and EHS
# 1260           Academic and Student Services
# 1261      Administration, Facilities and EHS
# 1262      Administration, Facilities and EHS
# 1263           Academic and Student Services
#
#                                              DivisionAR  \
# 0                             مكتب نائب الرئيس التنفيذي
# 1                                  كلية الاداب و العلوم
# 2                                  كلية الاداب و العلوم
# 3                                          كلية الهندسة
# 4                                             كلية الطب
# ...                                                 ...
# 1259  إدارة  الشؤون الإدارية والمرافق ، البيئة و الص...
# 1260                  قطاع الخدمات الطلابية والاكاديميه
# 1261  إدارة  الشؤون الإدارية والمرافق ، البيئة و الص...
# 1262  إدارة  الشؤون الإدارية والمرافق ، البيئة و الص...
# 1263                  قطاع الخدمات الطلابية والاكاديميه
#
#                              Sector                           SectorAR  \
# 0                  President Office                        مكتب الرئيس
# 1                   Academic Sector                   القطاع الأكاديمي
# 2                   Academic Sector                   القطاع الأكاديمي
# 3                   Academic Sector                   القطاع الأكاديمي
# 4                   Academic Sector                   القطاع الأكاديمي
# ...                             ...                                ...
# 1259    Executive Management Sector                               None
# 1260  Academic and Student Services  قطاع الخدمات الطلابية والاكاديميه
# 1261    Executive Management Sector                               None
# 1262    Executive Management Sector                               None
# 1263  Academic and Student Services  قطاع الخدمات الطلابية والاكاديميه
#
#                                     College   VPID  \
# 0                                      None  KU100
# 1               College of Arts and Science  KU103
# 2               College of Arts and Science  KU103
# 3                    College of Engineering  KU218
# 4     College of Medicine & Health Sciences  KU104
# ...                                     ...    ...
# 1259                                   None  KU947
# 1260                                   None  KU105
# 1261                                   None  KU947
# 1262                                   None  KU947
# 1263                                   None  KU105
#
#                              VPName Contract_End
# 0            Arif Sultan Al Hammadi  31-Dec-2021
# 1                     David Sheehan  31-Dec-2022
# 2                     David Sheehan  31-Dec-2022
# 3                Hassan Reda Barada  31-May-2022
# 4                  John Aubrey Rock         None
# ...                             ...          ...
# 1259  Adnan Jasem Yaqoob AlMansoori  31-Dec-2021
# 1260               Ahmed Al Shoaibi  31-Dec-2021
# 1261  Adnan Jasem Yaqoob AlMansoori  31-Dec-2021
# 1262  Adnan Jasem Yaqoob AlMansoori  31-Dec-2021
# 1263               Ahmed Al Shoaibi  31-Dec-2021
#
# [1264 rows x 44 columns]

# %% [markdown]
# ## 4.1 Duplicate Emirates ID

# %%
df_employee_EmiratesID = df_employee_master[df_employee_master.duplicated(['EmiratesID'])]

# %%
df_employee_EmiratesID
# Out:
#         EmpNo   PersonID                    EmployeeName  \
# 68     KU1058  1563659.0                 Nurlan Akhmetov
# 69     KU1059  1563078.0                  Michael Hughes
# 72     KU1061  1563115.0  Alessandro Giacomo Maria Gardi
# 602  KU500358  1541516.0             Deepa Kishor Dumbre
# 638  KU500435  1563750.0                     Israr Uddin
# 677  KU500493  1515591.0              Brian David Campos
# 753  KU500582  1556097.0                     Pawan Verma
# 758  KU500589  1555266.0                  Bhivraj Suthar
# 766  KU500597  1563092.0                  Mariyam Khalid
# 770  KU500601  1555283.0                     Abdul Latif
# 771  KU500602  1562400.0               Praveen Managutti
# 772  KU500603  1562393.0           Muzafar Ahmad Kanjwal
# 773  KU500604  1563128.0            Eswara Vara Komarala
# 774  KU500606  1568397.0          Eyachew Misganew Tegaw
# 779  KU500611  1565396.0         Shambhu Bhandari Sharma
# 781  KU500613  1563119.0                Ahmed Sami Adila
# 782  KU500614  1567279.0                Ali Ahmed Siddig
# 783  KU500615  1566099.0            Jabir Ubaid Parakkal
# 784  KU500616  1566056.0                    Rajesh Madhu
# 787  KU500619  1565938.0             Layla Mahmoud Saleh
# 788  KU500620  1567280.0                   Harish Ramesh
# 789  KU500622  1568387.0       Elise Michelle Harrington
# 790  KU500623  1568353.0                Tamara Milosevic
# 791  KU500624  1568582.0            Hans Leo F Huybrighs
#
#           EmployeeArabicName                      Position  \
# 68           نورلان   احمدوف   CORE Lab Specialist.1010972
# 69             مايكل    هيوز             Professor.1011033
# 72       أليساندرو   ا غاردي   Assistant Professor.1011079
# 602      ديبا  كيشور   دومبر       Research Scientist.3823
# 638            إصرار   الدين     Post Doctoral Fellow.3929
# 677     بريان دافيد   كامبوس       Research Associate.3796
# 753            باوان   فيرما     Post Doctoral Fellow.4320
# 758         بهيفراج    سوثار  Post Doctoral Fellow.8800119
# 766              مريم   خالد  Post Doctoral Fellow.8800117
# 770              عبد   الطيف       Research Associate.4203
# 771        برافين   ماناجوتى     Post Doctoral Fellow.4414
# 772       مظفر احمد   كنجوال       Research Scientist.3821
# 773       إسوارا    كومارالا     Post Doctoral Fellow.3958
# 774    اياكو ميسجانيو  تيجاو     Post Doctoral Fellow.4405
# 779            شامبو   شارما       Research Associate.4192
# 781            احمد    عديله       Research Associate.4217
# 782         على  احمد   صديق     Post Doctoral Fellow.4103
# 783       جابر عبيد  باراكال  Post Doctoral Fellow.8800141
# 784            راجيش   مادهو       Research Scientist.3916
# 787              ليلا   صالح  Post Doctoral Fellow.8800122
# 788                هاريش   .     Post Doctoral Fellow.4398
# 789  ايليس ميشيلى  هارينجتون       Research Associate.4199
# 790       تامارا    ميلوسيفك        Research Engineer.4357
# 791          هانس   هيوبريغز     Post Doctoral Fellow.4399
#
#              PositionName PositionCode               PositionAR  \
# 68    CORE Lab Specialist      1010972            اخصائي مختبر
# 69              Professor      1011033              استاذ جامعي
# 72    Assistant Professor      1011079        أستاذ جامعي مساعد
# 602    Research Scientist         3823                باحث علمي
# 638  Post Doctoral Fellow         3929  زمالة ما بعد الدكتوراه
# 677    Research Associate         3796               باحث مشارك
# 753  Post Doctoral Fellow         4320  زمالة ما بعد الدكتوراه
# 758  Post Doctoral Fellow      8800119  زمالة ما بعد الدكتوراه
# 766  Post Doctoral Fellow      8800117  زمالة ما بعد الدكتوراه
# 770    Research Associate         4203               باحث مشارك
# 771  Post Doctoral Fellow         4414  زمالة ما بعد الدكتوراه
# 772    Research Scientist         3821                باحث علمي
# 773  Post Doctoral Fellow         3958  زمالة ما بعد الدكتوراه
# 774  Post Doctoral Fellow         4405  زمالة ما بعد الدكتوراه
# 779    Research Associate         4192               باحث مشارك
# 781    Research Associate         4217               باحث مشارك
# 782  Post Doctoral Fellow         4103  زمالة ما بعد الدكتوراه
# 783  Post Doctoral Fellow      8800141  زمالة ما بعد الدكتوراه
# 784    Research Scientist         3916                باحث علمي
# 787  Post Doctoral Fellow      8800122  زمالة ما بعد الدكتوراه
# 788  Post Doctoral Fellow         4398  زمالة ما بعد الدكتوراه
# 789    Research Associate         4199               باحث مشارك
# 790     Research Engineer         4357               مهندس باحث
# 791  Post Doctoral Fellow         4399  زمالة ما بعد الدكتوراه
#
#                       Job                        OrgUnit  ...  \
# 68             Specialist                 ACBC Core Labs  ...
# 69              Professor         Biomedical Engineering  ...
# 72    Assistant Professor          Aerospace Engineering  ...
# 602    Research Scientist  Temp Researcher Internal Fund  ...
# 638  Post Doctoral Fellow  Temp Researcher External Fund  ...
# 677    Research Associate  Temp Researcher Internal Fund  ...
# 753  Post Doctoral Fellow  Temp Researcher External Fund  ...
# 758  Post Doctoral Fellow  Temp Researcher Internal Fund  ...
# 766  Post Doctoral Fellow  Temp Researcher Internal Fund  ...
# 770    Research Associate  Temp Researcher Internal Fund  ...
# 771  Post Doctoral Fellow  Temp Researcher Internal Fund  ...
# 772    Research Scientist  Temp Researcher Internal Fund  ...
# 773  Post Doctoral Fellow  Temp Researcher Internal Fund  ...
# 774  Post Doctoral Fellow  Temp Researcher Internal Fund  ...
# 779    Research Associate  Temp Researcher Internal Fund  ...
# 781    Research Associate  Temp Researcher Internal Fund  ...
# 782  Post Doctoral Fellow  Temp Researcher External Fund  ...
# 783  Post Doctoral Fellow  Temp Researcher External Fund  ...
# 784    Research Scientist  Temp Researcher Internal Fund  ...
# 787  Post Doctoral Fellow  Temp Researcher Internal Fund  ...
# 788  Post Doctoral Fellow  Temp Researcher Internal Fund  ...
# 789    Research Associate  Temp Researcher Internal Fund  ...
# 790     Research Engineer  Temp Researcher External Fund  ...
# 791  Post Doctoral Fellow  Temp Researcher Internal Fund  ...
#
#                         Department                DepartmentAR  \
# 68           Research Laboratories              مختبرات البحوث
# 69          Biomedical Engineering      الهندسة الطبية الحيوية
# 72           Aerospace Engineering                هندسة الفضاء
# 602  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 638  Temp Researcher External Fund   الأبحاث من المنح الخارجية
# 677  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 753  Temp Researcher External Fund   الأبحاث من المنح الخارجية
# 758  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 766  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 770  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 771  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 772  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 773  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 774  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 779  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 781  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 782  Temp Researcher External Fund   الأبحاث من المنح الخارجية
# 783  Temp Researcher External Fund   الأبحاث من المنح الخارجية
# 784  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 787  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 788  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 789  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 790  Temp Researcher External Fund   الأبحاث من المنح الخارجية
# 791  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
#
#                           Division                  DivisionAR  \
# 68        Research and Development        قطاع البحوث والتطوير
# 69          College of Engineering                كلية الهندسة
# 72          College of Engineering                كلية الهندسة
# 602  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 638  Temp Researcher External Fund   الأبحاث من المنح الخارجية
# 677  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 753  Temp Researcher External Fund   الأبحاث من المنح الخارجية
# 758  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 766  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 770  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 771  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 772  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 773  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 774  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 779  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 781  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 782  Temp Researcher External Fund   الأبحاث من المنح الخارجية
# 783  Temp Researcher External Fund   الأبحاث من المنح الخارجية
# 784  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 787  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 788  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 789  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
# 790  Temp Researcher External Fund   الأبحاث من المنح الخارجية
# 791  Temp Researcher Internal Fund  الأبحات من التمويل الداخلي
#
#                        Sector              SectorAR                 College  \
# 68   Research and Development  قطاع البحوث والتطوير                    None
# 69            Academic Sector      القطاع الأكاديمي  College of Engineering
# 72            Academic Sector      القطاع الأكاديمي  College of Engineering
# 602  Research and Development  قطاع البحوث والتطوير                    None
# 638  Research and Development  قطاع البحوث والتطوير                    None
# 677  Research and Development  قطاع البحوث والتطوير                    None
# 753  Research and Development  قطاع البحوث والتطوير                    None
# 758  Research and Development  قطاع البحوث والتطوير                    None
# 766  Research and Development  قطاع البحوث والتطوير                    None
# 770  Research and Development  قطاع البحوث والتطوير                    None
# 771  Research and Development  قطاع البحوث والتطوير                    None
# 772  Research and Development  قطاع البحوث والتطوير                    None
# 773  Research and Development  قطاع البحوث والتطوير                    None
# 774  Research and Development  قطاع البحوث والتطوير                    None
# 779  Research and Development  قطاع البحوث والتطوير                    None
# 781  Research and Development  قطاع البحوث والتطوير                    None
# 782  Research and Development  قطاع البحوث والتطوير                    None
# 783  Research and Development  قطاع البحوث والتطوير                    None
# 784  Research and Development  قطاع البحوث والتطوير                    None
# 787  Research and Development  قطاع البحوث والتطوير                    None
# 788  Research and Development  قطاع البحوث والتطوير                    None
# 789  Research and Development  قطاع البحوث والتطوير                    None
# 790  Research and Development  قطاع البحوث والتطوير                    None
# 791  Research and Development  قطاع البحوث والتطوير                    None
#
#       VPID                   VPName Contract_End
# 68    None                     None  09-Jan-2025
# 69   KU218       Hassan Reda Barada  31-Dec-2024
# 72   KU218       Hassan Reda Barada  31-Dec-2024
# 602  KU106  Steven Wesley Griffiths  30-Jun-2023
# 638  KU106  Steven Wesley Griffiths  31-Dec-2022
# 677  KU106  Steven Wesley Griffiths  31-Oct-2022
# 753  KU106  Steven Wesley Griffiths  19-Jun-2022
# 758  KU106  Steven Wesley Griffiths  30-Jun-2023
# 766  KU106  Steven Wesley Griffiths  30-Jun-2023
# 770  KU106  Steven Wesley Griffiths  06-Dec-2022
# 771  KU106  Steven Wesley Griffiths  30-Jun-2024
# 772  KU106  Steven Wesley Griffiths  28-Dec-2022
# 773  KU106  Steven Wesley Griffiths  30-Jun-2023
# 774  KU106  Steven Wesley Griffiths  30-Jun-2023
# 779  KU106  Steven Wesley Griffiths  30-Jun-2022
# 781  KU106  Steven Wesley Griffiths  30-Jun-2023
# 782  KU106  Steven Wesley Griffiths  31-Aug-2023
# 783  KU106  Steven Wesley Griffiths  31-Dec-2023
# 784  KU106  Steven Wesley Griffiths  30-Jun-2023
# 787  KU106  Steven Wesley Griffiths  30-Jun-2023
# 788  KU106  Steven Wesley Griffiths  30-Jun-2024
# 789  KU106  Steven Wesley Griffiths  30-Jun-2024
# 790  KU106  Steven Wesley Griffiths  15-Jun-2023
# 791  KU106  Steven Wesley Griffiths  08-Feb-2024
#
# [24 rows x 44 columns]

# %%
## write into excel; if required 

## df_employee_EmiratesID.to_excel("C:/Users/prabhjotsingh3/OneDrive - KPMG/Documents/2021 Projects/Khalifa University/Project/Analysis/Duplicate Employeese Emirates ID.xlsx")

# %%
df_employee_master['Length'] = df_employee_master['EmiratesID'].str.len()

# %%
df_employee_EID = df_employee_master[(df_employee_master['Length'] < 15) | (df_employee_master['Length'] > 15)]

# %%
df_employee_EID
# Out:
#      EmpNo   PersonID             EmployeeName  \
# 25  KU1016  1531373.0  Hatem Samir Issa Haddad
# 63  KU1053  1562979.0    Arjen Rene' Van Vliet
# 82  KU1073  1565316.0   Amin Ahmed Babiker Ali
#
#                              EmployeeArabicName  \
# 25                          حاتم سمير عيسى حداد
# 63  أرجين رينيه فان فليت   أرجين رينيه فان فليت
# 82                        امين احمد بابكر   علي
#
#                                           Position  \
# 25  Senior Auditor, IT and Audit Analytics.1011012
# 63                     Assistant Professor.1011091
# 82                         Senior Lecturer.1050538
#
#                               PositionName PositionCode         PositionAR  \
# 25  Senior Auditor, IT and Audit Analytics      1011012          مدقق أول
# 63                     Assistant Professor      1011091  أستاذ جامعي مساعد
# 82                         Senior Lecturer      1050538          محاضر أول
#
#                     Job                  OrgUnit  ...  \
# 25    Senior Specialist                    Audit  ...
# 63  Assistant Professor                  Physics  ...
# 82      Senior Lecturer  Pre-Medicine Bridge PMO  ...
#
#                DepartmentAR                     Division  \
# 25  إدارة التدقيق والامتثال             Executive Office
# 63            علوم الفيزياء  College of Arts and Science
# 82  Pre-Medicine Bridge PMO  College of Arts and Science
#
#               DivisionAR            Sector          SectorAR  \
# 25      Executive Office  President Office       مكتب الرئيس
# 63  كلية الاداب و العلوم   Academic Sector  القطاع الأكاديمي
# 82  كلية الاداب و العلوم   Academic Sector  القطاع الأكاديمي
#
#                         College   VPID         VPName Contract_End Length
# 25                         None   None           None  07-Aug-2024     17
# 63  College of Arts and Science  KU103  David Sheehan  31-Dec-2024     17
# 82  College of Arts and Science  KU103  David Sheehan  16-Jan-2024     20
#
# [3 rows x 45 columns]

# %%
df_comparison = pd.merge(df_employee_master, df_employee_EID, on='EmiratesID', how='inner')
df_comparison.head(5)
# Out:
#   EmpNo_x  PersonID_x           EmployeeName_x  \
# 0  KU1016   1531373.0  Hatem Samir Issa Haddad
# 1  KU1053   1562979.0    Arjen Rene' Van Vliet
# 2  KU1073   1565316.0   Amin Ahmed Babiker Ali
#
#                           EmployeeArabicName_x  \
# 0                          حاتم سمير عيسى حداد
# 1  أرجين رينيه فان فليت   أرجين رينيه فان فليت
# 2                        امين احمد بابكر   علي
#
#                                        Position_x  \
# 0  Senior Auditor, IT and Audit Analytics.1011012
# 1                     Assistant Professor.1011091
# 2                         Senior Lecturer.1050538
#
#                            PositionName_x PositionCode_x       PositionAR_x  \
# 0  Senior Auditor, IT and Audit Analytics        1011012          مدقق أول
# 1                     Assistant Professor        1011091  أستاذ جامعي مساعد
# 2                         Senior Lecturer        1050538          محاضر أول
#
#                  Job_x                OrgUnit_x  ...           DepartmentAR_y  \
# 0    Senior Specialist                    Audit  ...  إدارة التدقيق والامتثال
# 1  Assistant Professor                  Physics  ...            علوم الفيزياء
# 2      Senior Lecturer  Pre-Medicine Bridge PMO  ...  Pre-Medicine Bridge PMO
#
#                     Division_y          DivisionAR_y          Sector_y  \
# 0             Executive Office      Executive Office  President Office
# 1  College of Arts and Science  كلية الاداب و العلوم   Academic Sector
# 2  College of Arts and Science  كلية الاداب و العلوم   Academic Sector
#
#          SectorAR_y                    College_y VPID_y       VPName_y  \
# 0       مكتب الرئيس                         None   None           None
# 1  القطاع الأكاديمي  College of Arts and Science  KU103  David Sheehan
# 2  القطاع الأكاديمي  College of Arts and Science  KU103  David Sheehan
#
#   Contract_End_y Length_y
# 0    07-Aug-2024       17
# 1    31-Dec-2024       17
# 2    16-Jan-2024       20
#
# [3 rows x 89 columns]

# %%
## write into excel; if required

## df_employee_EID.to_excel("C:/Users/prabhjotsingh3/OneDrive - KPMG/Documents/2021 Projects/Khalifa University/Project/Analysis/Invalid Emirates ID.xlsx")

# %% [markdown]
# ## 4.2 Employee ID

# %% [markdown]
# Employee ID are verified to ensure no two employees are under the same employee ID.
#
# For the same, pandas library is utilized to automatically find the duplicated entries within the master data on "Emp No" (Employee ID) and "PersonID" (Old Employee ID).

# %%
df_employee_employeeID = df_employee_master[df_employee_master.duplicated(['EmpNo'])]

# %%
df_employee_employeeID
# Out:
# Empty DataFrame
# Columns: [EmpNo, PersonID, EmployeeName, EmployeeArabicName, Position, PositionName, PositionCode, PositionAR, Job, OrgUnit, OrgUnitAR, Payroll, Grade, Nationality, ArCountry, NatCat, DateOfBirth, Age, EmailAddress, EmiratesID, MaritalStat, Gender, NearestAirport, Religion, Title, ORIGINALHIREDATE, HireDate, ServiceYrs, AdjustedServiceDate, SupervisorNumber, SupervisorName, AssignmentCategory, Section, SectionAR, Department, DepartmentAR, Division, DivisionAR, Sector, SectorAR, College, VPID, VPName, Contract_End, Length]
# Index: []
#
# [0 rows x 45 columns]

# %%
df_employee_personID = df_employee_master[df_employee_master.duplicated(['PersonID'])]

# %%
df_employee_personID
# Out:
# Empty DataFrame
# Columns: [EmpNo, PersonID, EmployeeName, EmployeeArabicName, Position, PositionName, PositionCode, PositionAR, Job, OrgUnit, OrgUnitAR, Payroll, Grade, Nationality, ArCountry, NatCat, DateOfBirth, Age, EmailAddress, EmiratesID, MaritalStat, Gender, NearestAirport, Religion, Title, ORIGINALHIREDATE, HireDate, ServiceYrs, AdjustedServiceDate, SupervisorNumber, SupervisorName, AssignmentCategory, Section, SectionAR, Department, DepartmentAR, Division, DivisionAR, Sector, SectorAR, College, VPID, VPName, Contract_End, Length]
# Index: []
#
# [0 rows x 45 columns]

# %% [markdown]
# ## 4.3 Contract Date

# %% [markdown]
# The below scripts analyzes the continuance of emplyoee beyond the contract period and incase any employees are active in the system beyond the contracted period.
#
# Employee master contains two columnn namely "Contract End" (end date of contract) and "HireDate" (date of joining / continuance). By analyzing the difference between the columns, all employees beyond contracted period can be analyzed.

# %%
df_employee_master['Diff'] = df_employee_master['Contract_End'] - df_employee_master['HireDate']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-a0ac1d9881d2> in <module>
# ----> 1 df_employee_master['Diff'] = df_employee_master['Contract_End'] - df_employee_master['HireDate']
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __sub__(self, other)
#      98     @unpack_zerodim_and_defer("__sub__")
#      99     def __sub__(self, other):
# --> 100         return self._arith_method(other, operator.sub)
#     101
#     102     @unpack_zerodim_and_defer("__rsub__")
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    5524
#    5525         with np.errstate(all="ignore"):
# -> 5526             result = ops.arithmetic_op(lvalues, rvalues, op)
#    5527
#    5528         return self._construct_result(result, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     216         # Timedelta/Timestamp and other custom scalars are included in the check
#     217         # because numexpr will fail on it, see GH#31457
# --> 218         res_values = op(left, right)
#     219     else:
#     220         # TODO we should handle EAs consistently and move this check before the if/else
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in __rsub__(self, other)
#    1374             # GH#19959 datetime - datetime is well-defined as timedelta,
#    1375             # but any other type - datetime is not well-defined.
# -> 1376             raise TypeError(
#    1377                 f"cannot subtract {type(self).__name__} from {type(other).__name__}"
#    1378             )
#
# TypeError: cannot subtract DatetimeArray from ndarray

# %%
df_employee_master['Diff']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-64ef9ada4368> in <module>
# ----> 1 df_employee_master['Diff']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Diff'

# %%
df_employee_contract = df_employee_master[(df_employee_master['Diff'] < '365')]

# %%
df_employee_contract
# Out:
# Empty DataFrame
# Columns: [EmpNo, PersonID, EmployeeName, EmployeeArabicName, Position, PositionName, PositionCode, PositionAR, Job, OrgUnit, OrgUnitAR, Payroll, Grade, Nationality, ArCountry, NatCat, DateOfBirth, Age, EmailAddress, EmiratesID, MaritalStat, Gender, NearestAirport, Religion, Title, HireDate, ServiceYrs, AdjustedServiceDate, SupervisorNumber, SupervisorName, AssignmentCategory, Section, SectionAR, Department, DepartmentAR, Division, DivisionAR, Sector, SectorAR, College, VPID, VPName, Contract_End, Length, Diff]
# Index: []
#
# [0 rows x 45 columns]

# %% [markdown]
# ## 4.4 Employee Leaves

# %% [markdown]
# Employee Leaves are granted on an annual basis to each employee. Below are the exceptions that can be identified for employee who have availed a leave for beyond 60 day period for any leave type, i.e., Annual Leave, Unpaid Leave etc.

# %%
#df_employee_leave = pd.read_excel("C:/Users/ku1016/Downloads/Employee Leave Data.xlsx")
df_employee_leaves.head(5)
# Out:
#   EmployeeNumber leaveCategory             LeaveType LeaveStartDate  \
# 0      100020235             V          Annual Leave     2017-08-13
# 1      100020235             S  Maternity Sick Leave     2017-05-09
# 2      100020235             S  Maternity Sick Leave     2017-04-18
# 3      100020235             V          Annual Leave     2017-03-28
# 4      100020235             V          Annual Leave     2017-03-22
#
#   LeaveEndDate  leaveduration LeaveStatus
# 0   2017-09-02           21.0           A
# 1   2017-05-11            3.0           A
# 2   2017-04-18            1.0           A
# 3   2017-03-30            3.0           A
# 4   2017-03-23            2.0           A

# %%
df_employee_leaves['Diff'] = df_employee_leaves['LeaveEndDate'] - df_employee_leaves['LeaveStartDate']
df_employee_leaves.head(5)
# Out:
#   EmployeeNumber leaveCategory             LeaveType LeaveStartDate  \
# 0      100020235             V          Annual Leave     2017-08-13
# 1      100020235             S  Maternity Sick Leave     2017-05-09
# 2      100020235             S  Maternity Sick Leave     2017-04-18
# 3      100020235             V          Annual Leave     2017-03-28
# 4      100020235             V          Annual Leave     2017-03-22
#
#   LeaveEndDate  leaveduration LeaveStatus    Diff
# 0   2017-09-02           21.0           A 20 days
# 1   2017-05-11            3.0           A  2 days
# 2   2017-04-18            1.0           A  0 days
# 3   2017-03-30            3.0           A  2 days
# 4   2017-03-23            2.0           A  1 days

# %%
df_employee_leave_exception = df_employee_leaves[(df_employee_leaves['Diff'] > '60 days')]
df_employee_leave_exception
# Out:
#       EmployeeNumber leaveCategory                  LeaveType LeaveStartDate  \
# 7          100020242             H            Maternity Leave     2017-05-17
# 321        100031378            UL  Unauthorized Unpaid Leave     2017-06-13
# 921        100035628             V  Scholarship Student Leave     2013-12-04
# 963        100035663             H            Maternity Leave     2017-11-06
# 1218       100035704             V               Annual Leave     2014-06-25
# ...              ...           ...                        ...            ...
# 44634         PI4223             H            Maternity Leave     2020-02-27
# 44656         PI4223             H            Maternity Leave     2018-05-29
# 44787         PI4349             H            Maternity Leave     2018-12-14
# 44861         PI4377            UL               Unpaid Leave     2018-04-16
# 44998         PI4418             H            Maternity Leave     2018-07-21
#
#       LeaveEndDate  leaveduration LeaveStatus    Diff
# 7       2017-08-14           90.0           A 89 days
# 321     2017-08-17           66.0           A 65 days
# 921     2014-02-05           64.0           A 63 days
# 963     2018-02-03           90.0           A 89 days
# 1218    2014-08-28           65.0           A 64 days
# ...            ...            ...         ...     ...
# 44634   2020-05-26           90.0           A 89 days
# 44656   2018-08-26           90.0           A 89 days
# 44787   2019-03-13           90.0           A 89 days
# 44861   2018-06-18           64.0           A 63 days
# 44998   2018-10-18           90.0           A 89 days
#
# [126 rows x 8 columns]

# %%
df_employee_leave_exception.to_sql("Employee_Leaves_Exception", eng_write)
# Out:
# C:\Users\ku1016\Anaconda3\lib\site-packages\pandas\io\sql.py:717: UserWarning: the 'timedelta' type is not supported, and will be written as integer values (ns frequency) to the database.
#   pandas_sql.to_sql(

# %% [markdown]
# ## 4.5 Missing Employee Information

# %% [markdown]
# All active employees should have complete information as per the HR records and protocol within the master data. The below script analyzes the missing information to ensure completeness of the data.

# %% [markdown]
# To identify the missing values, the pandas libraries for isnull() is utilized and specifies any axis (column) to target all missing values in any column.

# %%
## df_employee_master = pd.read_excel("C:/Users/ku1016/Downloads/HR Employee Data.xlsx")
## df_employee_master.head(5)
# Out:
#        EmpNo  PersonID                 EmployeeName  \
# 0  100043305    308866  Shaima Ahmad Abdulaziz Ahli
# 1  100046247    309197                Chong Un Pyon
# 2  100046248    309466                  Ayoung Sohn
# 3  100049466    778886               Akihide Hidaka
# 4  100049994    819498            Riyazdheen Kaffar
#
#             EmployeeArabicName              Position     PositionName  \
# 0  شيماء   احمد عبدالعزيز اهلى         STAFF.2020208            STAFF
# 1             تشونج اون   بيون  Adjunct Faculty.1062  Adjunct Faculty
# 2                 ايونج   سوهن  Adjunct Faculty.1061  Adjunct Faculty
# 3             أكيهايد   هيديكا   Adjunct Faculty.878  Adjunct Faculty
# 4               رياضدين   كفار           Driver.5042           Driver
#
#    PositionCode       PositionAR              Job  \
# 0       2020208             موظف       Specialist
# 1          1062  Adjunct Faculty  Adjunct Faculty
# 2          1061  Adjunct Faculty  Adjunct Faculty
# 3           878  Adjunct Faculty  Adjunct Faculty
# 4          5042             سائق           Driver
#
#                                    OrgUnit  ...  \
# 0  Off Chart - Marketing and Communication  ...
# 1           Humanities and Social Sciences  ...
# 2           Humanities and Social Sciences  ...
# 3            Nuclear Engineering Institute  ...
# 4    College of Medicine & Health Sciences  ...
#
#                               Department                  DepartmentAR  \
# 0            Marketing and Communication        إدارة التسويق والاتصال
# 1         Humanities and Social Sciences  العلوم الإنسانية والإجتماعية
# 2         Humanities and Social Sciences  العلوم الإنسانية والإجتماعية
# 3          Nuclear Engineering Institute               الهندسة النووية
# 4  College of Medicine & Health Sciences                     كلية الطب
#
#                                  Division                 DivisionAR  \
# 0  Office of the Executive Vice President  مكتب نائب الرئيس التنفيذي
# 1             College of Arts and Science       كلية الاداب و العلوم
# 2             College of Arts and Science       كلية الاداب و العلوم
# 3                  College of Engineering               كلية الهندسة
# 4   College of Medicine & Health Sciences                  كلية الطب
#
#              Sector          SectorAR                                College  \
# 0  President Office       مكتب الرئيس                                    NaN
# 1   Academic Sector  القطاع الأكاديمي            College of Arts and Science
# 2   Academic Sector  القطاع الأكاديمي            College of Arts and Science
# 3   Academic Sector  القطاع الأكاديمي                 College of Engineering
# 4   Academic Sector  القطاع الأكاديمي  College of Medicine & Health Sciences
#
#     VPID                  VPName Contract_End
# 0  KU100  Arif Sultan Al Hammadi   2021-12-31
# 1  KU103           David Sheehan   2021-12-31
# 2  KU103           David Sheehan   2021-12-31
# 3  KU218      Hassan Reda Barada   2021-12-21
# 4  KU104        John Aubrey Rock          NaT
#
# [5 rows x 43 columns]

# %%
df_employee_master.isnull()
# Out:
#       EmpNo  PersonID  EmployeeName  EmployeeArabicName  Position  \
# 0     False     False         False               False     False
# 1     False     False         False               False     False
# 2     False     False         False               False     False
# 3     False     False         False               False     False
# 4     False     False         False               False     False
# ...     ...       ...           ...                 ...       ...
# 1259  False     False         False               False     False
# 1260  False     False         False               False     False
# 1261  False     False         False               False     False
# 1262  False     False         False               False     False
# 1263  False     False         False               False     False
#
#       PositionName  PositionCode  PositionAR    Job  OrgUnit  ...  \
# 0            False         False       False  False    False  ...
# 1            False         False       False  False    False  ...
# 2            False         False       False  False    False  ...
# 3            False         False       False  False    False  ...
# 4            False         False       False  False    False  ...
# ...            ...           ...         ...    ...      ...  ...
# 1259         False         False       False  False    False  ...
# 1260         False         False       False  False    False  ...
# 1261         False         False       False  False    False  ...
# 1262         False         False       False  False    False  ...
# 1263         False         False       False  False    False  ...
#
#       DepartmentAR  Division  DivisionAR  Sector  SectorAR  College   VPID  \
# 0            False     False       False   False     False     True  False
# 1            False     False       False   False     False    False  False
# 2            False     False       False   False     False    False  False
# 3            False     False       False   False     False    False  False
# 4            False     False       False   False     False    False  False
# ...            ...       ...         ...     ...       ...      ...    ...
# 1259         False     False       False   False      True     True  False
# 1260         False     False       False   False     False     True  False
# 1261         False     False       False   False      True     True  False
# 1262         False     False       False   False      True     True  False
# 1263         False     False       False   False     False     True  False
#
#       VPName  Contract_End  Length
# 0      False         False   False
# 1      False         False   False
# 2      False         False   False
# 3      False         False   False
# 4      False          True   False
# ...      ...           ...     ...
# 1259   False         False   False
# 1260   False         False   False
# 1261   False         False   False
# 1262   False         False   False
# 1263   False         False   False
#
# [1264 rows x 45 columns]

# %%
df_employee_missing = df_employee_master[df_employee_master.isnull().any(axis=1)]
df_employee_missing.head(5)
# Out:
#        EmpNo  PersonID                 EmployeeName  \
# 0  100043305  308866.0  Shaima Ahmad Abdulaziz Ahli
# 1  100046247  309197.0                Chong Un Pyon
# 2  100046248  309466.0                  Ayoung Sohn
# 3  100049466  778886.0               Akihide Hidaka
# 4  100049994  819498.0            Riyazdheen Kaffar
#
#             EmployeeArabicName              Position     PositionName  \
# 0  شيماء   احمد عبدالعزيز اهلى         STAFF.2020208            STAFF
# 1             تشونج اون   بيون  Adjunct Faculty.1062  Adjunct Faculty
# 2                 ايونج   سوهن  Adjunct Faculty.1061  Adjunct Faculty
# 3             أكيهايد   هيديكا   Adjunct Faculty.878  Adjunct Faculty
# 4               رياضدين   كفار           Driver.5042           Driver
#
#   PositionCode       PositionAR              Job  \
# 0      2020208             موظف       Specialist
# 1         1062  Adjunct Faculty  Adjunct Faculty
# 2         1061  Adjunct Faculty  Adjunct Faculty
# 3          878  Adjunct Faculty  Adjunct Faculty
# 4         5042             سائق           Driver
#
#                                    OrgUnit  ...                  DepartmentAR  \
# 0  Off Chart - Marketing and Communication  ...        إدارة التسويق والاتصال
# 1           Humanities and Social Sciences  ...  العلوم الإنسانية والإجتماعية
# 2           Humanities and Social Sciences  ...  العلوم الإنسانية والإجتماعية
# 3            Nuclear Engineering Institute  ...               الهندسة النووية
# 4    College of Medicine & Health Sciences  ...                     كلية الطب
#
#                                  Division                 DivisionAR  \
# 0  Office of the Executive Vice President  مكتب نائب الرئيس التنفيذي
# 1             College of Arts and Science       كلية الاداب و العلوم
# 2             College of Arts and Science       كلية الاداب و العلوم
# 3                  College of Engineering               كلية الهندسة
# 4   College of Medicine & Health Sciences                  كلية الطب
#
#              Sector          SectorAR                                College  \
# 0  President Office       مكتب الرئيس                                   None
# 1   Academic Sector  القطاع الأكاديمي            College of Arts and Science
# 2   Academic Sector  القطاع الأكاديمي            College of Arts and Science
# 3   Academic Sector  القطاع الأكاديمي                 College of Engineering
# 4   Academic Sector  القطاع الأكاديمي  College of Medicine & Health Sciences
#
#     VPID                  VPName Contract_End Length
# 0  KU100  Arif Sultan Al Hammadi  31-Dec-2021     15
# 1  KU103           David Sheehan  31-Dec-2022     15
# 2  KU103           David Sheehan  31-Dec-2022     15
# 3  KU218      Hassan Reda Barada  31-May-2022     15
# 4  KU104        John Aubrey Rock         None     15
#
# [5 rows x 45 columns]

# %%
df_employee_missing.to_sql("Missing_employee_info",eng_write)

# %% [markdown]
# ## 4.6 Employee bank details and account number

# %% [markdown]
# For any bank details, no two employees can share the same bank details and the length of IBAN should remain constant number of digits as per the international IBAN standards (23 digits).
#
# Below are the scripts to analyze both scenarios.

# %%
## df_employee_bank_details = pd.read_excel("C:/users/ku1016/downloads/Employee Bank Details.xlsx")

# %%
## df_employee_bank_details.head(5)
# Out:
#    PERSONID                BANKSTARTDATE                  BANKENDDATE  \
# 0    308657  2016-05-01 00:00:00.0000000  2016-12-31 00:00:00.0000000
# 1    635927  2017-12-31 00:00:00.0000000  2017-12-31 00:00:00.0000000
# 2    635999  2017-12-31 00:00:00.0000000  2017-12-31 00:00:00.0000000
# 3    636017  2017-12-31 00:00:00.0000000  2017-12-31 00:00:00.0000000
# 4    635983  2017-12-31 00:00:00.0000000  2017-12-31 00:00:00.0000000
#
#   BANKPRIORITY EMPLOYEENUMBER      ORG_PAYMENT_METHOD   BANKID       BANKNAME  \
# 0                   100036842  KUK Bank Transfer - KU  70617.0  AL HILAL BANK
# 1                    KU500095  KUK Bank Transfer - KU      NaN            NaN
# 2                    KU500183  KUK Bank Transfer - KU      NaN            NaN
# 3                    KU500082  KUK Bank Transfer - KU      NaN            NaN
# 4                    KU500078  KUK Bank Transfer - KU      NaN            NaN
#
#   BRANCHNAME IBAN  Length of EID  ACCOUNTNO  CREATEDBY  LASTUPDATEDBY  \
# 0        NaN   AE              2        NaN      60850          62647
# 1        NaN   AE              2        NaN          0         188569
# 2        NaN   AE              2        NaN          0         188569
# 3        NaN   AE              2        NaN          0         188569
# 4        NaN   AE              2        NaN          0         188569
#
#                 LASTUPDATEDATE          LASTUPDATEDATE1
# 0  2017-01-21 14:38:25.0000000  2021-12-12 23:32:19.930
# 1  2018-03-05 11:08:36.0000000  2021-12-12 23:32:19.930
# 2  2018-03-05 11:09:51.0000000  2021-12-12 23:32:19.930
# 3  2018-03-05 11:11:43.0000000  2021-12-12 23:32:19.930
# 4  2018-03-05 11:12:46.0000000  2021-12-12 23:32:19.930

# %%
df_employee_bank_details_duplicated = df_employee_bank_details[df_employee_bank_details.duplicated(['IBAN'])]

# %%
df_employee_bank_details_duplicated.to_sql("Duplicatee_employee_bank", eng_write)

# %%
df_employee_bank_details['Length of IBAN'] = df_employee_bank_details['IBAN'].str.len()
df_employee_bank_details.head(5)
# Out:
#     PERSONID BANKSTARTDATE          BANKENDDATE BANKPRIORITY EMPLOYEENUMBER  \
# 0  1482073.0    2020-12-15  4712-12-31 00:00:00                   100058647
# 1   635927.0    2017-12-31  2017-12-31 00:00:00                    KU500095
# 2   635999.0    2017-12-31  2017-12-31 00:00:00                    KU500183
# 3   636017.0    2017-12-31  2017-12-31 00:00:00                    KU500082
# 4   635983.0    2017-12-31  2017-12-31 00:00:00                    KU500078
#
#        ORG_PAYMENT_METHOD BANKID BANKNAME BRANCHNAME  IBAN ACCOUNTNO  \
# 0  KUK Bank Transfer - KU   None     None       None  None      None
# 1  KUK Bank Transfer - KU   None     None       None    AE      None
# 2  KUK Bank Transfer - KU   None     None       None    AE      None
# 3  KUK Bank Transfer - KU   None     None       None    AE      None
# 4  KUK Bank Transfer - KU   None     None       None    AE      None
#
#    CREATEDBY  LASTUPDATEDBY      LASTUPDATEDATE         LASTUPDATEDATE1  \
# 0   188488.0       188488.0 2020-12-15 07:31:13 2022-02-13 23:31:18.187
# 1        0.0       188569.0 2018-03-05 11:08:36 2022-02-13 23:31:18.187
# 2        0.0       188569.0 2018-03-05 11:09:51 2022-02-13 23:31:18.187
# 3        0.0       188569.0 2018-03-05 11:11:43 2022-02-13 23:31:18.187
# 4        0.0       188569.0 2018-03-05 11:12:46 2022-02-13 23:31:18.187
#
#    Length of IBAN
# 0             NaN
# 1             2.0
# 2             2.0
# 3             2.0
# 4             2.0

# %%
df_employee_bank_details_length = df_employee_bank_details[(df_employee_bank_details['Length of IBAN']<23)]

# %%
df_employee_bank_details_length.to_sql("Incorrect_employee_IBAN", eng_write)

# %% [markdown]
# # Finance and Procurement (Frequency: as per requirements - weekly, monthly or annually)

# %% [markdown]
# ## 5.1 Supplier Master Analysis

# %% [markdown]
# The following are analyzed for the supplier master:
#
# - Duplicate supplier codes for the same supplier
# - Duplicate bank details for different suppliers
# - Duplicate TRN (Tax registration number) for different suppliers

# %%
## df_supplier_master = pd.read_excel("C:/users/ku1016/downloads/Supplier Master.xlsx")
## df_supplier_master.head(5)
# Out:
#                                       OPERATING_UNIT REGISTER_MODE  \
# 0  KUST Khalifa University of Science and Technol...        Manual
# 1              KUX - External Khalifa University O.U        Manual
# 2                  KUA - Ankabout Khalifa University        Manual
# 3                 KUJ -  Aric Khalifa University O.U        Manual
# 4                                           KUGRC OU        Manual
#
#    SUPPLIER_NO   SUP_CREATION_DATE SUPPLIER_INACTIVE_DATE  \
# 0            1 2010-06-01 19:12:48                    NaT
# 1            1 2010-06-01 19:12:48                    NaT
# 2            1 2010-06-01 19:12:48                    NaT
# 3            1 2010-06-01 19:12:48                    NaT
# 4            1 2010-06-01 19:12:48                    NaT
#
#                                  SUPPLIER_NAME SUPPLIER_CATEGORY  \
# 0  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI            VENDOR
# 1  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI            VENDOR
# 2  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI            VENDOR
# 3  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI            VENDOR
# 4  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI            VENDOR
#
#    TOTAL_APPROVE_PO_CNT  TOT_APPROVED_BPA_AMT LAST_SUP_PO_REL_DATE  ...  \
# 0                     0                   NaN                  NaT  ...
# 1                     0                   NaN                  NaT  ...
# 2                     0                   NaN                  NaT  ...
# 3                     0                   NaN                  NaT  ...
# 4                     0                   NaN                  NaT  ...
#
#   ADDRESS_LINE1 ADDRESS_LINE2 ADDRESS_LINE3 ADDRESS_LINE4 POSTAL_CODE  \
# 0     ABU DHABI           NaN           NaN           555         NaN
# 1     ABU DHABI           NaN           NaN           555         NaN
# 2     ABU DHABI           NaN           NaN           555         NaN
# 3     ABU DHABI           NaN           NaN           555         NaN
# 4     ABU DHABI           NaN           NaN           555         NaN
#
#         CITY               COUNTRY SUP_PHONE_NUM SUP_FAX_NUM SUP_EMAIL_ADDRESS
# 0  ABU DHABI  United Arab Emirates    02-5559636  02-6593630               NaN
# 1  ABU DHABI  United Arab Emirates    02-5559636  02-6593630               NaN
# 2  ABU DHABI  United Arab Emirates    02-5559636  02-6593630               NaN
# 3  ABU DHABI  United Arab Emirates    02-5559636  02-6593630               NaN
# 4  ABU DHABI  United Arab Emirates    02-5559636  02-6593630               NaN
#
# [5 rows x 29 columns]

# %%
df_supplier_master_duplicate = df_supplier_master[df_supplier_master.duplicated(['SUPPLIER_NO'])]
df_supplier_master_duplicate
# Out:
#                                             SUPPLIER_NAME SUPPLIER_NO  \
# 1             AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI           1
# 2             AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI           1
# 3             AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI           1
# 4             AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI           1
# 9                     SOFIA ALEXANDRA BALULA PEREIRA DIAS      100018
# ...                                                   ...         ...
# 107196  KHALIFA UNIVERSITY OF SCIENCE AND TECHONOLOGY-...       99975
# 107197                               LOTHIAN HEALTH BOARD       99980
# 107198                               https://www.aip.org/       99981
# 107199                    ONLINE LEARNING CONSORTIUM,INC.       99982
# 107200                 ADTECH POLYMER ENGINEERING LIMITED       99992
#
#                          ADDRESS_LINE1                AREA               CITY  \
# 1                            ABU DHABI                None          ABU DHABI
# 2                            ABU DHABI                None          ABU DHABI
# 3                            ABU DHABI                None          ABU DHABI
# 4                            ABU DHABI                None          ABU DHABI
# 9                             PORTUGAL                None           PORTUGAL
# ...                                ...                 ...                ...
# 107196                       ABU DHABI                None          ABU DHABI
# 107197         WAVERLEY GATE 2ND FLOOR  2-4 WATERLOO PLACE  EDINBURGH,EH1 3DG
# 107198                       ABU DHABI                None          ABU DHABI
# 107199                   UNITED STATES                None               None
# 107200  Unit 40 Aston Down East Stroud                None               GLOS
#
#                      COUNTRY                  Email Address CL_LICENSE_NO  \
# 1       United Arab Emirates                           None    CN-1003984
# 2       United Arab Emirates                           None    CN-1003984
# 3       United Arab Emirates                           None    CN-1003984
# 4       United Arab Emirates                           None    CN-1003984
# 9                   Portugal                           None          None
# ...                      ...                            ...           ...
# 107196  United Arab Emirates  KUAccountReceivables@ku.ac.ae          None
# 107197        United Kingdom                           None          None
# 107198  United Arab Emirates                           None          None
# 107199         United States                           None          None
# 107200        United Kingdom             sales@adtech.co.uk       1669451
#
#              CL_EXPIRY_DATE  TAX_REGISTRATION_NUM SUPPLIER_INACTIVE_DATE  \
# 1       2020-10-01 00:00:00    100072684200003-10                    NaT
# 2       2020-10-01 00:00:00    100072684200003-10                    NaT
# 3       2020-10-01 00:00:00    100072684200003-10                    NaT
# 4       2020-10-01 00:00:00    100072684200003-10                    NaT
# 9                      None  INDIVIDUAL -  100018                    NaT
# ...                     ...                   ...                    ...
# 107196                 None        NO VAT - 99975                    NaT
# 107197                 None                  None                    NaT
# 107198                 None            VAT  99981                    NaT
# 107199                 None            VAT  99982                    NaT
# 107200  2030-12-31 00:00:00           GB267205993                    NaT
#
#                         Bank_Name           Branch_name  Bank_Account_Num  \
# 1       ABU DHABI COMMERCIAL BANK           DUBAI RIQQA      100317020003
# 2       ABU DHABI COMMERCIAL BANK           DUBAI RIQQA        1005612298
# 3                   ARAB BANK PLC                AL AIN   3002-043002-311
# 4                   ARAB BANK PLC           DEIRA/DUBAI   3001-043002-311
# 9       ABU DHABI COMMERCIAL BANK        ABU DHABI MAIN    11980906910001
# ...                           ...                   ...               ...
# 107196       FIRST ABU DHABI BANK  ABU DHABI KHALIFA ST  1011003284369136
# 107197                       None                  None              None
# 107198                       None                  None              None
# 107199            BANK OF AMERICA          222 BROADWAY      004668636650
# 107200                       None                  None              None
#
#                 Bank_Account_Name        Bank_Account_IBAN  \
# 1       ABU DHABI COMMERCIAL BANK  AE230030000100317020003
# 2                            ADCB                     None
# 3                       ARAB BANK                     None
# 4                       ARAB BANK                     None
# 9                            ADCB  AE860030011980906910001
# ...                           ...                      ...
# 107196                        FAB  AE030351011003284369136
# 107197                       None                     None
# 107198                       None                     None
# 107199            BANK OF AMERICA                     None
# 107200                       None                     None
#
#        Bank_Account_Start_date Bank_Account_end_date Bank_Account_Created_by
# 1                          NaT                   NaT                   DCONV
# 2                          NaT                   NaT                   DCONV
# 3                          NaT                   NaT                   DCONV
# 4                          NaT                   NaT                   DCONV
# 9                   2021-04-18                   NaT                DOF47008
# ...                        ...                   ...                     ...
# 107196              2020-11-15                   NaT              AYYARAKATH
# 107197                     NaT                   NaT                    None
# 107198                     NaT                   NaT                    None
# 107199              2020-11-15                   NaT              AYYARAKATH
# 107200                     NaT                   NaT                    None
#
# [96781 rows x 19 columns]

# %%
df_comparison = pd.merge(df_supplier_master, df_supplier_master_duplicate, on='SUPPLIER_NO', how='inner')
df_comparison.head(5)
# Out:
#                                SUPPLIER_NAME_x SUPPLIER_NO ADDRESS_LINE1_x  \
# 0  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI           1       ABU DHABI
# 1  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI           1       ABU DHABI
# 2  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI           1       ABU DHABI
# 3  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI           1       ABU DHABI
# 4  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI           1       ABU DHABI
#
#   AREA_x     CITY_x             COUNTRY_x Email Address_x CL_LICENSE_NO_x  \
# 0   None  ABU DHABI  United Arab Emirates            None      CN-1003984
# 1   None  ABU DHABI  United Arab Emirates            None      CN-1003984
# 2   None  ABU DHABI  United Arab Emirates            None      CN-1003984
# 3   None  ABU DHABI  United Arab Emirates            None      CN-1003984
# 4   None  ABU DHABI  United Arab Emirates            None      CN-1003984
#
#       CL_EXPIRY_DATE_x TAX_REGISTRATION_NUM_x  ... TAX_REGISTRATION_NUM_y  \
# 0  2020-10-01 00:00:00     100072684200003-10  ...     100072684200003-10
# 1  2020-10-01 00:00:00     100072684200003-10  ...     100072684200003-10
# 2  2020-10-01 00:00:00     100072684200003-10  ...     100072684200003-10
# 3  2020-10-01 00:00:00     100072684200003-10  ...     100072684200003-10
# 4  2020-10-01 00:00:00     100072684200003-10  ...     100072684200003-10
#
#   SUPPLIER_INACTIVE_DATE_y                Bank_Name_y Branch_name_y  \
# 0                      NaT  ABU DHABI COMMERCIAL BANK   DUBAI RIQQA
# 1                      NaT  ABU DHABI COMMERCIAL BANK   DUBAI RIQQA
# 2                      NaT              ARAB BANK PLC        AL AIN
# 3                      NaT              ARAB BANK PLC   DEIRA/DUBAI
# 4                      NaT  ABU DHABI COMMERCIAL BANK   DUBAI RIQQA
#
#   Bank_Account_Num_y        Bank_Account_Name_y      Bank_Account_IBAN_y  \
# 0       100317020003  ABU DHABI COMMERCIAL BANK  AE230030000100317020003
# 1         1005612298                       ADCB                     None
# 2    3002-043002-311                  ARAB BANK                     None
# 3    3001-043002-311                  ARAB BANK                     None
# 4      10-056-1229-8                       None                     None
#
#   Bank_Account_Start_date_y Bank_Account_end_date_y Bank_Account_Created_by_y
# 0                       NaT                     NaT                     DCONV
# 1                       NaT                     NaT                     DCONV
# 2                       NaT                     NaT                     DCONV
# 3                       NaT                     NaT                     DCONV
# 4                       NaT                     NaT                     MWASI
#
# [5 rows x 37 columns]

# %%
df_supplier_master_duplicate.to_sql("Duplicate_suppliers_same_entity", eng_write)

# %% [markdown]
# The below output will require analysis to ensure the TRN duplicates are based on different suppliers and not the same supplier. The reason for the analysis is due to the fact Khalifa University registers the same vendor for the same entity twice based on minor tweaks.
#
# As a recommendation, Internal Audit should recommend to establish 1 vendor across Khalifa University or remove the duplicated vendors registered multiple times for the same entity.

# %%
df_supplier_master_TRN = df_supplier_master[df_supplier_master.duplicated(['TAX_REGISTRATION_NUM','OPERATING_UNIT','CITY'])]
df_supplier_master_TRN
# Out:
#                                           OPERATING_UNIT REGISTER_MODE  \
# 43                 KUX - External Khalifa University O.U        Manual
# 44                     KUA - Ankabout Khalifa University        Manual
# 45                    KUE - Ebitic Khalifa University OU        Manual
# 46                    KUK - Khalifa University Ledger OU        Manual
# 49                    KUJ -  Aric Khalifa University O.U        Manual
# ...                                                  ...           ...
# 63035                                         KUADRIC OU        Manual
# 63036                                           KUGRC OU        Manual
# 63037  KUST Khalifa University of Science and Technol...        Manual
# 63038                 KUE - Ebitic Khalifa University OU        Manual
# 63039                 KUK - Khalifa University Ledger OU        Manual
#
#        SUPPLIER_NO   SUP_CREATION_DATE SUPPLIER_INACTIVE_DATE  \
# 43              17 2010-06-01 19:13:00                    NaT
# 44              17 2010-06-01 19:13:00                    NaT
# 45              17 2010-06-01 19:13:00                    NaT
# 46              17 2010-06-01 19:13:00                    NaT
# 49              17 2010-06-01 19:13:00                    NaT
# ...            ...                 ...                    ...
# 63035       104903 2021-10-10 12:23:11                    NaT
# 63036       104903 2021-10-10 12:23:11                    NaT
# 63037       104903 2021-10-10 12:23:11                    NaT
# 63038       104903 2021-10-10 12:23:11                    NaT
# 63039       104903 2021-10-10 12:23:11                    NaT
#
#                                        SUPPLIER_NAME SUPPLIER_CATEGORY  \
# 43     AL FUTTAIM ELECTRONICS CO. (ABU DHABI) L.L.C.            VENDOR
# 44     AL FUTTAIM ELECTRONICS CO. (ABU DHABI) L.L.C.            VENDOR
# 45     AL FUTTAIM ELECTRONICS CO. (ABU DHABI) L.L.C.            VENDOR
# 46     AL FUTTAIM ELECTRONICS CO. (ABU DHABI) L.L.C.            VENDOR
# 49     AL FUTTAIM ELECTRONICS CO. (ABU DHABI) L.L.C.            VENDOR
# ...                                              ...               ...
# 63035                     https://uae.microless.com/               NaN
# 63036                     https://uae.microless.com/               NaN
# 63037                     https://uae.microless.com/               NaN
# 63038                     https://uae.microless.com/               NaN
# 63039                     https://uae.microless.com/               NaN
#
#        TOTAL_APPROVE_PO_CNT  TOT_APPROVED_BPA_AMT LAST_SUP_PO_REL_DATE  ...  \
# 43                        0                   NaN                  NaT  ...
# 44                        0                   NaN                  NaT  ...
# 45                        0                   NaN                  NaT  ...
# 46                        0                   NaN                  NaT  ...
# 49                        0                   NaN                  NaT  ...
# ...                     ...                   ...                  ...  ...
# 63035                     0                   NaN                  NaT  ...
# 63036                     0                   NaN                  NaT  ...
# 63037                     0                   NaN                  NaT  ...
# 63038                     0                   NaN                  NaT  ...
# 63039                     0                   NaN                  NaT  ...
#
#                ADDRESS_LINE1 ADDRESS_LINE2 ADDRESS_LINE3 ADDRESS_LINE4  \
# 43                 ABU DHABI           NaN           NaN           NaN
# 44                 ABU DHABI           NaN           NaN           NaN
# 45                 ABU DHABI           NaN           NaN           NaN
# 46                 ABU DHABI           NaN           NaN           NaN
# 49     MINA ZAYED- ABU DHABI           NaN           NaN           NaN
# ...                      ...           ...           ...           ...
# 63035              ABU DHABI           NaN           NaN        127788
# 63036              ABU DHABI           NaN           NaN        127788
# 63037              ABU DHABI           NaN           NaN        127788
# 63038              ABU DHABI           NaN           NaN        127788
# 63039              ABU DHABI           NaN           NaN        127788
#
#       POSTAL_CODE       CITY               COUNTRY SUP_PHONE_NUM SUP_FAX_NUM  \
# 43          73618  ABU DHABI  United Arab Emirates           NaN         NaN
# 44          73618  ABU DHABI  United Arab Emirates           NaN         NaN
# 45          73618  ABU DHABI  United Arab Emirates           NaN         NaN
# 46          73618  ABU DHABI  United Arab Emirates           NaN         NaN
# 49           6885  ABU DHABI  United Arab Emirates    02-6819539  02-6815501
# ...           ...        ...                   ...           ...         ...
# 63035         NaN  ABU DHABI  United Arab Emirates           NaN         NaN
# 63036         NaN  ABU DHABI  United Arab Emirates           NaN         NaN
# 63037         NaN  ABU DHABI  United Arab Emirates           NaN         NaN
# 63038         NaN  ABU DHABI  United Arab Emirates           NaN         NaN
# 63039         NaN  ABU DHABI  United Arab Emirates           NaN         NaN
#
#                   SUP_EMAIL_ADDRESS
# 43                              NaN
# 44                              NaN
# 45                              NaN
# 46                              NaN
# 49     techserveOA.ABD@alfuttaim.ae
# ...                             ...
# 63035                           NaN
# 63036                           NaN
# 63037                           NaN
# 63038                           NaN
# 63039                           NaN
#
# [16058 rows x 29 columns]

# %%
df_comparison = pd.merge(df_supplier_master, df_supplier_master_TRN, on='TAX_REGISTRATION_NUM', how='inner')
df_comparison.head(5)

# %%
df_supplier_master_TRN.to_sql("TRN_supplier_duplicates", conn)

# %% [markdown]
# The bank related details are not part of the master supplier list and has been read from the excel file shared. In case the supplier master contains the bank details, **the code will only be required to be modifie from "df_supplier_bank" to "df_supplier_master"**.

# %%
df_supplier_bank = pd.read_excel("C:/users/ku1016/downloads/Supplier bank detail.xlsx")
df_supplier_bank.head(5)
# Out:
#    Supplier No.                                Supplier Name  \
# 0             1  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI
# 1             1  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI
# 2             1  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI
# 3             1  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI
# 4        100006                          GILSON COMPANY INC.
#
#   Registered Method Vendor Type Commercial Licence No  \
# 0            Manual      VENDOR            CN-1003984
# 1            Manual      VENDOR            CN-1003984
# 2            Manual      VENDOR            CN-1003984
# 3            Manual      VENDOR            CN-1003984
# 4            Manual      VENDOR                   NaN
#
#   Commercial Licence Expiry Date Tax Registration No.               Country  \
# 0            2020-10-01 00:00:00   100072684200003-10  United Arab Emirates
# 1            2020-10-01 00:00:00   100072684200003-10  United Arab Emirates
# 2            2020-10-01 00:00:00   100072684200003-10  United Arab Emirates
# 3            2020-10-01 00:00:00   100072684200003-10  United Arab Emirates
# 4                            NaN            310961077         United States
#
#             Supplier Created By Supplier Creation Date  ...  \
# 0                           NaN             2010-06-01  ...
# 1                           NaN             2010-06-01  ...
# 2                           NaN             2010-06-01  ...
# 3                           NaN             2010-06-01  ...
# 4  سهيل احمد خان غلام سروار خان             2020-11-16  ...
#
#   Business Class Last Update Date  \
# 0             2020-01-20 07:54:50
# 1             2020-01-20 07:54:50
# 2             2020-01-20 07:54:50
# 3             2020-01-20 07:54:50
# 4                             NaT
#
#                                    Organization Name     Bank Account  \
# 0  KUST Khalifa University of Science and Technol...     100317020003
# 1  KUST Khalifa University of Science and Technol...       1005612298
# 2  KUST Khalifa University of Science and Technol...  3001-043002-311
# 3  KUST Khalifa University of Science and Technol...  3002-043002-311
# 4  KUST Khalifa University of Science and Technol...       1306992777
#
#            Bank Account Name                               Bank Acc Title  \
# 0  ABU DHABI COMMERCIAL BANK  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI
# 1                       ADCB  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI
# 2                  ARAB BANK  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI
# 3                  ARAB BANK  AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI
# 4                   CNB BANK                                          NaN
#
#                       Iban                  Bank Name  Branch Name  \
# 0  AE230030000100317020003  ABU DHABI COMMERCIAL BANK  DUBAI RIQQA
# 1                      NaN  ABU DHABI COMMERCIAL BANK  DUBAI RIQQA
# 2                      NaN              ARAB BANK PLC  DEIRA/DUBAI
# 3                      NaN              ARAB BANK PLC       AL AIN
# 4                      NaN                   CNB BANK   CLEARFIELD
#
#               Country.1   End Date
# 0  United Arab Emirates        NaT
# 1  United Arab Emirates 2011-11-15
# 2  United Arab Emirates 2013-03-21
# 3  United Arab Emirates 2013-03-21
# 4         United States        NaT
#
# [5 rows x 26 columns]

# %% [markdown]
# The output will require analysis to ensure the IBANs are for different suppliers, since at Khalifa University **multiple active accounts are valid for same supplier with same bank details, same bank account number and same address**.

# %%
df_supplier_bank_duplicate = df_supplier_bank[(df_supplier_bank.duplicated(["Iban", "Bank Account"])) & (df_supplier_bank['Iban'].notna())]
df_supplier_bank_duplicate
# Out:
#        Supplier No.                 Supplier Name Registered Method  \
# 500          103518                 KHADJETOU JED            Manual
# 1012          12155      AL DHAFRA PRIVATE SCHOOL            Manual
# 1013          12155      AL DHAFRA PRIVATE SCHOOL            Manual
# 1014          12155      AL DHAFRA PRIVATE SCHOOL            Manual
# 1015          12155      AL DHAFRA PRIVATE SCHOOL            Manual
# ...             ...                           ...               ...
# 15859         99020    Mohamed Ibrahim Hassan Ali            Manual
# 15860         99020    Mohamed Ibrahim Hassan Ali            Manual
# 15864          9906  EDUTECH MIDDLE EAST (L.L.C.)            Manual
# 15896         99407                  EMILIO PORCU            Manual
# 15949         99800              MD MOTIUR RAHMAN            Manual
#
#        Vendor Type Commercial Licence No Commercial Licence Expiry Date  \
# 500    BENIFICIARY                   NaN                            NaN
# 1012        SCHOOL            CN-1003266            2023-11-09 00:00:00
# 1013        SCHOOL            CN-1003266            2023-11-09 00:00:00
# 1014        SCHOOL            CN-1003266            2023-11-09 00:00:00
# 1015        SCHOOL            CN-1003266            2023-11-09 00:00:00
# ...            ...                   ...                            ...
# 15859     EMPLOYEE                   NaN                            NaN
# 15860     EMPLOYEE                   NaN                            NaN
# 15864       VENDOR                225130            2018-06-05 00:00:00
# 15896  BENIFICIARY                   NaN                            NaN
# 15949  BENIFICIARY                   NaN                            NaN
#
#       Tax Registration No.               Country          Supplier Created By  \
# 500     INDIVIDUAL -103518  United Arab Emirates  نجود غانم سالم سعيد الصيعري
# 1012     100310305600003-4  United Arab Emirates                          NaN
# 1013     100310305600003-4  United Arab Emirates                          NaN
# 1014     100310305600003-4  United Arab Emirates                          NaN
# 1015     100310305600003-4  United Arab Emirates                          NaN
# ...                    ...                   ...                          ...
# 15859                  NaN                   NaN           اياراكات عبدالمجيد
# 15860                  NaN                   NaN           اياراكات عبدالمجيد
# 15864         225130-DUBAI  United Arab Emirates                          NaN
# 15896   INDIAVIDUAL- 99407  United Arab Emirates  نجود غانم سالم سعيد الصيعري
# 15949   INDIVIDUAL - 99800  United Arab Emirates           اياراكات عبدالمجيد
#
#       Supplier Creation Date  ... Business Class Last Update Date  \
# 500               2021-08-01  ...                             NaT
# 1012              2010-06-23  ...             2021-01-18 12:58:38
# 1013              2010-06-23  ...             2021-01-18 12:58:38
# 1014              2010-06-23  ...             2021-01-18 12:58:38
# 1015              2010-06-23  ...             2021-01-18 12:58:38
# ...                      ...  ...                             ...
# 15859             2020-08-31  ...                             NaT
# 15860             2020-08-31  ...                             NaT
# 15864             2010-06-23  ...             2017-06-05 11:44:21
# 15896             2020-10-01  ...                             NaT
# 15949             2020-11-01  ...                             NaT
#
#                                        Organization Name      Bank Account  \
# 500    KUST Khalifa University of Science and Technol...     3707596970002
# 1012   KUST Khalifa University of Science and Technol...      012063581391
# 1013   KUST Khalifa University of Science and Technol...  1051001004868027
# 1014   KUST Khalifa University of Science and Technol...  1051001004868027
# 1015   KUST Khalifa University of Science and Technol...  4021003307897811
# ...                                                  ...               ...
# 15859  KUST Khalifa University of Science and Technol...          24392765
# 15860  KUST Khalifa University of Science and Technol...          24392765
# 15864  KUST Khalifa University of Science and Technol...      258955319001
# 15896  KUST Khalifa University of Science and Technol...       12231395001
# 15949  KUST Khalifa University of Science and Technol...       24238399013
#
#                        Bank Account Name                Bank Acc Title  \
# 500                                 HSBC                 KHADJETOU JED
# 1012                                 UNB                           NaN
# 1013   Al Dhafra Secondry Private School                           NaN
# 1014                                 FAB                           NaN
# 1015                                 FAB                           NaN
# ...                                  ...                           ...
# 15859                               ADIB                           NaN
# 15860                               ADIB                           NaN
# 15864                               ADCB  EDUTECH MIDDLE EAST (L.L.C.)
# 15896                               HSBC                  EMILIO PORCU
# 15949                      AL HILAL BANK              MD MOTIUR RAHMAN
#
#                           Iban                  Bank Name  \
# 500    AE360340003707596970002      HSBC BANK MIDDLE EAST
# 1012   AE510450000012063581391        UNION NATIONAL BANK
# 1013   AE080271051001004868027            FIRST GULF BANK
# 1014   AE020351051001004868027       FIRST ABU DHABI BANK
# 1015   AE450354021003307897811       FIRST ABU DHABI BANK
# ...                        ...                        ...
# 15859  AE050500000000024392765     ABU DHABI ISLAMIC BANK
# 15860  AE050500000000024392765     ABU DHABI ISLAMIC BANK
# 15864  AE800030000258955319001  ABU DHABI COMMERCIAL BANK
# 15896  AE120200000012231395001      HSBC BANK MIDDLE EAST
# 15949  AE680530000024238399013              AL HILAL BANK
#
#                        Branch Name             Country.1   End Date
# 500    ABU DHABI RASHID MAKTOUM ST  United Arab Emirates 2021-09-08
# 1012        ABU DHABI SALAM BRANCH  United Arab Emirates        NaT
# 1013             AL AIN KHALIFA ST  United Arab Emirates        NaT
# 1014          ABU DHABI KHALIFA ST  United Arab Emirates        NaT
# 1015          ABU DHABI KHALIFA ST  United Arab Emirates 2020-05-28
# ...                            ...                   ...        ...
# 15859         ABU DHABI BANIYAS ST  United Arab Emirates        NaT
# 15860         ABU DHABI BANIYAS ST  United Arab Emirates        NaT
# 15864          DUBAI AL MEENA ROAD  United Arab Emirates        NaT
# 15896  ABU DHABI RASHID MAKTOUM ST  United Arab Emirates        NaT
# 15949    ABU DHABI CORNICHE BRANCH  United Arab Emirates        NaT
#
# [631 rows x 26 columns]

# %%
df_comparison = pd.merge(df_supplier_bank, df_supplier_bank_duplicate, on='TAX_REGISTRATION_NUM', how='inner')
df_comparison.head(5)

# %%
df_supplier_duplicate.to_sql("IBAN_supplier", conn)

# %% [markdown]
# ## 5.2 Missing information for suppliers

# %% [markdown]
# All active vendors at Khalifa University are required to have valid IBAN, address and TRN numbers at a minimum. Below are the analysis:

# %%
df_supplier_missing_iban = df_supplier_bank[df_supplier_bank['Iban'].isnull()]
df_supplier_missing_iban
# Out:
#        Supplier No.                                      Supplier Name  \
# 1                 1        AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI
# 2                 1        AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI
# 3                 1        AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI
# 4            100006                                GILSON COMPANY INC.
# 8            100023                             SYSTEMS TECHNOLOGY INC
# ...             ...                                                ...
# 15954         99893                    HUAIYIN INSTITUTE OF TECHNOLOGY
# 15960         99899  THE RECTOR AND VISITORS OF THE UNIVERSITY OF V...
# 15962         99912                                    DUKE UNIVERSITY
# 15970         99955            GOLDEN KEY INTERNATIONAL HONOUR SOCIETY
# 15972         99982                    ONLINE LEARNING CONSORTIUM,INC.
#
#       Registered Method Vendor Type Commercial Licence No  \
# 1                Manual      VENDOR            CN-1003984
# 2                Manual      VENDOR            CN-1003984
# 3                Manual      VENDOR            CN-1003984
# 4                Manual      VENDOR                   NaN
# 8                Manual         NaN                  2657
# ...                 ...         ...                   ...
# 15954            Manual         NaN                   NaN
# 15960            Manual         NaN                   NaN
# 15962            Manual         NaN                   NaN
# 15970            Manual         NaN                   NaN
# 15972            Manual         NaN                   NaN
#
#       Commercial Licence Expiry Date Tax Registration No.  \
# 1                2020-10-01 00:00:00   100072684200003-10
# 2                2020-10-01 00:00:00   100072684200003-10
# 3                2020-10-01 00:00:00   100072684200003-10
# 4                                NaN            310961077
# 8                                NaN           95-1957989
# ...                              ...                  ...
# 15954                            NaN       NO VAT - 99893
# 15960                            NaN       NO VAT - 99899
# 15962                            NaN        NO VAT -99912
# 15970                            NaN        NO VAT -99955
# 15972                            NaN            VAT 99982
#
#                     Country           Supplier Created By  \
# 1      United Arab Emirates                           NaN
# 2      United Arab Emirates                           NaN
# 3      United Arab Emirates                           NaN
# 4             United States  سهيل احمد خان غلام سروار خان
# 8             United States           مجيد حسين طلحه محمد
# ...                     ...                           ...
# 15954                 China            اياراكات عبدالمجيد
# 15960         United States            اياراكات عبدالمجيد
# 15962         United States            اياراكات عبدالمجيد
# 15970         United States            اياراكات عبدالمجيد
# 15972         United States            اياراكات عبدالمجيد
#
#       Supplier Creation Date  ... Business Class Last Update Date  \
# 1                 2010-06-01  ...             2020-01-20 07:54:50
# 2                 2010-06-01  ...             2020-01-20 07:54:50
# 3                 2010-06-01  ...             2020-01-20 07:54:50
# 4                 2020-11-16  ...                             NaT
# 8                 2020-11-18  ...             2020-11-18 10:04:17
# ...                      ...  ...                             ...
# 15954             2020-11-05  ...                             NaT
# 15960             2020-11-05  ...                             NaT
# 15962             2020-11-08  ...                             NaT
# 15970             2020-11-11  ...                             NaT
# 15972             2020-11-15  ...                             NaT
#
#                                        Organization Name     Bank Account  \
# 1      KUST Khalifa University of Science and Technol...       1005612298
# 2      KUST Khalifa University of Science and Technol...  3001-043002-311
# 3      KUST Khalifa University of Science and Technol...  3002-043002-311
# 4      KUST Khalifa University of Science and Technol...       1306992777
# 8      KUST Khalifa University of Science and Technol...        546343200
# ...                                                  ...              ...
# 15954  KUST Khalifa University of Science and Technol...     536568825651
# 15960  KUST Khalifa University of Science and Technol...     004117975749
# 15962  KUST Khalifa University of Science and Technol...    2000048265067
# 15970  KUST Khalifa University of Science and Technol...     000000193666
# 15972  KUST Khalifa University of Science and Technol...     004668636650
#
#             Bank Account Name  \
# 1                        ADCB
# 2                   ARAB BANK
# 3                   ARAB BANK
# 4                    CNB BANK
# 8        PACIFIC WESTERN BANK
# ...                       ...
# 15954           BANK OF CHINA
# 15960         BANK OF AMERICA
# 15962  WELLS FARGO BANK, N.A,
# 15970         BANK OF AMERICA
# 15972         BANK OF AMERICA
#
#                                           Bank Acc Title Iban  \
# 1            AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI  NaN
# 2            AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI  NaN
# 3            AL FUTTAIM MOTOR COMPANY L.L.C. - ABU DHABI  NaN
# 4                                                    NaN  NaN
# 8                                                    NaN  NaN
# ...                                                  ...  ...
# 15954                    HUAIYIN INSTITUTE OF TECHNOLOGY  NaN
# 15960  THE RECTOR AND VISITORS OF THE UNIVERSITY OF V...  NaN
# 15962                                    DUKE UNIVERSITY  NaN
# 15970            GOLDEN KEY INTERNATIONAL HONOUR SOCIETY  NaN
# 15972                    ONLINE LEARNING CONSORTIUM,INC.  NaN
#
#                        Bank Name           Branch Name             Country.1  \
# 1      ABU DHABI COMMERCIAL BANK           DUBAI RIQQA  United Arab Emirates
# 2                  ARAB BANK PLC           DEIRA/DUBAI  United Arab Emirates
# 3                  ARAB BANK PLC                AL AIN  United Arab Emirates
# 4                       CNB BANK            CLEARFIELD         United States
# 8           PACIFIC WESTERN BANK   1025 W 190TH STREET         United States
# ...                          ...                   ...                   ...
# 15954              BANK OF CHINA        JIANGSU BRANCH                 China
# 15960            BANK OF AMERICA              NEW YORK         United States
# 15962     WELLS FARGO BANK, N.A,        301 S TRYON ST         United States
# 15970            BANK OF AMERICA  600 PEACHTREE ST. NE         United States
# 15972            BANK OF AMERICA          222 BROADWAY         United States
#
#         End Date
# 1     2011-11-15
# 2     2013-03-21
# 3     2013-03-21
# 4            NaT
# 8            NaT
# ...          ...
# 15954        NaT
# 15960        NaT
# 15962        NaT
# 15970        NaT
# 15972        NaT
#
# [4397 rows x 26 columns]

# %%
df_supplier_missing_iban.to_sql("Missing_supplier_Iban", conn)

# %%
df_supplier_missing_trn = df_supplier_bank[df_supplier_bank['Tax Registration No.'].isnull()]
df_supplier_missing_trn
# Out:
#        Supplier No.                          Supplier Name Registered Method  \
# 9            100027  AADEL HASSAN MOHAMED MOHAMED ALHMOUDI            Manual
# 30           100099       TRIDENT SUPPORT FLAG POLES L.L.C            Manual
# 62           100315                       Mutasem El Fadel            Manual
# 64           100331                      Ismail Aejaz Baig            Manual
# 82           100540                Nnamdi Valbocso Ugwuoke            Manual
# ...             ...                                    ...               ...
# 15904         99490                      Aamir Younis Raja            Manual
# 15933         99688             Daniel Johannes Van Tonder            Manual
# 15934         99689                    Thripti Vijayakumar            Manual
# 15935         99690                            Partha Guha            Manual
# 15936         99697                         Trust Nyirenda            Manual
#
#       Vendor Type Commercial Licence No Commercial Licence Expiry Date  \
# 9             NaN                   NaN                            NaN
# 30            NaN                   NaN                            NaN
# 62       EMPLOYEE                   NaN                            NaN
# 64       EMPLOYEE                   NaN                            NaN
# 82       EMPLOYEE                   NaN                            NaN
# ...           ...                   ...                            ...
# 15904    EMPLOYEE                   NaN                            NaN
# 15933    EMPLOYEE                   NaN                            NaN
# 15934    EMPLOYEE                   NaN                            NaN
# 15935    EMPLOYEE                   NaN                            NaN
# 15936    EMPLOYEE                   NaN                            NaN
#
#       Tax Registration No.               Country  \
# 9                      NaN  United Arab Emirates
# 30                     NaN  United Arab Emirates
# 62                     NaN                   NaN
# 64                     NaN                   NaN
# 82                     NaN                   NaN
# ...                    ...                   ...
# 15904                  NaN                   NaN
# 15933                  NaN                   NaN
# 15934                  NaN                   NaN
# 15935                  NaN                   NaN
# 15936                  NaN                   NaN
#
#                    Supplier Created By Supplier Creation Date  ...  \
# 9          نجود غانم سالم سعيد الصيعري             2020-11-18  ...
# 30     عبدالله راشد مبارك فهاد الهاجري             2020-11-23  ...
# 62                  اياراكات عبدالمجيد             2020-12-09  ...
# 64                  اياراكات عبدالمجيد             2020-12-10  ...
# 82                  اياراكات عبدالمجيد             2020-12-23  ...
# ...                                ...                    ...  ...
# 15904               اياراكات عبدالمجيد             2020-10-07  ...
# 15933               اياراكات عبدالمجيد             2020-10-22  ...
# 15934               اياراكات عبدالمجيد             2020-10-22  ...
# 15935               اياراكات عبدالمجيد             2020-10-22  ...
# 15936               اياراكات عبدالمجيد             2020-10-22  ...
#
#       Business Class Last Update Date  \
# 9                                 NaT
# 30                                NaT
# 62                                NaT
# 64                                NaT
# 82                                NaT
# ...                               ...
# 15904                             NaT
# 15933                             NaT
# 15934                             NaT
# 15935                             NaT
# 15936                             NaT
#
#                                        Organization Name    Bank Account  \
# 9      KUST Khalifa University of Science and Technol...        28230787
# 30     KUST Khalifa University of Science and Technol...   1014833627701
# 62     KUST Khalifa University of Science and Technol...    012245361001
# 64     KUST Khalifa University of Science and Technol...  11878472920001
# 82     KUST Khalifa University of Science and Technol...  11807768920001
# ...                                                  ...             ...
# 15904  KUST Khalifa University of Science and Technol...    012233219001
# 15933  KUST Khalifa University of Science and Technol...  11853072920001
# 15934  KUST Khalifa University of Science and Technol...  11852376920001
# 15935  KUST Khalifa University of Science and Technol...  11855091920001
# 15936  KUST Khalifa University of Science and Technol...  11852412920001
#
#       Bank Account Name                         Bank Acc Title  \
# 9                  ADIB  AADEL HASSAN MOHAMED MOHAMED ALHMOUDI
# 30                 ENBD                                    NaN
# 62                 HSBC                                    NaN
# 64                 ADCB                                    NaN
# 82                 ADCB                                    NaN
# ...                 ...                                    ...
# 15904              HSBC                                    NaN
# 15933              ADCB                                    NaN
# 15934              ADCB                                    NaN
# 15935              ADCB                                    NaN
# 15936              ADCB                                    NaN
#
#                           Iban                  Bank Name  \
# 9      AE630500000000028230787     ABU DHABI ISLAMIC BANK
# 30     AE250260001014833627701               EMIRATES NBD
# 62     AE800200000012245361001      HSBC BANK MIDDLE EAST
# 64     AE400030011878472920001  ABU DHABI COMMERCIAL BANK
# 82     AE750030011807768920001  ABU DHABI COMMERCIAL BANK
# ...                        ...                        ...
# 15904  AE760200000012233219001      HSBC BANK MIDDLE EAST
# 15933  AE190030011853072920001  ABU DHABI COMMERCIAL BANK
# 15934  AE930030011852376920001  ABU DHABI COMMERCIAL BANK
# 15935  AE460030011855091920001  ABU DHABI COMMERCIAL BANK
# 15936  AE390030011852412920001  ABU DHABI COMMERCIAL BANK
#
#                        Branch Name             Country.1 End Date
# 9             ABU DHABI BANIYAS ST  United Arab Emirates      NaT
# 30               DUBAI MALL BRANCH  United Arab Emirates      NaT
# 62     ABU DHABI RASHID MAKTOUM ST  United Arab Emirates      NaT
# 64                  ABU DHABI MAIN  United Arab Emirates      NaT
# 82                  ABU DHABI MAIN  United Arab Emirates      NaT
# ...                            ...                   ...      ...
# 15904  ABU DHABI RASHID MAKTOUM ST  United Arab Emirates      NaT
# 15933               ABU DHABI MAIN  United Arab Emirates      NaT
# 15934               ABU DHABI MAIN  United Arab Emirates      NaT
# 15935               ABU DHABI MAIN  United Arab Emirates      NaT
# 15936               ABU DHABI MAIN  United Arab Emirates      NaT
#
# [6098 rows x 26 columns]

# %%
df_supplier_missing_trn.to_sql("Missing_supplier_trn", conn)

# %% [markdown]
# ## 5.3 AP Master - Vendor payments, duplicate invoices/payments and multiple payments

# %% [markdown]
# The below scripts help to analyze the employee payments as vendor payments, duplicate invoices / payments issued or multiple payments issued to the same vendor in a short duration of time.

# %%
## df_AP_invoices = pd.read_excel("C:/users/ku1016/downloads/AP Master.xlsx")
## df_AP_invoices.head(5)
# Out:
#    LEDGER_NAME  VENDOR_NO                                        VENDOR_NAME  \
# 0  KUST Ledger      64998  MINISTRY OF HIGHER EDUCATION & SCIENTIFIC RESE...
# 1  KUST Ledger      64998  MINISTRY OF HIGHER EDUCATION & SCIENTIFIC RESE...
# 2  KUST Ledger      64998  MINISTRY OF HIGHER EDUCATION & SCIENTIFIC RESE...
# 3  KUST Ledger      82641                                       VIKAS MITTAL
# 4  KUST Ledger      82641                                       VIKAS MITTAL
#
#    VENDOR_TYPE INVOICE_NUM VOUCHER_NUM INVOICE_APPROVAL_STATUS INVOICE_TYPE  \
# 0       VENDOR    29052019  8471027936                APPROVED     STANDARD
# 1       VENDOR    29052019  8471027936                APPROVED     STANDARD
# 2       VENDOR    29052019  8471027936                APPROVED     STANDARD
# 3  BENIFICIARY  PR20193499  8471028118                APPROVED     STANDARD
# 4  BENIFICIARY  PR20193499  8471028118                APPROVED     STANDARD
#
#                                  INVOICE_DESCRIPTION CREATION_DATE  ...  \
# 0  Accreditation charges- Doctor of Med Program (...    2019-08-18  ...
# 1  Accreditation charges- Doctor of Med Program (...    2019-08-18  ...
# 2  Accreditation charges- Doctor of Med Program (...    2019-08-18  ...
# 3                            RELOCATION VIKAS MITTAL    2019-08-27  ...
# 4                            RELOCATION VIKAS MITTAL    2019-08-27  ...
#
#    WFAPPROVAL_STATUS  ACCOUNTED  LINE_TYPE        TAX_RATE_NAME TAX_RATE  \
# 0       NOT REQUIRED        Yes       ITEM                  NaN      NaN
# 1       NOT REQUIRED        Yes        TAX       NOT APPLICABLE      0.0
# 2       NOT REQUIRED        Yes        TAX       NOT APPLICABLE      0.0
# 3       NOT REQUIRED        Yes       ITEM                  NaN      NaN
# 4       NOT REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
#
#   RECOVERABLE_TAX_AMOUNT  NON_RECOVERABLE_TAX_AMOUNT PAYMENT_STATUS_FLAG  \
# 0                    NaN                         NaN                 Yes
# 1                    0.0                         0.0                 Yes
# 2                    0.0                         0.0                 Yes
# 3                    NaN                         NaN                 Yes
# 4                    0.0                         0.0                 Yes
#
#    ENCUMBERED_FLAG   DUE_DATE
# 0               No 2019-05-29
# 1               No 2019-05-29
# 2               No 2019-05-29
# 3               No 2019-08-27
# 4               No 2019-08-27
#
# [5 rows x 48 columns]

# %% [markdown]
# In Khalifa University, employee payments are rendered as vendor payments. As per industry best practice, all employee related payments should be routed through HR payroll to ensure adequate controls are-in-place.
#
# Below are the details:

# %%
df_AP_employees = df_AP_invoices[(df_AP_invoices['VENDOR_TYPE']=='EMPLOYEE')]
df_AP_employees
# Out:
#         LEDGER_NAME  VENDOR_NO            VENDOR_NAME VENDOR_TYPE  \
# 10      KUST Ledger      84369  Khaled Ebrahim Al Ali    EMPLOYEE
# 11      KUST Ledger      84369  Khaled Ebrahim Al Ali    EMPLOYEE
# 12      KUST Ledger      84369  Khaled Ebrahim Al Ali    EMPLOYEE
# 13      KUST Ledger      84369  Khaled Ebrahim Al Ali    EMPLOYEE
# 14      KUST Ledger      84369  Khaled Ebrahim Al Ali    EMPLOYEE
# ...             ...        ...                    ...         ...
# 487983  KUST Ledger      84005     Mohammad Alsuwaidi    EMPLOYEE
# 487984  KUST Ledger      84005     Mohammad Alsuwaidi    EMPLOYEE
# 487985  KUST Ledger      84005     Mohammad Alsuwaidi    EMPLOYEE
# 487986  KUST Ledger      84005     Mohammad Alsuwaidi    EMPLOYEE
# 487987  KUST Ledger      84005     Mohammad Alsuwaidi    EMPLOYEE
#
#                 INVOICE_NUM VOUCHER_NUM INVOICE_APPROVAL_STATUS INVOICE_TYPE  \
# 10               PC21072019  8471027995                APPROVED     STANDARD
# 11               PC21072019  8471027995                APPROVED     STANDARD
# 12               PC21072019  8471027995                APPROVED     STANDARD
# 13               PC21072019  8471027995                APPROVED     STANDARD
# 14               PC21072019  8471027995                APPROVED     STANDARD
# ...                     ...         ...                     ...          ...
# 487983  2021-06-16 00:00:00  8471057066               CANCELLED     STANDARD
# 487984  2021-06-16 00:00:00  8471057066               CANCELLED     STANDARD
# 487985  2021-06-16 00:00:00  8471057066               CANCELLED     STANDARD
# 487986  2021-06-16 00:00:00  8471057066               CANCELLED     STANDARD
# 487987  2021-06-16 00:00:00  8471057066               CANCELLED     STANDARD
#
#                              INVOICE_DESCRIPTION CREATION_DATE  ...  \
# 10      Petty cash for Facilities- Vehicle Maint    2019-08-20  ...
# 11      Petty cash for Facilities- Vehicle Maint    2019-08-20  ...
# 12      Petty cash for Facilities- Vehicle Maint    2019-08-20  ...
# 13      Petty cash for Facilities- Vehicle Maint    2019-08-20  ...
# 14      Petty cash for Facilities- Vehicle Maint    2019-08-20  ...
# ...                                          ...           ...  ...
# 487983                             Expense claim    2021-06-16  ...
# 487984                             Expense claim    2021-06-16  ...
# 487985                             Expense claim    2021-06-16  ...
# 487986                             Expense claim    2021-06-16  ...
# 487987                             Expense claim    2021-06-16  ...
#
#         WFAPPROVAL_STATUS  ACCOUNTED  LINE_TYPE        TAX_RATE_NAME TAX_RATE  \
# 10           NOT REQUIRED        Yes       ITEM                  NaN      NaN
# 11           NOT REQUIRED        Yes       ITEM                  NaN      NaN
# 12           NOT REQUIRED        Yes        TAX       NOT APPLICABLE      0.0
# 13           NOT REQUIRED        Yes        TAX       NOT APPLICABLE      0.0
# 14           NOT REQUIRED        Yes        TAX       NOT APPLICABLE      0.0
# ...                   ...        ...        ...                  ...      ...
# 487983           REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
# 487984           REQUIRED        Yes       ITEM                  NaN      NaN
# 487985           REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
# 487986           REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
# 487987           REQUIRED        Yes       ITEM                  NaN      NaN
#
#        RECOVERABLE_TAX_AMOUNT  NON_RECOVERABLE_TAX_AMOUNT PAYMENT_STATUS_FLAG  \
# 10                        NaN                         NaN                 Yes
# 11                        NaN                         NaN                 Yes
# 12                        0.0                         0.0                 Yes
# 13                        0.0                         0.0                 Yes
# 14                        0.0                         0.0                 Yes
# ...                       ...                         ...                 ...
# 487983                   25.0                         0.0                  No
# 487984                    NaN                         NaN                  No
# 487985                   25.0                         0.0                  No
# 487986                   25.0                         0.0                  No
# 487987                    NaN                         NaN                  No
#
#         ENCUMBERED_FLAG   DUE_DATE
# 10                   No 2019-07-21
# 11                   No 2019-07-21
# 12                   No 2019-07-21
# 13                   No 2019-07-21
# 14                   No 2019-07-21
# ...                 ...        ...
# 487983               No 2021-06-16
# 487984               No 2021-06-16
# 487985               No 2021-06-16
# 487986               No 2021-06-16
# 487987               No 2021-06-16
#
# [39649 rows x 48 columns]

# %%
df_AP_employee.to_sql("Employee_Payments_as_Vendor", conn)

# %%
df_AP_duplicate = df_AP_invoices[df_AP_invoices.duplicated()]
df_AP_duplicate
# Out:
# Empty DataFrame
# Columns: [LEDGER_NAME, VENDOR_NO, VENDOR_NAME, VENDOR_TYPE, INVOICE_NUM, VOUCHER_NUM, INVOICE_APPROVAL_STATUS, INVOICE_TYPE, INVOICE_DESCRIPTION, CREATION_DATE, LINE_NUMBER, INVOICE_DISTRIBUTION_ID, EXCHANGE_RATE, INVOICE_DATE, GL_DATE, INVOICE_CURRENCY_CODE, ENTITY_CODE, ENTITY_DESCRIPTION, COST_CENTER_CODE, BUDGET_CODE, ACCOUNT_CODE, ACTIVITY_CODE, FUTURE1_CODE, FUTURE2_CODE, PO_NUMBER, INVOICE_DIST_AMOUNT, INVOICE_DIST_BASE_AMOUNT, TERMS_DATE, PAY_GROUP_LOOKUP_CODE, PAYMENT_METHOD_CODE, PAYMENT_TERM, TAX_AMOUNT, RECEIPT_NUMBER, INVOICE_SUBMISSION_DATE, INVOICE_APPROVED_DATE, PAYMENT_DATE, RECEIPT_DATE, INVOICE_RECEIVED_DATE, WFAPPROVAL_STATUS, ACCOUNTED, LINE_TYPE, TAX_RATE_NAME, TAX_RATE, RECOVERABLE_TAX_AMOUNT, NON_RECOVERABLE_TAX_AMOUNT, PAYMENT_STATUS_FLAG, ENCUMBERED_FLAG, DUE_DATE]
# Index: []
#
# [0 rows x 48 columns]

# %%
df_AP_duplicate = df_AP_invoices[(df_AP_invoices.duplicated(['VENDOR_NO','INVOICE_NUM','INVOICE_DESCRIPTION'])) & (df_AP_invoices['INVOICE_APPROVAL_STATUS'] == "APPROVED")]
df_AP_duplicate
# Out:
#          LEDGER_NAME  VENDOR_NO  \
# 1        KUST Ledger      64998
# 2        KUST Ledger      64998
# 4        KUST Ledger      82641
# 5        KUST Ledger      82641
# 6        KUST Ledger      82641
# ...              ...        ...
# 487974   KUST Ledger      98330
# 487977  KUX - Ledger      58199
# 487978  KUX - Ledger      58199
# 487980  KUX - Ledger      58199
# 487981  KUX - Ledger      58199
#
#                                               VENDOR_NAME  VENDOR_TYPE  \
# 1       MINISTRY OF HIGHER EDUCATION & SCIENTIFIC RESE...       VENDOR
# 2       MINISTRY OF HIGHER EDUCATION & SCIENTIFIC RESE...       VENDOR
# 4                                            VIKAS MITTAL  BENIFICIARY
# 5                                            VIKAS MITTAL  BENIFICIARY
# 6                                            VIKAS MITTAL  BENIFICIARY
# ...                                                   ...          ...
# 487974                               ETAP AUTOMATION DMCC       VENDOR
# 487977                           ALLIANCE GLOBAL FZ - LLC       VENDOR
# 487978                           ALLIANCE GLOBAL FZ - LLC       VENDOR
# 487980                           ALLIANCE GLOBAL FZ - LLC       VENDOR
# 487981                           ALLIANCE GLOBAL FZ - LLC       VENDOR
#
#        INVOICE_NUM VOUCHER_NUM INVOICE_APPROVAL_STATUS INVOICE_TYPE  \
# 1         29052019  8471027936                APPROVED     STANDARD
# 2         29052019  8471027936                APPROVED     STANDARD
# 4       PR20193499  8471028118                APPROVED     STANDARD
# 5       PR20193499  8471028118                APPROVED     STANDARD
# 6       PR20193499  8471028118                APPROVED     STANDARD
# ...            ...         ...                     ...          ...
# 487974    18042021  8471056358                APPROVED     STANDARD
# 487977   202106165  843X007976                APPROVED     STANDARD
# 487978   202106165  843X007976                APPROVED     STANDARD
# 487980   202105753  843X007977                APPROVED     STANDARD
# 487981   202105753  843X007977                APPROVED     STANDARD
#
#                                       INVOICE_DESCRIPTION CREATION_DATE  ...  \
# 1       Accreditation charges- Doctor of Med Program (...    2019-08-18  ...
# 2       Accreditation charges- Doctor of Med Program (...    2019-08-18  ...
# 4                                 RELOCATION VIKAS MITTAL    2019-08-27  ...
# 5                                 RELOCATION VIKAS MITTAL    2019-08-27  ...
# 6                                 RELOCATION VIKAS MITTAL    2019-08-27  ...
# ...                                                   ...           ...  ...
# 487974  PMR20212184-Renewal: ETAP - Educational Licens...    2021-05-16  ...
# 487977                                                NaN    2021-06-08  ...
# 487978                                                NaN    2021-06-08  ...
# 487980                                                NaN    2021-06-08  ...
# 487981                                                NaN    2021-06-08  ...
#
#         WFAPPROVAL_STATUS  ACCOUNTED  LINE_TYPE        TAX_RATE_NAME TAX_RATE  \
# 1            NOT REQUIRED        Yes        TAX       NOT APPLICABLE      0.0
# 2            NOT REQUIRED        Yes        TAX       NOT APPLICABLE      0.0
# 4            NOT REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
# 5            NOT REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
# 6            NOT REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
# ...                   ...        ...        ...                  ...      ...
# 487974       NOT REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
# 487977       NOT REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
# 487978       NOT REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
# 487980       NOT REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
# 487981       NOT REQUIRED        Yes        TAX  VAT INPUT STD - REC      5.0
#
#        RECOVERABLE_TAX_AMOUNT  NON_RECOVERABLE_TAX_AMOUNT PAYMENT_STATUS_FLAG  \
# 1                         0.0                         0.0                 Yes
# 2                         0.0                         0.0                 Yes
# 4                         0.0                         0.0                 Yes
# 5                         0.0                         0.0                 Yes
# 6                         0.0                         0.0                 Yes
# ...                       ...                         ...                 ...
# 487974                  642.7                         0.0                 Yes
# 487977                 2250.0                         0.0                 Yes
# 487978                 2250.0                         0.0                 Yes
# 487980                 1125.0                         0.0                 Yes
# 487981                 1125.0                         0.0                 Yes
#
#         ENCUMBERED_FLAG   DUE_DATE
# 1                    No 2019-05-29
# 2                    No 2019-05-29
# 4                    No 2019-08-27
# 5                    No 2019-08-27
# 6                    No 2019-08-27
# ...                 ...        ...
# 487974               No 2021-04-18
# 487977               No 2021-05-25
# 487978               No 2021-05-25
# 487980               No 2021-03-10
# 487981               No 2021-03-10
#
# [355637 rows x 48 columns]

# %%
df_AP_duplicate.to_sql("SameInvoiceNum_SameInvoiceDescription_SameVendor_Approved_Invoice", conn)

# %% [markdown]
# ## 5.4 Purchase Orders

# %% [markdown]
# The below scripts enables IA Department to view all purchase orders created after the approval date of the purchase orders. Two columns utilized are "CREATION_DATE" (date of creation) and "PO_APPROVED_DATE" (date of approval).

# %%
## df_POs = pd.read_excel("C:/users/ku1016/downloads/PO Master.xlsx")
## df_POs.head(5)
# Out:
#     PO_NUMBER AUTHORIZATION_STATUS   PO_TYPE ITEM_CATEGORY  \
# 0  8431200017             APPROVED  STANDARD         23.01
# 1  8431200017             APPROVED  STANDARD         23.01
# 2  8431200017             APPROVED  STANDARD         23.01
# 3  8431200017             APPROVED  STANDARD         23.01
# 4  8431200017             APPROVED  STANDARD         23.01
#
#   ITEM_CATEGORY_DESCRIPTION ITEM_CODE ITEM_DESCRIPTION   GL_ENCUMBERED_DATE  \
# 0          University Books         -              NaN  2017-03-07 15:00:02
# 1          University Books         -              NaN  2017-03-07 15:00:02
# 2          University Books         -              NaN  2017-03-07 15:00:02
# 3          University Books         -              NaN  2017-03-07 15:00:02
# 4          University Books         -              NaN  2017-03-07 15:00:02
#
#          CREATION_DATE ENCUMBERED_AMOUNT  ...  VENDOR_SITE CURRENCY_CODE  \
# 0  2017-03-07 00:00:00               470  ...        DUBAI           AED
# 1  2017-03-07 00:00:00               594  ...        DUBAI           AED
# 2  2017-03-07 00:00:00               777  ...        DUBAI           AED
# 3  2017-03-07 00:00:00            2201.5  ...        DUBAI           AED
# 4  2017-03-07 00:00:00              2543  ...        DUBAI           AED
#
#   AMOUNT_ORDERED QUANTITY_DELIVERED AMOUNT_DELIVERED QUANTITY_BILLED  \
# 0          470.0                1.0            470.0             1.0
# 1          594.0                2.0            594.0             2.0
# 2          777.0                5.0            777.0             5.0
# 3         2201.5                5.0           2201.5             5.0
# 4         2543.0                1.0           2543.0             1.0
#
#   AMOUNT_BILLED QUANTITY_CANCELLED AMOUNT_CANCELLED        VENDOR_COUNTRY
# 0         470.0                0.0              0.0  United Arab Emirates
# 1         594.0                0.0              0.0  United Arab Emirates
# 2         777.0                0.0              0.0  United Arab Emirates
# 3        2201.5                0.0              0.0  United Arab Emirates
# 4        2543.0                0.0              0.0  United Arab Emirates
#
# [5 rows x 56 columns]

# %%
df_POs['Approval'] = df_POs['PO_APPROVED_DATE']-df_POs['CREATION_DATE']

# %%
df_POs.to_sql('Creation_After_Approval', conn)
