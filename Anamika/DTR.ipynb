# %%
import pandas as pd
import numpy as np

# %%
dtr = pd.read_excel('dtr.xlsx',index_col=0)

# %%
dtr = dtr.reset_index(drop=True)

# %%
ap = pd.read_excel('Approved DTRs not in AP data.xlsx',skiprows=2)

# %%
ap.head(1)
# Out:
#           Request No                       Email                Date  \
# 0  DTR12/14/2021-520  suwaidan.alnuaimi@ku.ac.ae 2021-12-14 14:00:00
#
#   Workflow Status Employee Id       Employee Name    Running Workflow Status  \
# 0        Approved       KU406  Suwaidan Al Nuaimi  Approval from HR Services
#
#    Running Workflow Step No Employee Category SamAccountName  ... PO Number  \
# 0                        22             STAFF      salnuaimi  ...       NaN
#
#   SVP or Above CreatePO CreateAPInvoice TotalPaymentToEmployee Travel Agency  \
# 0          NaN       No              No                  350.0           NaN
#
#    DTR Create PO in ADERP DTR Create AP Invoice in ADERP Item Type  \
# 0                     NaN                            NaN      Item
#
#                                                 Path
# 0  sites/Administration/HR/DTR/Lists/DutyTravelRe...
#
# [1 rows x 150 columns]

# %%
ap['DTR'] = [x[0:3] for x in ap['Request No']]

# %%
ap
# Out:
#             Request No                       Email                Date  \
# 0    DTR12/14/2021-520  suwaidan.alnuaimi@ku.ac.ae 2021-12-14 14:00:00
# 1    DTR12/14/2021-519  suwaidan.alnuaimi@ku.ac.ae 2021-12-14 14:00:00
# 2    DTR12/14/2021-518  suwaidan.alnuaimi@ku.ac.ae 2021-12-14 13:00:00
# 3    DTR12/13/2021-512     fatema.alzaabi@ku.ac.ae 2021-12-13 12:00:00
# 4    DTR12/13/2021-511   hafsa.almansoori@ku.ac.ae 2021-12-13 12:00:00
# ..                 ...                         ...                 ...
# 103    DTR7/5/2021-222     narendra.nelli@ku.ac.ae 2021-07-05 13:00:00
# 104   DTR6/22/2021-216      daniel.tonder@ku.ac.ae 2021-06-22 11:00:00
# 105   DTR3/30/2021-178        prasoon.raj@ku.ac.ae 2021-03-30 09:00:00
# 106   DTR3/27/2021-175   shaju.badarudeen@ku.ac.ae 2021-03-27 23:00:00
# 107   DTR2/24/2021-167      pravin.kannan@ku.ac.ae 2021-02-24 17:00:00
#
#     Workflow Status Employee Id                        Employee Name  \
# ...
