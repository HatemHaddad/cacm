# %%
import pandas as pd
import numpy as np
import pyodbc
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
svr_name = 'KU1ICDDWV011.kunet.ae'
db_name_read = 'CACM'
db_name_write = 'CACMP'
u_name = 'cacm_user'
u_pass = 'Welcome#123'

# %%
eng_read = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name_read+"?driver=ODBC+Driver+17+for+SQL+Server")
eng_write = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name_write+"?driver=ODBC+Driver+17+for+SQL+Server")

# %% [markdown]
# # Select statements

# %%
query_po = "select * from dbo.KU_SRC_BI_KUST_PO"
query_ap = "select * from dbo.KU_SRC_BI_KUST_AP"

# %% [markdown]
# # Reading from SQL

# %%
po = pd.read_sql(query_po, eng_read)
ap = pd.read_sql(query_ap, eng_read)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
# ...

# %%
# po.reset_index().to_sql('po',eng_write,if_exists='replace')

# %%
po_c = po.copy()
ap_c = ap.copy()

# %%
po_c = po_c[po_c['CREATION_DATE'] >= '2020-01-01']
ap_c = ap_c[ap_c['CREATION_DATE'] >= '2020-01-01']

# %%
po_c['PO_Total'] = po_c['QUANTITY_ORDERED'] * po_c['UNIT_PRICE']
df_ap = ap_c.groupby('PO_NUMBER').agg({'INVOICE_DIST_AMOUNT':'sum'}).reset_index()
df_po = po_c.groupby('PO_NUMBER').agg({'PO_Total':'sum'}).reset_index()

# %%
ap_vendor = po_c.groupby(['VENDOR_NAME',ap_c['CREATION_DATE'].dt.year]).agg({'PO_Total':'sum'}).reset_index()

# %%
ap_vendor.to_excel('ap_vendor.xlsx')

# %%
po
# Out:
#         PO_NUMBER AUTHORIZATION_STATUS   PO_TYPE ITEM_CATEGORY  \
# 0      8431200017             APPROVED  STANDARD         23.01
# 1      8431200017             APPROVED  STANDARD         23.01
# 2      8431200017             APPROVED  STANDARD         23.01
# 3      8431200017             APPROVED  STANDARD         23.01
# 4      8431200017             APPROVED  STANDARD         23.01
# ...           ...                  ...       ...           ...
# 51048  8472107558             APPROVED  STANDARD         40.31
# 51049  8472107558             APPROVED  STANDARD         40.31
# 51050  8472107558             APPROVED  STANDARD         40.31
# 51051  8472107558             APPROVED  STANDARD         40.31
# 51052  8472107558             APPROVED  STANDARD         40.31
#
#                               ITEM_CATEGORY_DESCRIPTION ITEM_CODE  \
# 0                                      University Books         -
# 1                                      University Books         -
# ...

# %%
po[po['PO_NUMBER'].isin(['8472106738','8472106744','8472106752'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ec39d0541a7> in <module>
# ----> 1 po[po['PO_NUMBER'].isin(['8472106738','8472106744','8472106752'])]
#
# NameError: name 'po' is not defined

# %%
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %pwd
# Out:
# 'C:\\Users\\ku1016\\Desktop\\CACM\\Anamika\\Final'
