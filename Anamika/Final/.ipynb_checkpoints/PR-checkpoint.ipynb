# %%
import pandas as pd
import numpy as np
import pyodbc
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
svr_name = 'KU1ICDDWV011.kunet.ae'
db_name_read = 'CACM'
db_name_write = 'CACMP'
u_name = 'cacm_user'
u_pass = 'Welcome#123'

# %%
eng_read = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name_read+"?driver=ODBC+Driver+17+for+SQL+Server")
eng_write = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name_write+"?driver=ODBC+Driver+17+for+SQL+Server")

# %%
query_pr = "select * from dbo.KU_SRC_BI_KUST_PR"

# %%
pr = pd.read_sql(query_pr, eng_read)

# %%
# pr.reset_index().to_sql('pr',eng_write,if_exists='replace')

# %%
pr
# Out:
#             PR_ID      PR_NUM    PR_CREATION_DATE    PR_APPROVED_DATE  \
# 0      32389640.0  8471108702 2021-07-11 12:10:13 2021-07-11 13:52:24
# 1      32389640.0  8471108702 2021-07-11 12:10:13 2021-07-11 13:52:24
# 2      32376667.0  8471108683 2021-07-07 08:27:12 2021-07-11 11:43:29
# 3      32376667.0  8471108683 2021-07-07 08:27:12 2021-07-11 11:43:29
# 4      32376667.0  8471108683 2021-07-07 08:27:12 2021-07-11 11:43:29
# ...           ...         ...                 ...                 ...
# 50728  33196842.0  8471109436 2022-02-07 13:13:53                 NaT
# 50729  33185748.0  8432102563 2022-02-01 11:37:53 2022-02-04 08:32:52
# 50730  33185748.0  8432102563 2022-02-01 11:37:53 2022-02-04 08:32:52
# 50731  33185748.0  8432102563 2022-02-01 11:37:53 2022-02-04 08:32:52
# 50732  33191819.0  8471109430 2022-02-03 16:01:26 2022-02-07 12:12:32
#
#                                                  PR_DESC  \
# 0      COVARIS microTUBE-50 AFA Fiber Cat# 520166 (Sc...
# 1      COVARIS microTUBE-50 AFA Fiber Cat# 520166 (Sc...
# 2                              Composite Lab Consumables
# 3                              Composite Lab Consumables
# 4                              Composite Lab Consumables
# ...                                                  ...
# 50728  Additional Civil & MEP requirements in wave ta...
# 50729  PCR, 0.2ML, SEMI SKIRTED PLATE (SOLD AS BOX OF...
# 50730  PCR, 0.2ML, SEMI SKIRTED PLATE (SOLD AS BOX OF...
# 50731  PCR, 0.2ML, SEMI SKIRTED PLATE (SOLD AS BOX OF...
# 50732                           Mycoplasma Detection Kit
#
#                             PREPARER                      REQUESTER  \
# 0                         Suna Nazar                     Suna Nazar
# 1                         Suna Nazar                     Suna Nazar
# 2                       Bittu Scaria                   Bittu Scaria
# 3                       Bittu Scaria                   Bittu Scaria
# 4                       Bittu Scaria                   Bittu Scaria
# ...                              ...                            ...
# 50728         Sivadas Velli Pulakkil         Sivadas Velli Pulakkil
# 50729                     Suna Nazar                     Suna Nazar
# 50730                     Suna Nazar                     Suna Nazar
# 50731                     Suna Nazar                     Suna Nazar
# 50732  Manal Khalil Ali Abu-Al Haija  Manal Khalil Ali Abu-Al Haija
#
#       PR_ASSIGNED_DATE                            ASSIGNED_BUYER  \
# 0           2021-07-24                  Mohamed Alawi Zain Alkaf
# 1           2021-07-24                  Mohamed Alawi Zain Alkaf
# 2           2021-07-24                    Mohamed Saleh Alhashmi
# 3           2021-07-24                    Mohamed Saleh Alhashmi
# 4           2021-07-24                    Mohamed Saleh Alhashmi
# ...                ...                                       ...
# 50728       2022-02-07                                      None
# 50729       2022-02-07  Moneirah Khameis Salem Saeed Al Mazrouei
# 50730       2022-02-07  Moneirah Khameis Salem Saeed Al Mazrouei
# 50731       2022-02-07  Moneirah Khameis Salem Saeed Al Mazrouei
# 50732       2022-02-07      Nayfa Abdulla Ahmed Awana Al Masaabi
#
#       ITEM_CATEGORY  ... DISTRIBUTION_NUM UNIT_PRICE CURRENCY_CODE RATE  \
# 0         4112.1216  ...              1.0    3197.92           AED  NaN
# 1         4112.1216  ...              1.0     973.22           AED  NaN
# 2         2700.0003  ...              1.0     338.00           AED  NaN
# 3         2700.0003  ...              1.0       1.50           AED  NaN
# 4         2700.0003  ...              1.0      65.00           AED  NaN
# ...             ...  ...              ...        ...           ...  ...
# 50728     8888.8802  ...              1.0        NaN           AED  NaN
# 50729     4112.1216  ...              1.0     625.00           AED  NaN
# 50730     4112.1216  ...              1.0     721.67           AED  NaN
# 50731     4112.1216  ...              1.0     396.22           AED  NaN
# 50732     0000.0000  ...              1.0    3200.00           AED  NaN
#
#       PR_QUANTITY  PR_AMOUNT  PR_APPROVAL_STATUS PR_FINAL_CLOSE_STATUS  \
# 0             2.0    6395.84            APPROVED                  OPEN
# 1            40.0   38928.80            APPROVED                  OPEN
# 2             3.0    1014.00            APPROVED                  OPEN
# 3           100.0     150.00            APPROVED                  OPEN
# 4             5.0     325.00            APPROVED                  OPEN
# ...           ...        ...                 ...                   ...
# 50728         NaN  250000.00          IN PROCESS                  OPEN
# 50729         3.0    1875.00            APPROVED                  OPEN
# 50730        30.0   21650.10            APPROVED                  OPEN
# 50731         1.0     396.22            APPROVED                  OPEN
# 50732         2.0    6400.00            APPROVED                  OPEN
#
#       PR_ENCUMBERED_AMOUNT   LEDGER_NAME
# 0                     0.00   KUST Ledger
# 1                     0.00   KUST Ledger
# 2                     0.00   KUST Ledger
# 3                     0.00   KUST Ledger
# 4                     0.00   KUST Ledger
# ...                    ...           ...
# 50728            250000.00   KUST Ledger
# 50729              1875.00  KUX - Ledger
# 50730             21650.10  KUX - Ledger
# 50731               396.22  KUX - Ledger
# 50732              6400.00   KUST Ledger
#
# [50733 rows x 45 columns]
