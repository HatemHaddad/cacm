# %%
import pandas as pd
import numpy as np
import pyodbc
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import datetime as dt

# %%
svr_name = 'KU1ICDDWV011.kunet.ae'
db_name_read = 'CACM'
db_name_write = 'CACMP'
u_name = 'cacm_user'
u_pass = 'Welcome#123'

# %%
eng_read = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name_read+"?driver=ODBC+Driver+17+for+SQL+Server")
eng_write = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name_write+"?driver=ODBC+Driver+17+for+SQL+Server")

# %%
query_pr = "select * from dbo.KU_SRC_BI_KUST_PR"
query_po = "select * from dbo.KU_SRC_BI_KUST_PO"
query_ap = "select * from dbo.KU_SRC_BI_KUST_ap"

# %%
pr = pd.read_sql(query_pr, eng_read)
po = pd.read_sql(query_po, eng_read)
ap = pd.read_sql(query_ap, eng_read)

# %%
#po.reset_index().to_sql('po',eng_write,if_exists='replace')

# %%
# ap['VENDOR_NAME'] = ap['VENDOR_NAME'].str.lower()

# %%
# ap = ap[ap['CREATION_DATE'] >= '2021-01-01']

# %%
# ap[ap['VENDOR_NAME'].str.contains('center')].to_excel('center.xlsx')

# %%
po = po[['COST_CENTER_DESC','LEDGER_NAME','PO_NUMBER','VENDOR_NAME','CREATION_DATE','AMOUNT_ORDERED']]

# %%
po = po[po['CREATION_DATE'] >= '2021-01-01']

# %%
#po['CREATION_DATE'] = po['CREATION_DATE'].dt.strftime('%Y-%m')

# %%
po
# Out:
#                                 COST_CENTER_DESC  LEDGER_NAME   PO_NUMBER  \
# 5659                KUST - Research Laboratories  KUST Ledger  8472100155
# 6147   KUST - SVP/ Research & Development Office  KUST Ledger  8472100198
# 6148   KUST - SVP/ Research & Development Office  KUST Ledger  8472100198
# 6149   KUST - SVP/ Research & Development Office  KUST Ledger  8472100198
# 6150   KUST - SVP/ Research & Development Office  KUST Ledger  8472100198
# ...                                          ...          ...         ...
# 51048       KUST - University Sponsored Research  KUST Ledger  8472107558
# 51049       KUST - University Sponsored Research  KUST Ledger  8472107558
# 51050       KUST - University Sponsored Research  KUST Ledger  8472107558
# 51051       KUST - University Sponsored Research  KUST Ledger  8472107558
# 51052       KUST - University Sponsored Research  KUST Ledger  8472107558
#
#                                              VENDOR_NAME CREATION_DATE  \
# 5659   EMIRATES SCIENTIFIC & TECHNICAL SUPPLIES (LLC)...    2022-02-08
# 6147   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...    2021-12-21
# 6148   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...    2021-12-21
# 6149   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...    2021-12-21
# 6150   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...    2021-12-21
# ...                                                  ...           ...
# 51048                     ZHENGZHOU KEJIA FURNACE CO.LTD    2021-11-01
# 51049                     ZHENGZHOU KEJIA FURNACE CO.LTD    2021-11-01
# 51050                     ZHENGZHOU KEJIA FURNACE CO.LTD    2021-11-01
# 51051                     ZHENGZHOU KEJIA FURNACE CO.LTD    2021-11-01
# 51052                     ZHENGZHOU KEJIA FURNACE CO.LTD    2021-11-01
#
#       CURRENCY_CODE  AMOUNT_ORDERED  AMOUNT_BILLED
# 5659            AED         2975.00           0.00
# 6147            AED         5000.00        5000.00
# 6148            AED         5000.00           0.00
# 6149            AED        10162.87       10162.87
# 6150            AED        10162.87           0.00
# ...             ...             ...            ...
# 51048           USD          200.00           0.00
# 51049           USD         1330.00           0.00
# 51050           USD         1330.00           0.00
# 51051           USD          600.00           0.00
# 51052           USD          600.00           0.00
#
# [7402 rows x 8 columns]

# %%
df3 = po.sort_values(by=['VENDOR_NAME','CREATION_DATE'],ascending=[True,False])

# %%
df3.drop_duplicates()
# Out:
#         LEDGER_NAME   PO_NUMBER  \
# 48893   KUST Ledger  8472106744
# 45481   KUST Ledger  8472106744
# 49741  KUX - Ledger  8472106744
# 37721   KUST Ledger  8472106744
# 37722   KUST Ledger  8472106744
# ...             ...         ...
# 45401   KUST Ledger  8472106744
# 46261   KUST Ledger  8472106744
# 46262   KUST Ledger  8472106744
# 48372   KUST Ledger  8472106744
# 44641   KUST Ledger  8472106744
#
#                                              VENDOR_NAME CREATION_DATE  \
# 48893          SHAMS SYSTEMS AND TECHNOLOGIES CO. W.L.L.       2021-06
# 45481                                  A U M TRADING LLC       2021-10
# 49741  ABU DHABI NATIONAL HOTELS COMPANY - COMPASS MI...       2021-10
# 37721  ABU DHABI NATIONAL HOTELS COMPANY - COMPASS MI...       2021-06
# 37722  ABU DHABI NATIONAL HOTELS COMPANY - COMPASS MI...       2021-06
# ...                                                  ...           ...
# 45401                                     samsung.com/ae       2021-10
# 46261                                www.fusoseiki.co.jp       2021-08
# 46262                                www.fusoseiki.co.jp       2021-08
# 48372                                    www.ossila.com/       2021-08
# 44641                                               None       2022-02
#
#       CURRENCY_CODE  AMOUNT_ORDERED  AMOUNT_BILLED
# 48893           USD         3400.00        3400.00
# 45481           AED        11000.00       11000.00
# 49741           AED        63600.00       63600.00
# 37721           AED        65518.00       63775.50
# 37722           AED        64345.88       16549.39
# ...             ...             ...            ...
# 45401           AED         4199.00        4199.00
# 46261           USD           34.20           0.00
# 46262           USD          139.30           0.00
# 48372           EUR         2070.00        2070.00
# 44641           AED      1219986.00           0.00
#
# [6088 rows x 7 columns]

# %%
# %pwd
# Out:
# 'C:\\Users\\ku1016\\Desktop\\CACM\\Anamika\\Final'

# %%
df3
# Out:
#         LEDGER_NAME   PO_NUMBER  \
# 48893   KUST Ledger  8472106878
# 45481   KUST Ledger  8472107482
# 49741  KUX - Ledger  8432201957
# 37721   KUST Ledger  8472105862
# 37722   KUST Ledger  8472105862
# ...             ...         ...
# 46261   KUST Ledger  8472107243
# 46262   KUST Ledger  8472107243
# 46263   KUST Ledger  8472107243
# 48372   KUST Ledger  8472107097
# 44641   KUST Ledger  8472107754
#
#                                              VENDOR_NAME CREATION_DATE  \
# 48893          SHAMS SYSTEMS AND TECHNOLOGIES CO. W.L.L.       2021-06
# 45481                                  A U M TRADING LLC       2021-10
# 49741  ABU DHABI NATIONAL HOTELS COMPANY - COMPASS MI...       2021-10
# 37721  ABU DHABI NATIONAL HOTELS COMPANY - COMPASS MI...       2021-06
# 37722  ABU DHABI NATIONAL HOTELS COMPANY - COMPASS MI...       2021-06
# ...                                                  ...           ...
# 46261                                www.fusoseiki.co.jp       2021-08
# 46262                                www.fusoseiki.co.jp       2021-08
# 46263                                www.fusoseiki.co.jp       2021-08
# 48372                                    www.ossila.com/       2021-08
# 44641                                               None       2022-02
#
#       CURRENCY_CODE  AMOUNT_ORDERED  AMOUNT_BILLED
# 48893           USD         3400.00        3400.00
# 45481           AED        11000.00       11000.00
# 49741           AED        63600.00       63600.00
# 37721           AED        65518.00       63775.50
# 37722           AED        64345.88       16549.39
# ...             ...             ...            ...
# 46261           USD           34.20           0.00
# 46262           USD          139.30           0.00
# 46263           USD          139.30           0.00
# 48372           EUR         2070.00        2070.00
# 44641           AED      1219986.00           0.00
#
# [7402 rows x 7 columns]

# %%
df3[df3.duplicated()]
# Out:
#         LEDGER_NAME   PO_NUMBER                              VENDOR_NAME  \
# 50107  KUX - Ledger  8472106744                     ACROSS INTERNATIONAL
# 50109  KUX - Ledger  8472106744                     ACROSS INTERNATIONAL
# 50111  KUX - Ledger  8472106744                     ACROSS INTERNATIONAL
# 45406   KUST Ledger  8472106744  AESTHETIX COMMUNICATION TECHNOLOGES LLC
# 45411   KUST Ledger  8472106744  AESTHETIX COMMUNICATION TECHNOLOGES LLC
# ...             ...         ...                                      ...
# 51050   KUST Ledger  8472106744           ZHENGZHOU KEJIA FURNACE CO.LTD
# 51051   KUST Ledger  8472106744           ZHENGZHOU KEJIA FURNACE CO.LTD
# 51052   KUST Ledger  8472106744           ZHENGZHOU KEJIA FURNACE CO.LTD
# 45688   KUST Ledger  8472106744         https://www.desertcart.ae/orders
# 46263   KUST Ledger  8472106744                      www.fusoseiki.co.jp
#
#       CREATION_DATE CURRENCY_CODE  AMOUNT_ORDERED  AMOUNT_BILLED
# 50107       2021-12           USD          6651.0            0.0
# 50109       2021-12           USD           531.0            0.0
# 50111       2021-12           USD          1705.0            0.0
# 45406       2021-10           AED         33920.0        33920.0
# 45411       2021-10           AED          7500.0         7500.0
# ...             ...           ...             ...            ...
# 51050       2021-11           USD          1330.0            0.0
# 51051       2021-11           USD           600.0            0.0
# 51052       2021-11           USD           600.0            0.0
# 45688       2021-04           AED          1530.0            0.0
# 46263       2021-08           USD           139.3            0.0
#
# [1314 rows x 7 columns]

# %%
df3['PO_NUMBER']
# Out:
# 48893    8472106744
# 45481    8472106744
# 49741    8472106744
# 37721    8472106744
# 37722    8472106744
#             ...
# 46261    8472106744
# 46262    8472106744
# 46263    8472106744
# 48372    8472106744
# 44641    8472106744
# Name: PO_NUMBER, Length: 7402, dtype: object

# %%
df3
# Out:
#         LEDGER_NAME   PO_NUMBER  \
# 48893   KUST Ledger  8472106744
# 45481   KUST Ledger  8472106744
# 49741  KUX - Ledger  8472106744
# 37721   KUST Ledger  8472106744
# 37722   KUST Ledger  8472106744
# ...             ...         ...
# 46261   KUST Ledger  8472106744
# 46262   KUST Ledger  8472106744
# 46263   KUST Ledger  8472106744
# 48372   KUST Ledger  8472106744
# 44641   KUST Ledger  8472106744
#
#                                              VENDOR_NAME CREATION_DATE  \
# 48893          SHAMS SYSTEMS AND TECHNOLOGIES CO. W.L.L.       2021-06
# 45481                                  A U M TRADING LLC       2021-10
# 49741  ABU DHABI NATIONAL HOTELS COMPANY - COMPASS MI...       2021-10
# 37721  ABU DHABI NATIONAL HOTELS COMPANY - COMPASS MI...       2021-06
# 37722  ABU DHABI NATIONAL HOTELS COMPANY - COMPASS MI...       2021-06
# ...                                                  ...           ...
# 46261                                www.fusoseiki.co.jp       2021-08
# 46262                                www.fusoseiki.co.jp       2021-08
# 46263                                www.fusoseiki.co.jp       2021-08
# 48372                                    www.ossila.com/       2021-08
# 44641                                               None       2022-02
#
#       CURRENCY_CODE  AMOUNT_ORDERED  AMOUNT_BILLED
# 48893           USD         3400.00        3400.00
# 45481           AED        11000.00       11000.00
# 49741           AED        63600.00       63600.00
# 37721           AED        65518.00       63775.50
# 37722           AED        64345.88       16549.39
# ...             ...             ...            ...
# 46261           USD           34.20           0.00
# 46262           USD          139.30           0.00
# 46263           USD          139.30           0.00
# 48372           EUR         2070.00        2070.00
# 44641           AED      1219986.00           0.00
#
# [7402 rows x 7 columns]

# %%
po
# Out:
#        LEDGER_NAME   PO_NUMBER  \
# 5659   KUST Ledger  8472100155
# 6147   KUST Ledger  8472100198
# 6148   KUST Ledger  8472100198
# 6149   KUST Ledger  8472100198
# 6150   KUST Ledger  8472100198
# ...            ...         ...
# 51048  KUST Ledger  8472107558
# 51049  KUST Ledger  8472107558
# 51050  KUST Ledger  8472107558
# 51051  KUST Ledger  8472107558
# 51052  KUST Ledger  8472107558
#
#                                              VENDOR_NAME CREATION_DATE  \
# 5659   EMIRATES SCIENTIFIC & TECHNICAL SUPPLIES (LLC)...       2022-02
# 6147   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...       2021-12
# 6148   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...       2021-12
# 6149   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...       2021-12
# 6150   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...       2021-12
# ...                                                  ...           ...
# 51048                     ZHENGZHOU KEJIA FURNACE CO.LTD       2021-11
# 51049                     ZHENGZHOU KEJIA FURNACE CO.LTD       2021-11
# 51050                     ZHENGZHOU KEJIA FURNACE CO.LTD       2021-11
# 51051                     ZHENGZHOU KEJIA FURNACE CO.LTD       2021-11
# 51052                     ZHENGZHOU KEJIA FURNACE CO.LTD       2021-11
#
#       CURRENCY_CODE  AMOUNT_ORDERED  AMOUNT_BILLED
# 5659            AED         2975.00           0.00
# 6147            AED         5000.00        5000.00
# 6148            AED         5000.00           0.00
# 6149            AED        10162.87       10162.87
# 6150            AED        10162.87           0.00
# ...             ...             ...            ...
# 51048           USD          200.00           0.00
# 51049           USD         1330.00           0.00
# 51050           USD         1330.00           0.00
# 51051           USD          600.00           0.00
# 51052           USD          600.00           0.00
#
# [7107 rows x 7 columns]

# %%
po.to_excel('po_h.xlsx')

# %%
pr.to_excel('pr_h.xlsx')

# %%
ap.to_excel('ap_h.xlsx')

# %%
p = po.copy()

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51053 entries, 0 to 51052
# Data columns (total 56 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PO_NUMBER                  51053 non-null  object
#  1   AUTHORIZATION_STATUS       51030 non-null  object
#  2   PO_TYPE                    51053 non-null  object
#  3   ITEM_CATEGORY              51053 non-null  object
#  4   ITEM_CATEGORY_DESCRIPTION  51052 non-null  object
#  5   ITEM_CODE                  51053 non-null  object
#  6   ITEM_DESCRIPTION           114 non-null    object
#  7   GL_ENCUMBERED_DATE         51053 non-null  datetime64[ns]
#  8   CREATION_DATE              51053 non-null  object
#  9   ENCUMBERED_AMOUNT          44843 non-null  float64
#  10  QUANTITY_ORDERED           43068 non-null  float64
#  11  REQUISITION_NUM            34746 non-null  object
#  12  RATE                       51053 non-null  float64
#  13  LINE_NUM                   51053 non-null  float64
#  14  DISTRIBUTION_NUM           51053 non-null  float64
#  15  UNIT_PRICE                 48590 non-null  float64
#  16  VENDOR_ID                  51044 non-null  float64
#  17  CLOSED_CODE                50600 non-null  object
#  18  ENTITY_CODE                51053 non-null  object
#  19  ENTITY_DESCRIPTION         51053 non-null  object
#  20  LEDGER_NAME                51053 non-null  object
#  21  PROJECT_NUM                22398 non-null  object
#  22  PROJECT_NAME               22398 non-null  object
#  23  PO_SUBMISION_DATE          50298 non-null  datetime64[ns]
#  24  PO_APPROVED_DATE           49193 non-null  datetime64[ns]
#  25  PROMISED_DATE              39034 non-null  datetime64[ns]
#  26  NEED_BY_DATE               30689 non-null  datetime64[ns]
#  27  PO_DESCRIPTION             26459 non-null  object
#  28  PO_LINE_DESCRIPTION        51053 non-null  object
#  29  PO_BUYER                   51053 non-null  object
#  30  COST_CENTER_CODE           51053 non-null  object
#  31  COST_CENTER_DESC           51053 non-null  object
#  32  BUDGET_CODE                51053 non-null  object
#  33  BUDGET_DESC                51053 non-null  object
#  34  ACCOUNT_CODE               51053 non-null  object
#  35  ACCOUNT_DESC               51053 non-null  object
#  36  ACTIVITY_CODE              51053 non-null  object
#  37  ACTIVITY_DESC              51053 non-null  object
#  38  FUTURE1_CODE               51053 non-null  object
#  39  FUTURE1_DESC               51053 non-null  object
#  40  FUTURE2_CODE               51053 non-null  object
#  41  FUTURE2_DESC               51053 non-null  object
#  42  GL_CODE                    51053 non-null  object
#  43  GL_DESC                    51053 non-null  object
#  44  VENDOR_NUM                 51044 non-null  object
#  45  VENDOR_NAME                51044 non-null  object
#  46  VENDOR_SITE                51044 non-null  object
#  47  CURRENCY_CODE              51053 non-null  object
#  48  AMOUNT_ORDERED             51052 non-null  float64
#  49  QUANTITY_DELIVERED         51053 non-null  float64
#  50  AMOUNT_DELIVERED           50649 non-null  float64
#  51  QUANTITY_BILLED            51053 non-null  float64
#  52  AMOUNT_BILLED              50552 non-null  float64
#  53  QUANTITY_CANCELLED         50503 non-null  float64
#  54  AMOUNT_CANCELLED           49331 non-null  float64
#  55  VENDOR_COUNTRY             51044 non-null  object
# dtypes: datetime64[ns](5), float64(14), object(37)
# memory usage: 21.8+ MB

# %%
p_1 = p[['PO_BUYER','COST_CENTER_DESC','LEDGER_NAME','PO_NUMBER','REQUISITION_NUM','PO_LINE_DESCRIPTION','VENDOR_NAME','CREATION_DATE','AMOUNT_ORDERED']]

# %%
p_2 = p_1[p_1['CREATION_DATE'] >= '2021-01-01']

# %%
p_2
# Out:
#                                     PO_BUYER  \
# 5659                      Mariam Al Baloushi
# 6147              Alzouhra Sulaiman Al Tauil
# 6148              Alzouhra Sulaiman Al Tauil
# 6149              Alzouhra Sulaiman Al Tauil
# 6150              Alzouhra Sulaiman Al Tauil
# ...                                      ...
# 51048  Kanna Saeed Mubarak Balqatri AlKhyeli
# 51049  Kanna Saeed Mubarak Balqatri AlKhyeli
# 51050  Kanna Saeed Mubarak Balqatri AlKhyeli
# 51051  Kanna Saeed Mubarak Balqatri AlKhyeli
# 51052  Kanna Saeed Mubarak Balqatri AlKhyeli
#
#                                 COST_CENTER_DESC  LEDGER_NAME   PO_NUMBER  \
# 5659                KUST - Research Laboratories  KUST Ledger  8472100155
# 6147   KUST - SVP/ Research & Development Office  KUST Ledger  8472100198
# 6148   KUST - SVP/ Research & Development Office  KUST Ledger  8472100198
# 6149   KUST - SVP/ Research & Development Office  KUST Ledger  8472100198
# 6150   KUST - SVP/ Research & Development Office  KUST Ledger  8472100198
# ...                                          ...          ...         ...
# 51048       KUST - University Sponsored Research  KUST Ledger  8472107558
# 51049       KUST - University Sponsored Research  KUST Ledger  8472107558
# 51050       KUST - University Sponsored Research  KUST Ledger  8472107558
# 51051       KUST - University Sponsored Research  KUST Ledger  8472107558
# 51052       KUST - University Sponsored Research  KUST Ledger  8472107558
#
#       REQUISITION_NUM                                PO_LINE_DESCRIPTION  \
# 5659             None  S/5130/53 Sodium Iodide AR Fisher UK Calcium C...
# 6147             None                            PC end-user station-40%
# 6148             None                            PC end-user station-40%
# 6149             None               Mobile access ladder to the deck 40%
# 6150             None               Mobile access ladder to the deck 40%
# ...               ...                                                ...
# 51048      8471108959                                Thermocouple-K type
# 51049            None                         KJ-T1200-PGEP Tube furnace
# 51050      8471108959                         KJ-T1200-PGEP Tube furnace
# 51051            None                                Tube furnace holder
# 51052      8471108959                                Tube furnace holder
#
#                                              VENDOR_NAME CREATION_DATE  \
# 5659   EMIRATES SCIENTIFIC & TECHNICAL SUPPLIES (LLC)...       2022-02
# 6147   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...       2021-12
# 6148   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...       2021-12
# 6149   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...       2021-12
# 6150   AL GHANEM TRADING & CONTRACTING CO. - DUBAI BR...       2021-12
# ...                                                  ...           ...
# 51048                     ZHENGZHOU KEJIA FURNACE CO.LTD       2021-11
# 51049                     ZHENGZHOU KEJIA FURNACE CO.LTD       2021-11
# 51050                     ZHENGZHOU KEJIA FURNACE CO.LTD       2021-11
# 51051                     ZHENGZHOU KEJIA FURNACE CO.LTD       2021-11
# 51052                     ZHENGZHOU KEJIA FURNACE CO.LTD       2021-11
#
#        AMOUNT_ORDERED
# 5659          2975.00
# 6147          5000.00
# 6148          5000.00
# 6149         10162.87
# 6150         10162.87
# ...               ...
# 51048          200.00
# 51049         1330.00
# 51050         1330.00
# 51051          600.00
# 51052          600.00
#
# [7107 rows x 9 columns]

# %%
p3 = p_2.drop_duplicates(subset=['LEDGER_NAME','PO_NUMBER','VENDOR_NAME','AMOUNT_ORDERED'])

# %%
gg = p3.groupby(['VENDOR_NAME','PO_NUMBER','LEDGER_NAME','CREATION_DATE'])['AMOUNT_ORDERED'].sum()

# %%
p3[p3['PO_NUMBER'] == '8472107401']
# Out:
#        LEDGER_NAME   PO_NUMBER REQUISITION_NUM  \
# 45234  KUST Ledger  8472107401      8471109127
# 45235  KUST Ledger  8472107401      8471109127
# 45236  KUST Ledger  8472107401      8471109127
# 45237  KUST Ledger  8472107401      8471109127
# 45238  KUST Ledger  8472107401      8471109127
# 45239  KUST Ledger  8472107401      8471109127
# 45240  KUST Ledger  8472107401      8471109127
# 45241  KUST Ledger  8472107401      8471109127
# 45242  KUST Ledger  8472107401      8471109127
# 45243  KUST Ledger  8472107401      8471109127
# 45244  KUST Ledger  8472107401      8471109127
# 45245  KUST Ledger  8472107401      8471109127
# 45246  KUST Ledger  8472107401      8471109127
# 45247  KUST Ledger  8472107401      8471109127
# 45248  KUST Ledger  8472107401      8471109127
# 45249  KUST Ledger  8472107401      8471109127
# 45250  KUST Ledger  8472107401      8471109127
# 45252  KUST Ledger  8472107401      8471109127
# 45253  KUST Ledger  8472107401      8471109127
# 45254  KUST Ledger  8472107401      8471109127
# 45255  KUST Ledger  8472107401      8471109127
# 45256  KUST Ledger  8472107401      8471109127
# 45257  KUST Ledger  8472107401      8471109127
# 45258  KUST Ledger  8472107401      8471109127
# 45259  KUST Ledger  8472107401      8471109127
# 45260  KUST Ledger  8472107401      8471109127
# 45261  KUST Ledger  8472107401      8471109127
# 45262  KUST Ledger  8472107401      8471109127
# 45263  KUST Ledger  8472107401      8471109127
# 45264  KUST Ledger  8472107401      8471109127
# 45265  KUST Ledger  8472107401      8471109127
# 45266  KUST Ledger  8472107401      8471109127
# 45267  KUST Ledger  8472107401      8471109127
# 45268  KUST Ledger  8472107401      8471109127
# 45269  KUST Ledger  8472107401      8471109127
# 45270  KUST Ledger  8472107401      8471109127
# 45271  KUST Ledger  8472107401      8471109127
# 45272  KUST Ledger  8472107401      8471109127
# 45273  KUST Ledger  8472107401      8471109127
# 45274  KUST Ledger  8472107401      8471109127
# 45275  KUST Ledger  8472107401      8471109127
# 45276  KUST Ledger  8472107401      8471109127
# 45277  KUST Ledger  8472107401      8471109127
# 45278  KUST Ledger  8472107401      8471109127
# 45279  KUST Ledger  8472107401      8471109127
# 45280  KUST Ledger  8472107401      8471109127
# 45282  KUST Ledger  8472107401      8471109127
# 45283  KUST Ledger  8472107401      8471109127
# 45284  KUST Ledger  8472107401      8471109127
# 45285  KUST Ledger  8472107401      8471109127
#
#                                      PO_LINE_DESCRIPTION  \
# 45234  050-004738 LIPTON YELLOW LABEL TEA-  BOX OF 10...
# 45235  050-004711 DISPOSABLE FOAM PLATE 7”(BAG OF 25/...
# 45236  050-004712 DISPOSABLE FOAM PLATE 9” (BAG OF 25...
# 45237  050-004714 DISPOSABLE PAPER CUP / FOAM CUP 6OZ...
# 45238      050-004715 DISPOSABLE SPOONS (BAG OF 50/PKTS)
# 45239  050-004716 DISPOSABLE WATER CUP, PLASTIC (BAG ...
# 45240                            050-004718 FRESH GINGER
# 45241                     050-004719 FRESH JUICE 1.5 LTR
# 45242                             050-004720 FRESH LEMON
# 45243   050-004721 FRESH MILK (FULL CREAM, LOW FAT) 2LTR
# 45244                              050-004722 FRESH MINT
# 45245                             050-004725 HONEY 400ML
# 45246  050-004736 LIPTON GREEN TEA - BOX OF 100 TEA BAGS
# 45247                        050-004737 LIPTON LOOSE TEA
# 45248              050-004739 LIQUID - DISH WASH (750ML)
# 45249               050-004740 LIQUID -HAND WASH (500ML)
# 45250  050-004741 LONG LIFE FULL FAT MILK-1 LTR (AL M...
# 45252            050-004744 MANSOUR - TURKISH COFFEE 1KG
# 45253             050-004745 MANSOUR -ARABIC COFFEE  1KG
# 45254                      050-004747 NESCAFE GOLD 200GM
# 45255                    050-004748 NESCAFE RED MUG 200G
# 45256                  050-004750 PERRIER WATER 24X200ML
# 45257      050-004752 RAIN BOW MILK CANS OF 160ML (1X96)
# 45258             050-004754 SAFFRON TAJ MAHAL BOX OF 4G
# 45259  050-004755 SOFT DRINKS - COCA COLA LIGHT  (330ML)
# 45260          050-004756 SOFT DRINKS -ZERO COKE (330ML)
# 45261  050-004757 SOFT DRINKS-ASSORTED(7UP, SPRITE, D...
# 45262             050-004765 SUGAR-FINE GRANULATED - 2KG
# 45263        050-004768 TISSUE FINE 200X2 PLY BOX (1X40)
# 45264                        050-004769 TISSUE ROLL MAXI
# 45265  050-004771 TROPICANA SLIM SWEETNER - BOX OF 10...
# 45266         050-004772 TWINING GREEN TEA WITH MINT 25G
# 45267  050-004773 TWININGS - PEPPERMINT TEA - BOX OF ...
# 45268  050-004774 TWININGS -LEMON GINGER TEA - BOX OF...
# 45269           050-004777 ZAATAR TEA BOX OF 25 TEA BAGS
# 45270  050-004776 TWININGS/ALOKOZAY -LEMON TEA - BOX ...
# 45271                  050-004709 DIAMOND-ALUMINIUM FOIL
# 45272       050-004713 DISPOSABLE FORKS (BAG OF 50/PKTS)
# 45273                  050-004708 DIAMOND CLING FILM-300
# 45274                        050-004753 ROSE WATER 400ML
# 45275                          060-002939 EARLY GREY TEA
# 45276  050-004746 MICROWAVE OVEN- 23LTR(MIDEA / BLACK...
# 45277                   050-004763 STEEL TEA POT (SMALL)
# 45278                   050-004764 STEEL TEA SPOON (1X6)
# 45279           050-004726 HOT PLATE DOUBLE SPIRAL-2000W
# 45280          050-004728 KETTLE - PHILIPS/BLACK & DECOR
# 45282                     050-004767 THERMOS FLASK (1 L)
# 45283             050-004697 CARDAMOM PODS (BAG OF 250G)
# 45284                050-004699 COFFEE MATE 400GM (1X15)
# 45285  050-004710 DISH WASH SPONGE -SCOTCH BRITE (10C...
#
#                                              VENDOR_NAME CREATION_DATE  \
# 45234  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45235  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45236  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45237  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45238  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45239  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45240  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45241  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45242  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45243  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45244  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45245  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45246  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45247  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45248  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45249  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45250  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45252  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45253  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45254  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45255  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45256  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45257  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45258  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45259  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45260  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45261  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45262  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45263  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45264  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45265  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45266  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45267  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45268  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45269  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45270  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45271  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45272  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45273  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45274  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45275  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45276  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45277  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45278  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45279  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45280  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45282  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45283  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45284  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
# 45285  AL SHUMOOKH NATIONAL FOODSTUFF TRADING-SOLE PR...    2021-09-21
#
#        AMOUNT_ORDERED
# 45234       2280.0096
# 45235        215.0000
# 45236        528.0000
# 45237       2548.0000
# 45238        460.8000
# 45239       1166.0000
# 45240        318.7500
# 45241        176.0000
# 45242        328.1250
# 45243        829.5000
# 45244        107.5000
# 45245         88.0000
# 45246        744.0000
# 45247        313.5000
# 45248        224.2500
# 45249        510.0000
# 45250         91.7400
# 45252        600.0000
# 45253       1800.0000
# 45254       3936.0000
# 45255        618.7500
# 45256        732.0000
# 45257       5669.9949
# 45258       2752.0000
# 45259         79.2000
# 45260         52.8000
# 45261        118.8000
# 45262       1296.0000
# 45263       2888.0000
# 45264        690.0000
# 45265        423.3000
# 45266        101.2500
# 45267        729.0000
# 45268       1563.5000
# 45269        441.0000
# 45270        607.5000
# 45271         28.0000
# 45272         40.8000
# 45273         27.0000
# 45274        125.0000
# 45275         22.5000
# 45276        698.0000
# 45277         72.0000
# 45278         60.0000
# 45279        120.0000
# 45280        220.0000
# 45282        188.0000
# 45283       1198.5000
# 45284       1400.0000
# 45285        312.5000

# %%
ggf =pd.DataFrame(gg)

# %%
hh = ggf.sort_values(by=['VENDOR_NAME','CREATION_DATE'],ascending=[True,False])

# %%
gg.duplicated(subset=['VENDOR_NAME'],keep='first')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-d2dac54b2831> in <module>
# ----> 1 gg.duplicated(subset=['VENDOR_NAME'],keep='first')
#
# TypeError: duplicated() got an unexpected keyword argument 'subset'

# %%
pd.DataFrame(gg)
# Out:
#                                                                                             AMOUNT_ORDERED
# VENDOR_NAME                                        PO_NUMBER  LEDGER_NAME    CREATION_DATE
# PASTEUR COMMERCIAL LIMITED - L.L.C                 8474200138 KUADRIC Ledger 2021-01-03           14000.00
# HAVAC & POWER SOLUTIONS - F.Z.E                    8432201816 KUX - Ledger   2021-01-03           22650.00
# AIR PRODUCTS GULF GAS L.L.C.                       8474200139 KUADRIC Ledger 2021-01-03            9325.00
# BDH MIDDLE EAST L.L.C.                             8432201817 KUX - Ledger   2021-01-03            3768.00
# BUSINESS COMMUNICATIONS CO. L.L.C. - ABU DHABI ... 8474200141 KUADRIC Ledger 2021-01-04           20808.80
# ...                                                                                                    ...
# UTS CARRIER L.L.C.                                 8472107756 KUST Ledger    2022-02-11         2684420.00
#                                                    8472107758 KUST Ledger    2022-02-11          895600.00
# PETRO MIDDLE EAST                                  8472107755 KUST Ledger    2022-02-11         5700000.00
# IMDAAD L.L.C. - ABU DHABI BRANCH                   8472107751 KUST Ledger    2022-02-11         1082950.00
# AIR LIQUIDE EMIRATES FOR INDUSTRIAL GASES L.L.C    8472107760 KUST Ledger    2022-02-12             500.96
#
# [1460 rows x 1 columns]

# %%
hh=hh.reset_index()

# %%
hh[hh.duplicated('VENDOR_NAME',keep=False)].to_excel('keep.xlsx')
