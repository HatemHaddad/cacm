# %%
import pandas as pd
import numpy as np
import pyodbc
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
svr_name = 'KU1ICDDWV011.kunet.ae'
db_name = 'CACM'
u_name = 'cacm_user'
u_pass = 'Welcome#123'

# %%
eng = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name+"?driver=ODBC+Driver+17+for+SQL+Server")

# %%
query_supplier = "select * from dbo.KU_SRC_BI_KUST_SUPPLIER"
query_employee_details = "select * from dbo.KU_SRC_EmployeeDetails"

# %%
supplier = pd.read_sql(query_supplier, eng)
employee = pd.read_sql(query_employee_details, eng)

# %%
suplier_copy = supplier[['SUPPLIER_NAME','SUPPLIER_CATEGORY']].drop_duplicates()

# %%
emp_29 = employee[employee['EmpNo'].isin(['KU509','KU328','KU500387','KU450','KU348','KU500310','KU320','KU500205','KU500038',
'KU386','KU206','KU559','100049994','KU493','KU500295','KU242','KU430','KU661','KU500321','KU753','KU850','KU858','KU866','KU898','KU500448',
 'KU500089','KU500200','KU500222','KU500383'])]

# %%
emp_29[['EmpNo','EmployeeName','PositionName','OrgUnit','Job','HireDate','Nationality','Department']]
# Out:
#           EmpNo                            EmployeeName  \
# 4     100049994                       Riyazdheen Kaffar
# 166       KU206                              Hadi Otrok
# 194       KU242                            Kinda Khalaf
# 258       KU320                       Khalifa Al Hosani
# 264       KU328               Joel Gregory Lucero-Bryan
# 281       KU348                        Hani Hasan Saleh
# 317       KU386               Athol Tomas Richard Yates
# 352       KU430                         Lejla Kucukalic
# 369       KU450         Mihai Adrian Tiberiu Sanduleanu
# 402       KU493                      Abdulla AlBusaeedi
# 432    KU500038            Salwa Mohamed Rashed Alzahmi
# 458    KU500089                     Michael John Weston
# 524    KU500200                    Mohammed H M Shurrab
# 526    KU500205             Irfan Muhammad Amir Hussain
# 537    KU500222                  Rambabu Krishnamoorthy
# 568    KU500295                       Abdul Raouf Tajik
# ...

# %%
emp_29.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 4 to 1139
# Data columns (total 44 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmpNo                29 non-null     object
#  1   PersonID             29 non-null     float64
#  2   EmployeeName         29 non-null     object
#  3   EmployeeArabicName   29 non-null     object
#  4   Position             29 non-null     object
#  5   PositionName         29 non-null     object
#  6   PositionCode         29 non-null     object
#  7   PositionAR           29 non-null     object
#  8   Job                  29 non-null     object
#  9   OrgUnit              29 non-null     object
#  10  OrgUnitAR            29 non-null     object
#  11  Payroll              29 non-null     object
#  12  Grade                29 non-null     object
#  13  Nationality          29 non-null     object
#  14  ArCountry            29 non-null     object
# ...
