# %%
import pandas as pd
import numpy as np
import pyodbc
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
svr_name = 'KU1ICDDWV011.kunet.ae'
db_name = 'CACM'
u_name = 'cacm_user'
u_pass = 'Welcome#123'

# %%
eng = create_engine("mssql+pyodbc://"+u_name+":"+u_pass+"@"+svr_name+"/"+db_name+"?driver=ODBC+Driver+17+for+SQL+Server")

# %%
query = "select * from aderp.dbo.XXDOF_BI_KU_PAYROLL_T"

# %%
payroll = pd.read_sql(query, eng)

# %%
payroll = payroll.astype({'ELEMENTVALUE':'float64'})

# %%
pay_ind = payroll.set_index(['PAYYEAR','PAYMONTH'])

# %%
payroll['Year'] = payroll['LASTUPDATEDATE'].dt.year

# %%
payroll['Month'] = payroll['LASTUPDATEDATE'].dt.month

# %%
payroll_20_21 = payroll[np.logical_or(payroll['Year'] == 2020,payroll['Year'] == 2021) & (payroll['ELEMENTNAME'] == 'Basic Salary')]
housing_20_21 = payroll[np.logical_or(payroll['Year'] == 2020,payroll['Year'] == 2021) & (payroll['ELEMENTNAME'] == 'Housing Allowance')]

# %%
payroll_pivot = payroll_20_21.pivot_table('ELEMENTVALUE',index='EMPLOYEENUMBER',columns=['Year','Month'])
housing_pivot = housing_20_21.pivot_table('ELEMENTVALUE',index='EMPLOYEENUMBER',columns=['Year','Month'])

# %%
housing_pivot
# Out:
# Year                2020                                               \
# Month                 1        2        3        4        5        6
# EMPLOYEENUMBER
# KU500018             NaN      NaN      NaN      NaN      NaN      NaN
# KU500079             NaN      NaN      NaN      NaN      NaN      NaN
# KU500417            0.00      NaN      NaN      NaN      NaN      NaN
# KU500421             NaN      0.0      NaN      NaN      NaN      NaN
# KU500422            0.00      NaN      NaN      NaN      NaN      NaN
# ...                  ...      ...      ...      ...      ...      ...
# PI4283          14666.00  14666.0  14666.0  14666.0  14666.0  14666.0
# PI4349              0.00      NaN      NaN      NaN      NaN      NaN
# PI4365           9166.00   9166.0   9166.0   9166.0   9166.0   9166.0
# PI4406               NaN      NaN      NaN      NaN      NaN      NaN
# PI4551          16666.67      0.0      NaN      NaN      NaN      NaN
#
# Year                                                ...     2021           \
# Month                7        8        9        10  ...       3        4
# EMPLOYEENUMBER                                      ...
# KU500018            NaN      NaN      NaN      NaN  ...      NaN      NaN
# KU500079            NaN      NaN      NaN      NaN  ...      NaN      NaN
# KU500417            NaN      NaN      NaN      NaN  ...      NaN      NaN
# KU500421            NaN      NaN      NaN      NaN  ...      NaN      NaN
# KU500422            NaN      NaN      NaN      NaN  ...      NaN      NaN
# ...                 ...      ...      ...      ...  ...      ...      ...
# PI4283          14666.0  14666.0  14666.0  14666.0  ...  14666.0  14666.0
# PI4349              NaN      NaN      NaN      NaN  ...      NaN      NaN
# PI4365           9166.0   9166.0   9166.0   9166.0  ...   9166.0   9166.0
# PI4406              NaN      NaN      NaN      NaN  ...      NaN      NaN
# PI4551              NaN      NaN      NaN      NaN  ...      NaN      NaN
#
# Year                                                                   \
# Month                5         6        7        8        9        10
# EMPLOYEENUMBER
# KU500018            NaN  16666.67      NaN      NaN      NaN      NaN
# KU500079            NaN  16666.67      NaN      NaN      NaN      NaN
# KU500417            NaN  10833.33      NaN      NaN      NaN      NaN
# KU500421            NaN       NaN      NaN      NaN      NaN      NaN
# KU500422            NaN  12500.00      NaN      NaN      NaN      NaN
# ...                 ...       ...      ...      ...      ...      ...
# PI4283          14666.0  14666.00  14666.0  14666.0  14666.0  14666.0
# PI4349              NaN  12500.00      NaN      NaN      NaN      NaN
# PI4365           9166.0       NaN      NaN      NaN      NaN      NaN
# PI4406              NaN   9166.67      NaN      NaN      NaN      NaN
# PI4551              NaN  16666.67      NaN      NaN      NaN      NaN
#
# Year
# Month                11       12
# EMPLOYEENUMBER
# KU500018            NaN      NaN
# KU500079            NaN      NaN
# KU500417            NaN      NaN
# KU500421            NaN      NaN
# KU500422            NaN      NaN
# ...                 ...      ...
# PI4283          14666.0  14666.0
# PI4349              NaN      NaN
# PI4365              NaN      NaN
# PI4406              NaN      NaN
# PI4551              NaN      NaN
#
# [96 rows x 24 columns]

# %%
#(payroll_pivot[payroll_pivot.nunique(axis=1).eq(3)].diff(axis=1))
(payroll_pivot[payroll_pivot.nunique(axis=1).eq(3)]).to_excel("basic_change_3_times.xlsx")

# %%
(payroll_pivot.loc['KU883'].pct_change()*100).round(2)
# Out:
# Year  Month
# 2020  1          NaN
#       2         0.00
#       3        18.12
#       4         0.00
#       5         0.00
#       6         0.00
#       7         0.00
#       8         0.00
#       9         0.00
#       10        0.00
#       11        0.00
#       12        0.00
# 2021  1         0.00
#       2         0.00
#       3         0.00
#       4         0.00
#       5         0.00
#       6         0.00
#       7         0.00
#       8        10.00
#       9         0.00
#       10        0.00
#       11        0.00
#       12        0.00
# Name: KU883, dtype: float64

# %%
consolidation = payroll2021[['EMPLOYEENUMBER','Month','CONSOLIDATION_SET_NAME']]

# %%
consolidation
# Out:
#        EMPLOYEENUMBER  Month    CONSOLIDATION_SET_NAME
# 2964        100035679      4         QuickPay Approved
# 4923            KU902      1         QuickPay Approved
# 5040            KU913      1         QuickPay Approved
# 5041            KU913      1         QuickPay Approved
# 5047            KU903      2         QuickPay Approved
# ...               ...    ...                       ...
# 512824       KU500052     12  External Non-Researchers
# 512829       KU500054     12  External Non-Researchers
# 512833       KU500055     12  External Non-Researchers
# 512837          KU919     12  External Non-Researchers
# 512841       KU500566     12  External Non-Researchers
#
# [11318 rows x 3 columns]

# %%
consolidation.pivot_table(index='EMPLOYEENUMBER',columns='Month',aggfunc='first').to_excel('consolidation.xlsx')

# %%
payroll[payroll['EMPLOYEENUMBER'] == 'KU105'].to_excel('KU105_All.xlsx')

# %%
Housing_pivot
# Out:
# Year                2020                                               \
# Month                 1        2        3        4        5        6
# EMPLOYEENUMBER
# KU500018             NaN      NaN      NaN      NaN      NaN      NaN
# KU500079             NaN      NaN      NaN      NaN      NaN      NaN
# KU500417            0.00      NaN      NaN      NaN      NaN      NaN
# KU500421             NaN      0.0      NaN      NaN      NaN      NaN
# KU500422            0.00      NaN      NaN      NaN      NaN      NaN
# ...                  ...      ...      ...      ...      ...      ...
# PI4283          14666.00  14666.0  14666.0  14666.0  14666.0  14666.0
# PI4349              0.00      NaN      NaN      NaN      NaN      NaN
# PI4365           9166.00   9166.0   9166.0   9166.0   9166.0   9166.0
# PI4406               NaN      NaN      NaN      NaN      NaN      NaN
# PI4551          16666.67      0.0      NaN      NaN      NaN      NaN
#
# Year                                                ...     2021           \
# Month                7        8        9        10  ...       3        4
# EMPLOYEENUMBER                                      ...
# KU500018            NaN      NaN      NaN      NaN  ...      NaN      NaN
# KU500079            NaN      NaN      NaN      NaN  ...      NaN      NaN
# KU500417            NaN      NaN      NaN      NaN  ...      NaN      NaN
# KU500421            NaN      NaN      NaN      NaN  ...      NaN      NaN
# KU500422            NaN      NaN      NaN      NaN  ...      NaN      NaN
# ...                 ...      ...      ...      ...  ...      ...      ...
# PI4283          14666.0  14666.0  14666.0  14666.0  ...  14666.0  14666.0
# PI4349              NaN      NaN      NaN      NaN  ...      NaN      NaN
# PI4365           9166.0   9166.0   9166.0   9166.0  ...   9166.0   9166.0
# PI4406              NaN      NaN      NaN      NaN  ...      NaN      NaN
# PI4551              NaN      NaN      NaN      NaN  ...      NaN      NaN
#
# Year                                                                   \
# Month                5         6        7        8        9        10
# EMPLOYEENUMBER
# KU500018            NaN  16666.67      NaN      NaN      NaN      NaN
# KU500079            NaN  16666.67      NaN      NaN      NaN      NaN
# KU500417            NaN  10833.33      NaN      NaN      NaN      NaN
# KU500421            NaN       NaN      NaN      NaN      NaN      NaN
# KU500422            NaN  12500.00      NaN      NaN      NaN      NaN
# ...                 ...       ...      ...      ...      ...      ...
# PI4283          14666.0  14666.00  14666.0  14666.0  14666.0  14666.0
# PI4349              NaN  12500.00      NaN      NaN      NaN      NaN
# PI4365           9166.0       NaN      NaN      NaN      NaN      NaN
# PI4406              NaN   9166.67      NaN      NaN      NaN      NaN
# PI4551              NaN  16666.67      NaN      NaN      NaN      NaN
#
# Year
# Month                11       12
# EMPLOYEENUMBER
# KU500018            NaN      NaN
# KU500079            NaN      NaN
# KU500417            NaN      NaN
# KU500421            NaN      NaN
# KU500422            NaN      NaN
# ...                 ...      ...
# PI4283          14666.0  14666.0
# PI4349              NaN      NaN
# PI4365              NaN      NaN
# PI4406              NaN      NaN
# PI4551              NaN      NaN
#
# [96 rows x 24 columns]

# %%
payroll_basic_2021 = payroll[(payroll['Year'] == 2021) & (payroll['ELEMENTNAME'] == 'Basic Salary')]

# %%
jan = payroll_basic_2021.loc[:,['ELEMENTVALUE','Month']]

# %%
jan.boxplot(column='ELEMENTVALUE',by='Month',figsize=(12,8))
plt.show()
